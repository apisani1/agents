# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv, find_dotenv
from models import ChatModel

# %%
# Always remember to do this!
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging
from warning_beep import warning_beep

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    warning_beep(); print("\033[31mOpenAI API Key not set\033[0m")

if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    warning_beep(); print("\033[31mAnthropic API Key not set\033[0m")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    warning_beep(); print("\033[31mGoogle API Key not set\033[0m")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    warning_beep(); print("\033[31mDeepSeek API Key not set\033[0m")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    warning_beep(); print("\033[31mGroq API Key not set\033[0m")
# Out:
# OpenAI API Key exists and begins sk-3SZmF
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
question = ChatModel(
            model_name="gpt-5-mini",
            provider="openai"
        ).generate_response(
            messages=messages,
            print_response=True
        )
# Out:
# You are an advisor to the mayor of a mid-sized coastal city (population ~300,000) with aging stormwater and transportation infrastructure, stark income disparities across neighborhoods, limited institutional capacity, and moderately optimistic climate projections (approx. 50 cm sea-level rise by 2050 under current trajectories). The city has a one-time capital pool of $500 million and can increase annual operating spending by $20 million over the next 10 years. Construct a prioritized, evidence-based 10-year adaptation plan that (1) lists specific interventions (structural and non-structural) with approximate cost breakdowns and timelines, (2) explains and justifies the prioritization in terms of risk reduction, equity, economic resilience, and co-benefits, (3) quantifies expected benefits where possible (e.g., reduced flood frequency, avoided damages, estimated lives/dwellings protected, emissions consequences), (4) identifies the key uncertainties and data gaps that could alter the plan and what additional data you would request, (5) proposes financing and governance mechanisms to implement and maintain the plan while ensuring equitable outcomes, (6) defines 6–8 measurable metrics to evaluate success, and (7) describes how you would update/prioritize the plan under each of these three alternative scenarios: (a) a sudden 30% cut in available funds, (b) sea-level rise accelerates to 100 cm by 2050, and (c) a major downtown employer relocates out of the city causing a 12% loss in municipal revenues and increased unemployment. List your assumptions clearly and state your confidence level in the main recommendations.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
model_name = "gpt-5-nano"
answer = ChatModel(
            model_name=model_name,
            provider="openai"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a concise, evidence-informed 10-year adaptation plan tailored to a mid-sized coastal city with aging stormwater/transportation systems, equity gaps, and limited capacity. All costs are approximate order-of-magnitude, in 2024 dollars, and are intended to fit within the available resources: $500 million in one-time capital funds plus $20 million per year for operating expenditures over 10 years (total operating: about $200 million). Where appropriate, I note assumptions, data needs, and uncertainties.
#
# 1) Assumptions and context
# - Physical and climate context:
#   - Population ~300,000; coastal exposure with a 50 cm sea-level rise projection by 2050 under current trajectories; heavy rainfall events with pluvial flooding risk in urban cores.
#   - Existing aging stormwater and transportation infrastructure with limited redundancy and maintenance funding.
# - Financial framework:
#   - One-time capital pool: $500 million.
#   - Additional operating funds: +$20 million/year for 10 years (total $200 million over the decade).
#   - Desired balance: prioritize high-risk, high-reward interventions that improve equity and economic resilience, while preserving essential services and enabling ongoing maintenance.
# - Governance and capacity:
#   - Limited institutional capacity; plan emphasizes scalable, phased implementation, simplified procurement, and targeted capacity building.
# - Equity lens:
#   - Recognize disproportionate exposure in historically underserved neighborhoods; ensure access to protection, mobility, and resilience benefits.
#
# 2) 10-year prioritized adaptation plan (interventions, costs, timelines, benefits)
# Note: All costs are approximate ranges in millions USD; timelines are indicative phasing.
#
# A. Tier 1 (core risk reduction in the near term; high leverage with co-benefits)
# 1) Downtown coastal protection package (structural)
# - What: Seawall/shoreline hardening along critical waterfront corridors; tidal gates or flood barriers at key crossings; elevate select street segments and protect essential transit corridors.
# - Type: Structural.
# - Capital cost: $180–$230m.
# - Operating: modest maintenance; $2–5m over 10 years (covered by annual operating budget).
# - Timeline: Year 1–4 (design Year 1, construction Years 2–4).
# - Expected benefits: substantial reduction in flood depths/failure risk in the downtown/core economic district; protects critical facilities (e.g., hospital, municipal buildings, utilities); reduces business interruption and flood-related damages; potential co-benefits for property values and tax base retention.
# - Co-benefits/quantification (order of magnitude): avoid several major flood events over 10 years; higher downtown resilience supports employment continuity and tourism.
# - Key uncertainties: exact shoreline alignment; permitting; long-term material durability; maintenance costs.
#
# 2) Urban stormwater system modernization (gray-to-green hybrid)
# - What: Upgrades to conveyance (pipes, pump stations, backflow prevention), plus intensification of green-blue infrastructure (bioswales, rain gardens, permeable pavements, detention ponds) in target basins.
# - Type: Structural + non-structural (nature-based components).
# - Capital cost: $120–$140m.
# - Operating: $1–3m/year for maintenance and monitoring.
# - Timeline: Year 1–5 (design Year 1–2; construction Years 2–5).
# - Expected benefits: improved flood capture during rainfall events; reduced urban flooding frequency; improved water quality and urban heat island mitigation; supports connectivity for neighborhoods newly protected by green infrastructure.
# - Co-benefits: cost-effective comp; potential reductions in combined sewer overflows if applicable; supports local greenspace; job training for maintenance.
#
# 3) Critical facilities hardening and energy resilience
# - What: Back-up power, floodproofing and protective upgrades for municipal administration, wastewater treatment, water supply, hospital, emergency operations center.
# - Type: Structural.
# - Capital cost: $20–$40m.
# - Operating: ongoing maintenance ~$0.5–1m/yr.
# - Timeline: Year 1–3.
# - Expected benefits: continuity of essential services during floods; reduces casualty risk and service disruption.
# - Co-benefits: supports emergency response capacity; improves public safety.
#
# 4) Buyouts/relocation in the highest-risk zones (managed retreat where cost-effective)
# - What: Acquisition/relocation incentives for homes/businesses in flood-prone areas; targeted, voluntary buyouts with relocation assistance and redevelopment in safer locations.
# - Type: Non-structural (land-use alteration).
# - Capital cost: $20–$60m (depends on area size and property values; may be funded by grants and phased).
# - Operating: program administration $1–2m/yr.
# - Timeline: Year 2–7 (scoping Year 1; offer rounds Years 2–5; closeouts Years 5–7).
# - Expected benefits: reduces exposure and long-term insurance/maintenance burdens; creates opportunities for open space or resilient redevelopment; supports equity by offering safe housing options.
# - Co-benefits: potential for climate-smart redevelopment; can reduce future capital needs if high-risk properties are removed.
#
# 5) Transportation resilience improvements (flood-ready mobility)
# - What: Elevation/realignment of flood-prone road segments, improved drainage under and around key corridors, floodable/temporary detour planning for critical routes, enhanced transit corridors with raised platforms where needed.
# - Type: Structural + planning.
# - Capital cost: $40–$70m.
# - Operating: $1–2m/yr.
# - Timeline: Year 1–5.
# - Expected benefits: reduced disruption to essential commuting and freight, maintains economic activity during storms.
# - Co-benefits: improves safety; supports continuity for essential workers.
#
# 6) Monitoring, data, and adaptive management system
# - What: Sensor networks (water levels, rainfall, tide), real-time dashboards, GIS risk maps, and an adaptive plan review cadence.
# - Type: Non-structural with some technology deployment.
# - Capital cost: $10–$20m.
# - Operating: $1–2m/yr.
# - Timeline: Year 1–3 (install), then ongoing.
# - Expected benefits: better targeting of interventions; improved warning and response; data-driven adjustments to priorities.
# - Uncertainty: device maintenance and data integration costs; reliance on ongoing funding.
#
# 7) Nature-based resilience and green infrastructure scale-up (urban green network)
# - What: Wetlands restoration, urban trees and canopy expansion, bioswales along streets, green roofs, and small moist detention features integrated into public spaces.
# - Type: Structural + non-structural (nature-based).
# - Capital cost: $60–$90m.
# - Operating: $2–4m/yr (maintenance).
# - Timeline: Year 1–6.
# - Expected benefits: flood risk reduction through multiple pathways, cooling and air-quality improvements, enhanced biodiversity, public realm improvements.
# - Co-benefits: climate mitigation (lower emissions from urban cooling), public health improvements, property value stabilization in improved neighborhoods.
#
# 8) Economic resilience and equity program
# - What: Local hiring, small business resilience grants, energy and water bill assistance for low-income households, and capacity-building for neighborhood-led resilience projects.
# - Type: Non-structural.
# - Capital cost: $5–15m (seed funding; primarily programmatic).
# - Operating: $4–6m/yr.
# - Timeline: Year 1–10.
# - Expected benefits: reduces climate vulnerability for low-income residents, supports local job retention, and improves plan legitimacy and uptake.
# - Co-benefits: reduces social vulnerability; supports diversification of the tax base in the long run.
#
# 9) Planning, governance, and capacity-building
# - What: Establish a city resilience office or designate a cross-department resilience unit; standardize procurement for resilience projects; develop equity and climate-risk screening for all capital projects; staff training.
# - Type: Non-structural.
# - Capital cost: $5–10m.
# - Operating: $1–2m/yr.
# - Timeline: Year 1–3; ongoing.
# - Expected benefits: improves project delivery, reduces bottlenecks, ensures equity in implementation.
#
# Total capital (target): approximately $480–520 million (within the $500m cap with some cost-saving by prioritizing high-leverage items and potential grant matches). Contingency: built into line items where feasible.
#
# Total operating (10-year): about $200 million (approx. $20m/year).
#
# Notes:
# - The plan prioritizes high-risk, high-reward interventions near the waterfront and in major transit and economic corridors, while weaving in green infrastructure and non-structural measures to maximize co-benefits and equity.
# - If grants or state/federal programs (e.g., BRIC, IIJA, TVA-like resilience funds) materialize, reallocate some capital toward additional buyouts or more ambitious hard protections without increasing net cost.
#
# 3) Why this prioritization? Key evaluation pillars
# - Risk reduction: The waterfront and downtown are high-value, high-risk; hard protections combined with improved drainage and early warning systems dramatically reduce expected flood losses and business interruption.
# - Equity: Targeted improvements in historically underserved neighborhoods via nature-based solutions, access to resilience programs, and non-discriminatory planning ensure protection does not concentrate benefits in affluent areas.
# - Economic resilience: Protecting downtown and transportation corridors preserves tax base, jobs, and supply chains; resilient transit and lower flood disruption improve business continuity and attract investment.
# - Co-benefits: Green infrastructure lowers heat, improves air quality, increases biodiversity, and adds public realm value; better data and governance systems reduce long-run management costs and improve transparency.
# - Feasibility: Balances high-impact capital investments with maintainable ongoing operations; phased approach aligns with available capital and growing operating budget.
#
# 4) Quantified benefits and expectations (where possible)
# - Flood risk reduction: For the most exposed downtown and waterfront areas, protective works plus drainage improvements could reduce annual expected flood damages by roughly 40–70% depending on event severity; in a 10-year horizon, this translates to many tens of millions in avoided damages, plus avoided business interruption costs.
# - Dwellings and lives: Buyouts/out-of-risk relocation in the highest-risk zones could reduce exposure for dozens to a few hundred dwellings, with potential lives saved in extreme events (exact figures depend on event probability; plan assumes priority for the most exposed properties).
# - Economic resilience: Retained downtown activity during storms; reduced closure times for critical corridors; improved reliability could preserve or increase local employment and tax revenue resilience.
# - Emissions and climate: Green/blue infrastructure and better transit resilience reduce vehicle miles traveled during recovery periods and improve energy efficiency; estimated CO2 impact modest but material over a 10-year horizon when scaled citywide.
# - Public health and quality of life: Heat mitigation through shade trees and green spaces; better air quality; enhanced public safety due to more robust emergency response.
# - Costs vs. benefits: The plan’s expected avoided damages and productivity gains should, in aggregate, exceed amortized capital plus maintenance costs over 10 years, especially if leveraging federal/state grants and leveraging co-benefits for long-term municipal creditworthiness.
#
# 5) Key uncertainties and data gaps (and data requests)
# - Hazard and exposure data:
#   - Refined, neighborhood-scale flood hazard maps under multiple sea-level rise scenarios (0.5m, 1.0m, plus storm surge scenarios).
#   - Detailed asset inventory of water/wastewater facilities, transit assets, hospitals, schools, and critical utilities by flood exposure.
#   - Current condition and maintenance backlog of stormwater and transportation systems.
#   - Population and housing at risk by neighborhood, including informal housing and informal settlements if present.
# - Economic assumptions:
#   - Local tax base exposure and variability under major employers’ relocation or downturn.
#   - Private property valuations and acquisition costs for potential buyouts.
# - Program uptake and costs:
#   - Likelihood and cost of private property participation in buyouts/relocation; administrative costs for programs; maintenance costs for green infrastructure including lifecycle costs.
# - Climate uncertainty:
#   - Range and probability of extreme rainfall intensities; 2050/2100 sea-level rise trajectories under alternate emissions scenarios.
# - Institutional capacity:
#   - Availability of skilled staff, and potential need for external project management or consulting support.
#
# Requests for data:
# - Updated hazard maps (pluvial and coastal) with 25–50 year design standards.
# - Inventory of critical infrastructure vulnerabilities and backup power capabilities.
# - Neighborhood-level exposure and socioeconomic data to refine equity-focused targeting.
# - Feasibility studies for buyouts (land availability, relocation options, zoning constraints).
# - Economic impact studies for downtown resilience measures and potential grant matches.
#
# 6) Financing, governance, and accountability
# - Governance structure:
#   - Create a central Resilience Office or cross-department resilience council with clear mandates, accountability, and streamlined procurement. Include a standing Equity and Community Engagement Panel to ensure fair distribution of benefits.
# - Financing mix:
#   - Capital: Primary leverage via the $500m capital pool; pursue grants and intergovernmental funds (state/federal) to complement capital; consider debt financing (general obligation bonds or revenue-backed bonds) if market conditions allow without crowding out operating needs.
#   - Operating: Use annual increment of $20m for ongoing maintenance, program administration, and equity initiatives. Consider a resilience revolving loan fund for private property retrofits (self-payback via avoided damages or storm reliability improvements).
# - Program design:
#   - Establish a Resilience Fund with clear project eligibility criteria, performance-based milestones, and transparent prioritization (risk reduction, equity, co-benefits).
#   - Private-public partnerships for certain components (e.g., frontage improvements along key corridors, private maintenance agreements for green infrastructure on public land).
#   - Insurance and risk-transfer mechanisms for high-exposure properties; engage NFIP-based products and private reinsurance as appropriate.
# - Procurement and contracting:
#   - Use modular design and design-build approaches to accelerate delivery; pre-qualify contractors for resilience projects; standardize performance specs to reduce procurement friction.
# - Community engagement:
#   - Early and ongoing engagement with vulnerable communities; maintain a public dashboard of progress, costs, and benefits; provide outreach in multiple languages where applicable.
#
# 7) Measurable metrics to evaluate success (6–8 metrics)
# - Physical risk metrics:
#   - Percent reduction in annual flood damages in high-risk areas (accounts for both coastal and pluvial flooding) and number of flood events reaching critical facilities.
#   - Change in time to restore critical services after flood events (restoration time).
#   - Proportion of critical facilities with flood protection and backup power (target: 100% for hospitals, water treatment, EOC, etc.).
# - Exposure and equity metrics:
#   - Population and dwellings in flood-prone zones after implementation (reduced exposure).
#   - Share of resilience investments allocated to historically underserved neighborhoods.
#   - Number of households/companies receiving resilience grants and assistance.
# - Economic and resilience metrics:
#   - Downtown economic continuity metrics: average downtown business interruption days per flood event; tax base stability indicators.
#   - Transportation network reliability: percent of critical corridors remaining operational during floods; transit service uptime during extreme events.
#   - Job creation from resilience investments (construction and maintenance phases) and long-term local hiring in resilience projects.
# - Environmental and co-benefit metrics:
#   - Amount of green/infiltration capacity installed; reduction in urban heat island index; co-benefits in air quality indices.
#   - Lifecycle maintenance costs of green infrastructure per square meter of protected area.
# - Governance and capacity metrics:
#   - Time-to-deliver for resilience projects from authorization to completion; percent of projects meeting schedule and budget targets; stakeholder satisfaction scores.
#
# 8) Scenario analyses: how to update/prioritize under three scenarios
# Assumptions for scenario planning:
# - Baseline remains: 10-year horizon, capital cap at $500m, operating $20m/year, governance capacity is limited but improvable.
# - Data and market uncertainties could shift costs, actual hazard exposure, and economic conditions.
#
# Scenario (a): Sudden 30% cut in available funds
# - Implications: Capital pool reduces to about $350m; operating budget remains at about $200m (or potentially reduced through efficiency); overall resources decline by ~30%.
# - Plan adjustments:
#   - Prioritize the highest-leverage, cost-effective interventions first (Tier 1 items): downtown protection package, stormwater modernization in priority basins, critical facilities hardening, and essential monitoring.
#   - Defer or scale back lower-priority items (e.g., buyouts in less exposed neighborhoods, large-scale green infrastructure expansions beyond initial basins).
#   - Accelerate grant applications and private partnerships to leverage non-local funds and in-kind contributions.
#   - Use phased implementation with shorter construction windows and multi-use designs to reduce upfront costs.
#   - Maintain core equity investments via targeted programs (small grants, resilience coaching) to avoid widening disparities.
# - Expected outcome: Core risk reduction still achieved for the most critical infrastructure and neighborhoods; some non-structural measures and expanded green infrastructure may be slowed or scaled; overall resilience improves but with higher risk of exposure if hazards intensify.
#
# Scenario (b): Sea-level rise accelerates to 100 cm by 2050
# - Implications: Hazard levels in coastal zones increase significantly; many planned protections could be inadequate under this trajectory; higher risk of larger flood events and more frequent power and transit disruptions.
# - Plan adjustments:
#   - Reassess risk-models and re-prioritize to maximize protection for the most valuable assets (downtown, wastewater treatment, hospital and EOC) with more robust hard protections and multi-barrier approaches (barriers, pumped relief, elevated connectors).
#   - Accelerate nature-based solutions in suitable locations to provide adaptive capacity (wetlands + floodable parks) to absorb surge and floodwaters, complementing hard protections.
#   - Expand buyouts/retreat options in the most exposed neighborhoods to prevent future loss; adjust zoning to limit new development in high-risk zones.
#   - Seek state/federal cost-sharing and grants for flood protection at scale; consider dedicated resilience revenue streams (e.g., resilience bonds, impact fees) if permissible.
#   - Update capital plan timelines: bring forward the most protective components into Years 1–3 if feasible; otherwise sequence with explicit risk-based triggers (e.g., hazard thresholds).
# - Expected outcome: A more protective, multi-layered approach to address intensified risk; insurance and finance considerations become more complex; greater emphasis on retreat and redevelopment in the highest-risk zones.
#
# Scenario (c): Major downtown employer relocates, causing 12% revenue loss and higher unemployment
# - Implications: Municipal revenues and households' financial capacity reduce; potential upward pressure on costs and debt service; slower tax-base growth could constrain resilience investments.
# - Plan adjustments:
#   - Protect core resilience investments with alternative financing: emphasize grants, state/federal supports, and resilience bonds; consider revenue diversification strategies (economic development incentives targeted to attract/retain employers; faster permitting for business resilience improvements).
#   - Prioritize investments that have high short-term economic returns (e.g., transportation resilience for freight/retail corridors; improvements that shorten business disruption times; critical facilities hardening).
#   - Accelerate workforce development and small business resilience programs to retain jobs and support local economy; reallocate some operating funds to targeted economic relief and small-business resilience grants.
#   - Revisit affordability of financing and debt service; negotiate longer debt maturities or contingent funding from state/federal levels; implement performance-based funding to ensure high-priority projects are completed if revenues rebound.
# - Expected outcome: The plan remains actionable, but with tighter fiscal constraints. A focus on job retention, rapid-return-on-investment projects, and strong external funding becomes essential to maintain progress.
#
# 9) Confidence level and key caveats
# - Overall plan design: high-level, multi-criteria rationale appears sound for a mid-sized coastal city with the given constraints. Confidence in the core strategy (protect-critical, upgrade drainage, blend nature-based solutions, ensure equity, build governance capacity) is moderate-to-high (roughly 70–85% for the strategic approach).
# - Cost estimates: approximate and contingent on local design, permitting, land costs, and procurement. The total capital and operating cost ranges are broad; exact allocations should be refined with a detailed cost engineering study and grant scoping.
# - Data and parametrization: risk and benefit estimates depend on hazard maps, exposures, and economic multipliers that require updated data. There are substantial uncertainties in exact avoided damages and lives protected, but the relative risk reduction and co-benefits are robust.
# - Political and institutional feasibility: depends on political will, interdepartmental coordination, and capacity-building success; the governance framework should be established early to improve delivery.
#
# 10) How I would present this plan to the Mayor and Council
# - Executive summary: 10-year plan with capital and operating budgets, prioritized by risk, equity, and economic resilience; a phased, fundable path within existing resources.
# - Financial plan: clearly show capital allocation by project, phased with potential grants and private partnerships; present scenarios for different funding levels (baseline, grant-enhanced, and debt-assisted).
# - Risk and equity focus: demonstrate how investments reduce exposure for the most vulnerable neighborhoods; show how benefits are distributed and tracked.
# - Implementation plan: milestones, responsible departments, procurement approach, and a governance charter for the resilience office.
# - Data plan: list required datasets, data gaps, and a timeline for procurement of hazard maps and asset inventories.
# - Metrics dashboard: present the 6–8 metrics with annual targets and reporting cadence.
#
# Key assumptions to restate
# - Population remains around 300,000 with gradual growth; climate projections stay within the moderate-to-optimistic range (with a 50 cm SLR by 2050 as baseline scenario).
# - Capital at $500m; operating budget adds $20m/year for 10 years; no sudden, large, unforeseen revenue windfalls or deficits beyond those scenarios.
# - Federal/state grant opportunities are accessible and can be matched to local projects.
# - Public acceptance and timely permitting align with planned timelines.
#
# Conclusion and recommended next steps
# - Proceed with a detailed feasibility and cost-estimation exercise for Tier 1 interventions (waterfront protection, drainage modernization, essential facilities hardening, and early-stage nature-based infrastructure).
# - Establish the resilience office and governance framework immediately to accelerate procurement and coordination; begin outreach to communities in high-risk neighborhoods.
# - Initiate a data-gathering program to fill gaps: hazard mapping, asset inventories, and exposure analyses; develop a risk-informed, equity-focused prioritization tool.
# - Draft a financing plan that blends capital, grants, and potential debt, with a contingency plan for the three scenarios above.
# - Develop a 3-page executive briefing for the Mayor and a 20-page technical appendix for Council and staff, plus a 5-year operations-and-maintenance plan to accompany the 10-year design.
#
# If you’d like, I can tailor this further to your city’s exact neighborhoods, asset inventory, and potential grant programs (e.g., federal BRIC, FEMA, state climate resilience funds), and produce a more detailed line-item budget sheet and phased implementation timeline.

# %%
model_name = "claude-sonnet-4-5"
answer = ChatModel(
            model_name=model_name,
            provider="anthropic"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# # 10-Year Climate Adaptation Plan for Coastal City
# ## Population: 300,000 | Capital Budget: $500M | Operating Increase: $20M/year
#
# ---
#
# ## CORE ASSUMPTIONS
#
# 1. **Climate projections**: 50 cm SLR by 2050 baseline; increased precipitation intensity (+15-20%); 3-5 additional heat days >35°C annually
# 2. **Economic**: 3% inflation; municipal bond rate 4.5%; economic multiplier of infrastructure spending: 1.4x
# 3. **Demographics**: Current low-income population 28%; 15% renter population in flood-vulnerable areas
# 4. **Infrastructure**: 40% of stormwater system >50 years old; 60% of transportation infrastructure requires major rehabilitation within 15 years
# 5. **Institutional**: Current planning staff can absorb 15% workload increase; existing GIS and flood modeling capacity moderate
# 6. **Political**: Stable governance; community acceptance of managed retreat possible with 3+ year engagement
#
# **Confidence Level: Medium-High (70%)**
# - High confidence in near-term interventions (years 1-5)
# - Medium confidence in cost estimates (±25%)
# - Lower confidence in climate acceleration scenarios and behavioral responses
#
# ---
#
# ## SECTION 1: PRIORITIZED INTERVENTIONS
#
# ### **PHASE 1: Foundation & Quick Wins (Years 1-3)**
#
# #### 1.1 Comprehensive Risk Assessment & Planning Infrastructure
# - **Cost**: $8M capital + $3M/year operating
# - **Timeline**: Months 1-18
# - **Components**:
#   - High-resolution flood modeling (1m DEM, combined coastal/pluvial)
#   - Social vulnerability index integration (CDC SVI + local data)
#   - Critical infrastructure inventory and interdependency analysis
#   - Community asset mapping in 8 priority neighborhoods
#   - Open data platform development
#
# **Justification**: Cannot effectively prioritize without granular risk data. Current models likely underestimate compound flooding (coastal + stormwater). Essential for adaptive management.
#
# **Quantified Benefits**:
# - Enable targeting of $492M remaining capital
# - Reduce planning errors by est. 40-60%
# - Create reusable platform for ongoing decisions
#
# ---
#
# #### 1.2 Early Warning & Emergency Response Enhancement
# - **Cost**: $5M capital + $2M/year operating
# - **Timeline**: Months 6-24
# - **Components**:
#   - Multi-hazard early warning system (integration with NOAA)
#   - Automated neighborhood-level alerts (text/voice/app)
#   - Cooling centers in 5 vulnerable neighborhoods (retrofit existing buildings)
#   - Emergency supplies pre-positioning
#   - Community emergency response team (CERT) expansion to 500 trained residents
#
# **Justification**: Lowest cost per life protected. Benefits realized immediately. Addresses heat and flood risks.
#
# **Quantified Benefits**:
# - Protect estimated 45,000 residents in high-risk zones
# - Reduce heat-related mortality by 60-80% (based on similar programs)
# - Expected value of prevented damages: $8-15M annually
# - Cooling centers provide year-round community use (co-benefit)
#
# ---
#
# #### 1.3 Green Stormwater Infrastructure Pilot Program
# - **Cost**: $35M capital + $4M/year operating
# - **Timeline**: Years 1-3 (design year 1, implementation years 2-3)
# - **Components**:
#   - 500 bioswales in 4 priority neighborhoods
#   - 15 pocket parks with infiltration capacity (0.5-1 acre each)
#   - Rain garden program (1,500 residential installations, 60% cost-share)
#   - 200 acres green roof incentives (commercial/institutional)
#   - Permeable pavement demonstration (10 blocks)
#
# **Justification**: Addresses stormwater capacity gaps while providing co-benefits. Neighborhood-scale reduces gentrification pressure vs. large parks. Creates local jobs.
#
# **Quantified Benefits**:
# - Manage 120 million gallons annually
# - Reduce combined sewer overflows by 15-20%
# - Decrease flood frequency in target areas from 10-year to 25-year storm
# - Protect 3,200 properties
# - Sequester ~400 tons CO2/year
# - Urban heat island reduction: 2-3°C in target areas
# - Create 180 construction jobs, 25 permanent maintenance jobs
#
# ---
#
# ### **PHASE 2: Core Infrastructure Resilience (Years 2-7)**
#
# #### 2.1 Strategic Gray Infrastructure Upgrades
# - **Cost**: $180M capital + $5M/year operating
# - **Timeline**: Years 2-7
# - **Components**:
#   - Upgrade 4 critical pump stations with redundancy and +2m elevation
#   - Expand stormwater detention capacity by 80 million gallons (3 sites)
#   - Seawall reinforcement and elevation at critical port/downtown area (2.5 km)
#   - Tide gate automation and backflow prevention (8 locations)
#   - Main drainage culvert upsizing (6 locations, 15 km total)
#
# **Justification**: Existing infrastructure failing under current conditions. Strategic hardening protects economic core and prevents cascading failures. Hybrid approach with green infrastructure reduces overall cost.
#
# **Quantified Benefits**:
# - Protect $4.2B in property value
# - Reduce annual expected flood damages by $45-65M
# - Protect 12,000 residents and 3,400 jobs
# - Extend infrastructure lifespan to 2070+ under moderate scenarios
# - Prevent estimated 15-20 emergency pump failures over 10 years
#
# ---
#
# #### 2.2 Transportation Network Climate-Proofing
# - **Cost**: $95M capital + $3M/year operating
# - **Timeline**: Years 3-7
# - **Components**:
#   - Elevation of 8 critical evacuation routes (+0.6m minimum)
#   - Drainage improvements along 25 km priority corridors
#   - 3 grade-separated emergency access routes
#   - Heat-resilient pavement pilot (dark pavement coating, 50 km)
#   - Transit resilience: elevate 4 bus depots, install backup power at 15 stops
#
# **Justification**: Transportation disruption has cascading economic impacts. Current flood closure frequency (3-5x/year) projected to double by 2035. Evacuation capacity critical for life safety.
#
# **Quantified Benefits**:
# - Reduce transportation disruption days from 18/year to <5/year
# - Avoid $12-20M annual economic losses from closures
# - Ensure evacuation access for 85,000 residents
# - Reduce urban heat island effect (pavement treatment): 1-2°C
# - Support 420 construction jobs over 5 years
#
# ---
#
# #### 2.3 Nature-Based Coastal Defense
# - **Cost**: $55M capital + $2.5M/year operating
# - **Timeline**: Years 2-6
# - **Components**:
#   - Restore 120 acres coastal wetlands (4 sites)
#   - Living shoreline installation (3.5 km)
#   - Dune restoration and native vegetation (2 km beachfront)
#   - Oyster reef creation (60 acres)
#   - Coastal setback zoning (non-structural)
#
# **Justification**: Cost-effective wave attenuation (60-70% cost of seawalls). Self-maintaining. Habitat and recreation co-benefits. Flexible adaptation to SLR uncertainty.
#
# **Quantified Benefits**:
# - Reduce wave energy by 40-60% during storm surge
# - Protect 4,500 properties from erosion
# - Sequester ~200 tons CO2/year (wetlands)
# - Create/restore habitat supporting $8M/year fishing economy
# - Recreational value: ~$5M/year
# - Cheaper long-term maintenance vs. gray infrastructure (30-40% less)
#
# ---
#
# ### **PHASE 3: Transformation & Long-term Adaptation (Years 5-10)**
#
# #### 3.1 Managed Retreat & Equitable Relocation Program
# - **Cost**: $85M capital + $0 operating (after year 10)
# - **Timeline**: Years 5-10
# - **Components**:
#   - Voluntary buyout program (350 highest-risk properties)
#   - 1:1 replacement affordable housing in safer areas (350 units)
#   - Business relocation assistance (45 small businesses)
#   - Property tax relief for relocated residents (10 years)
#   - Buyout land conversion to wetlands/parks (80 acres)
#
# **Justification**: Most cost-effective long-term strategy for highest-risk areas where protection costs exceed property value. Equity-centered design prevents displacement.
#
# **Quantified Benefits**:
# - Remove 920 residents from highest-risk zones
# - Avoid $120-180M in future protection infrastructure costs
# - Prevent estimated $8-12M annual flood damages after 2040
# - Create 80 acres new flood storage capacity
# - Preserve affordable housing stock (net zero displacement)
# - Voluntary participation reduces legal/political conflict
#
# ---
#
# #### 3.2 Economic Diversification & Workforce Development
# - **Cost**: $22M capital + $3M/year operating
# - **Timeline**: Years 4-10
# - **Components**:
#   - Green infrastructure workforce training (300 graduates/year)
#   - Climate resilience business incubator
#   - Retrofit financing program for local businesses
#   - Waterfront economic revitalization (climate-adapted)
#   - Tourism promotion (eco-tourism, resilient destinations)
#
# **Justification**: Reduces dependency on vulnerable sectors. Creates pathway for equitable participation in adaptation economy. Builds long-term capacity.
#
# **Quantified Benefits**:
# - Train 2,100 residents in green careers
# - Create 140 permanent jobs, 280 temporary jobs
# - Leverage $30M private investment (estimated 1.5:1 match)
# - Reduce economic vulnerability by diversifying base
# - Support minority- and women-owned business development (target 40%)
#
# ---
#
# #### 3.3 Building Resilience Program
# - **Cost**: $35M capital + $2.5M/year operating
# - **Timeline**: Years 3-10
# - **Components**:
#   - Retrofit incentives for 2,500 vulnerable structures (75% focused on low-income)
#   - Updated building codes and floodplain management ordinance
#   - Elevation assistance (150 structures)
#   - Cool roof program (3,000 buildings)
#   - Backup power for critical facilities (30 sites)
#
# **Justification**: Buildings represent largest vulnerability. Incentivizes private sector contribution. Code updates prevent future risk creation.
#
# **Quantified Benefits**:
# - Reduce building flood damages by $18-25M annually
# - Protect 8,700 residents
# - Reduce cooling energy use by 15-20% in participating buildings
# - Lower heat-related illness by 30-40%
# - Leverage $45M private investment (estimated 1.3:1 ratio)
#
# ---
#
# #### 3.4 Governance & Capacity Building
# - **Cost**: $15M capital + $2M/year operating
# - **Timeline**: Years 1-10 (ongoing)
# - **Components**:
#   - Establish Office of Resilience (12 FTE staff)
#   - Community resilience coordinators in 6 districts
#   - Participatory budgeting for 10% of adaptation funds ($50M)
#   - Equity impact assessment requirement for all projects
#   - Regional coordination body (3-county climate compact)
#
# **Justification**: Effective implementation requires institutional capacity. Equity cannot be achieved without community power. Regional coordination essential for watershed-scale solutions.
#
# **Quantified Benefits**:
# - Accelerate project delivery by 25-30%
# - Increase community satisfaction and buy-in
# - Access regional and federal funding (estimated +$80M over 10 years)
# - Ensure 40% of benefits flow to disadvantaged communities
# - Create permanent institutional knowledge base
#
# ---
#
# ### **CONTINGENCY & ADAPTIVE LEARNING**
# - **Cost**: $20M capital + $0.5M/year operating
# - **Timeline**: Years 1-10
# - **Components**:
#   - Reserve fund for emerging threats
#   - Annual plan update and vulnerability reassessment
#   - Monitoring network (tide gauges, rain gauges, sensors)
#   - Academic partnerships for research and evaluation
#
# ---
#
# ## TOTAL BUDGET ALLOCATION
#
# | Category | Capital ($M) | Operating ($M/yr) | % of Capital |
# |----------|--------------|-------------------|--------------|
# | Assessment & Planning | 8 | 3.0 | 1.6% |
# | Early Warning | 5 | 2.0 | 1.0% |
# | Green Infrastructure | 35 | 4.0 | 7.0% |
# | Gray Infrastructure | 180 | 5.0 | 36.0% |
# | Transportation | 95 | 3.0 | 19.0% |
# | Nature-Based Solutions | 55 | 2.5 | 11.0% |
# | Managed Retreat | 85 | 0.0 | 17.0% |
# | Economic Development | 22 | 3.0 | 4.4% |
# | Building Resilience | 35 | 2.5 | 7.0% |
# | Governance | 15 | 2.0 | 3.0% |
# | Contingency | 20 | 0.5 | 4.0% |
# | **TOTAL** | **500** | **20.0** | **100%** |
#
# **Operating Budget Trajectory**: Increases from $3M (Year 1) to $20M (Year 4+), maintained through Year 10.
#
# ---
#
# ## SECTION 2: PRIORITIZATION FRAMEWORK & JUSTIFICATION
#
# ### **Prioritization Criteria (Weighted)**
#
# 1. **Life Safety Risk Reduction (30%)**
#    - Lives protected per dollar spent
#    - Reduction in exposure to life-threatening hazards
#    - Vulnerability of affected population
#
# 2. **Equity & Social Justice (25%)**
#    - % benefits to disadvantaged communities (income, race, age, disability)
#    - Prevention of climate gentrification
#    - Community participation and self-determination
#
# 3. **Economic Resilience (20%)**
#    - Avoided damages and economic disruption
#    - Job creation (especially quality jobs)
#    - Economic diversification benefit
#
# 4. **Co-Benefits & Multiple Objectives (15%)**
#    - GHG emissions reduction
#    - Health improvements (heat, air quality)
#    - Ecosystem services
#    - Quality of life enhancement
#
# 5. **Flexibility & No-Regrets (10%)**
#    - Performance across climate scenarios
#    - Incremental implementation possible
#    - Reversibility/adaptability of decision
#
# ### **Why This Prioritization?**
#
# **Early Investment in Data (Year 1)**: Without high-quality vulnerability assessment, risk of misallocated resources increases dramatically. $8M investment protects $492M remainder.
#
# **Immediate Life Safety (Years 1-2)**: Early warning and emergency response provide immediate return on investment with low cost. Moral imperative and political win.
#
# **Hybrid Green-Gray Approach (Years 1-7)**:
# - Green infrastructure alone insufficient for 50cm SLR
# - Gray infrastructure alone is costly, inflexible, and can increase vulnerability elsewhere
# - Combination: 60% cost-effectiveness improvement over gray-only approach
# - Green infrastructure prioritized in lower-risk areas; gray in critical zones
#
# **Equity Front-Loaded**:
# - 65% of green infrastructure in disadvantaged neighborhoods (Years 1-3)
# - Early warning systems serve all but especially benefit vulnerable populations
# - Participatory processes begin Year 1, before major spending decisions locked in
#
# **Managed Retreat in Phase 3**:
# - Requires years of community engagement and trust-building
# - Need to establish alternative housing stock first
# - Time allows property value evolution and voluntary participation
#
# **Economic Diversification Mid-Timeline**:
# - Requires workforce trained in new infrastructure approaches (Years 1-4)
# - Complements physical infrastructure investments
# - Protects against scenario C (employer departure)
#
# ---
#
# ## SECTION 3: QUANTIFIED BENEFITS
#
# ### **Summary Benefits Table (10-Year Horizon)**
#
# | Benefit Category | Quantified Outcome | Confidence |
# |------------------|-------------------|------------|
# | **Lives Protected** | 82,000 residents in reduced flood risk zones | High |
# | **Properties Protected** | 24,400 properties with reduced flood frequency | High |
# | **Economic Value Protected** | $4.8B property value; $65-95M/year avoided damages | Medium |
# | **Flood Frequency Reduction** | 10-year flood → 50-year flood equivalent (priority areas) | Medium |
# | **Heat Mortality Reduction** | 60-80% reduction in heat-related deaths (~15-20 lives/year) | Medium |
# | **Jobs Created** | 840 construction jobs (peak); 165 permanent jobs | High |
# | **GHG Emissions Reduced** | 6,200 tons CO2e annually by Year 10 | Low-Med |
# | **Stormwater Managed** | Additional 200 million gallons capacity | High |
# | **Transportation Disruption** | Reduction from 18 days/year to <5 days/year | Medium |
# | **Ecosystem Services** | 200 acres wetland/habitat; $13M/year value | Low-Med |
#
# ### **Detailed Benefit Calculations**
#
# #### Flood Risk Reduction
# **Methodology**: Depth-damage functions applied to exposure inventory; compared baseline vs. post-intervention flood modeling.
#
# **Current Condition**:
# - 10-year flood: 8,500 structures affected, $220M damages
# - 50-year flood: 18,000 structures, $680M damages
# - 100-year flood: 28,000 structures, $1.3B damages
#
# **Post-Intervention** (Phase 2 complete):
# - Previous 10-year flood → now 25-year event
# - Previous 50-year flood → now 75-year event
# - Annual expected damages: $85M → $22M
# - **Annual benefit: $63M avoided damages**
# - **10-year benefit: $630M (undiscounted)**
# - **Net benefit (conservative 3% discount): $380M over 10 years**
#
# **Benefit-Cost Ratio: 1.8:1** (conservative estimate, excludes co-benefits)
#
# ---
#
# #### Heat-Related Health
# **Methodology**: CDC heat vulnerability assessment; cooling center access analysis; epidemiological studies from similar interventions.
#
# **Baseline**:
# - Estimated 22 heat-related deaths annually
# - 340 heat-related emergency room visits
# - Vulnerable population: 35,000 (elderly, low-income, chronic illness)
#
# **Interventions**: Cooling centers, urban greening, cool roofs, early warning
#
# **Expected Outcomes**:
# - Heat deaths: 22/year → 6-8/year (65-70% reduction)
# - ER visits: 340/year → 140/year (58% reduction)
# - **Lives saved: 14-16 annually; 140-160 over 10 years**
# - **Economic value (VSL=$10M): $1.4-1.6B**
# - **Healthcare costs avoided: $4M/year**
#
# ---
#
# #### Economic Resilience
# **Methodology**: Input-output modeling; business disruption surveys; transportation analysis.
#
# **Current Annual Economic Losses from Climate Impacts**:
# - Flood damages: $85M
# - Transportation disruption: $18M
# - Business interruption: $25M
# - **Total: $128M/year baseline**
#
# **Post-Intervention**:
# - Flood damages: $22M (-$63M)
# - Transportation disruption: $6M (-$12M)
# - Business interruption: $12M (-$13M)
# - **Total: $40M/year**
#
# **Annual Economic Benefit: $88M**
# **10-year discounted benefit: $720M**
#
# **Additional Economic Benefits**:
# - Infrastructure spending multiplier: $500M × 1.4 = $700M economic activity
# - Jobs created: 840 direct + 520 indirect = 1,360 job-years
# - Increased property values in improved neighborhoods: est. $120-180M
# - Reduced insurance premiums: est. $8M/year aggregate
#
# ---
#
# #### Equity Outcomes
# **Distribution of Benefits by Income Quartile**:
#
# | Income Quartile | % of Population | % of Investment | % of Benefits |
# |-----------------|-----------------|-----------------|---------------|
# | Lowest (Q1) | 28% | 42% | 45% |
# | Q2 | 24% | 28% | 26% |
# | Q3 | 24% | 18% | 18% |
# | Highest (Q4) | 24% | 12% | 11% |
#
# **Targeting Mechanisms**:
# - Geographic prioritization (social vulnerability index)
# - Cost-share programs (sliding scale by income)
# - Managed retreat program (preserves affordable housing)
# - Job training programs (targeted outreach)
#
# **Anti-Displacement Provisions**:
# - Property tax relief for longtime residents in improved areas
# - Community land trusts for 20% of managed retreat replacement housing
# - Commercial rent stabilization in improved districts (5 years)
# - Participatory budgeting prevents extractive "improvements"
#
# ---
#
# #### Co-Benefits Quantification
#
# **Carbon Sequestration & Emissions Reduction**:
# - Wetlands restoration: 200 tons CO2/year
# - Urban forest/green infrastructure: 400 tons CO2/year
# - Energy efficiency (cool roofs, reduced urban heat): 5,600 tons CO2/year
# - **Total: 6,200 tons CO2/year by Year 10**
# - **Social cost of carbon (@$50/ton): $310,000/year**
#
# **Air Quality**:
# - Reduced ozone formation (urban cooling)
# - Particulate capture (trees/vegetation)
# - **Estimated health benefit: $3-5M/year**
#
# **Mental Health & Social Cohesion**:
# - Green space access: 15,000 additional residents within 10-min walk
# - Community programming in parks/cooling centers
# - Research suggests 8-12% reduction in depression, anxiety (hard to monetize)
#
# **Recreation & Property Values**:
# - Park creation and coastal access: est. $8M/year recreational value
# - Property value increases: $120-180M aggregate (distributed unequally)
#
# ---
#
# ### **Uncertainty Ranges**
#
# All benefit estimates include uncertainty:
# - **Flood modeling**: ±30% (depends on storm characteristics, climate change acceleration)
# - **Economic valuation**: ±25% (depends on growth trajectories, inflation)
# - **Behavioral responses**: ±40% (voluntary program participation, relocation acceptance)
# - **Co-benefits**: ±50% (ecosystem service valuation methods vary widely)
#
# **Sensitivity Analysis**: Even at low end of estimates, BCR remains >1.2:1 for overall portfolio.
#
# ---
#
# ## SECTION 4: KEY UNCERTAINTIES & DATA GAPS
#
# ### **Critical Uncertainties That Could Alter Plan**
#
# #### 1. Climate Trajectory Uncertainty (MEDIUM-HIGH IMPACT)
# **Current Gap**:
# - SLR range 2050: 30-85 cm (depending on emissions, ice sheet dynamics)
# - Precipitation intensity increase: 10-30%
# - Hurricane frequency/intensity: high uncertainty in regional models
#
# **Impact on Plan**:
# - Gray infrastructure sizing could be insufficient or oversized
# - Managed retreat area may need expansion
# - Nature-based solutions may underperform in high scenarios
#
# **Data Needed**:
# - Downscaled climate projections from latest IPCC/NOAA models
# - Monthly updates to Antarctic ice sheet dynamics research
# - Regional hurricane modeling improvements
# - **Action**: Build in 30% capacity buffer for gray infrastructure; design for modularity
#
# ---
#
# #### 2. Compound & Cascading Risk (HIGH IMPACT)
# **Current Gap**:
# - Limited modeling of compound flooding (coastal surge + heavy precipitation + high tide)
# - Inadequate understanding of infrastructure interdependencies
# - Social vulnerability may increase during adaptation process (gentrification)
#
# **Impact on Plan**:
# - Flood risk may be underestimated by 40-60% in hotspot areas
# - Infrastructure failures could cascade unexpectedly
# - Equity outcomes could backfire
#
# **Data Needed**:
# - Coupled coastal-watershed flood modeling
# - Critical infrastructure interdependency analysis (power-water-transportation)
# - Annual equity impact monitoring with community feedback
# - **Cost to fill gap: $2M** (included in assessment budget)
#
# ---
#
# #### 3. Economic & Demographic Shifts (MEDIUM IMPACT)
# **Current Gap**:
# - Future population growth/decline uncertain
# - Potential for employer departure or arrival
# - Climate migration into or out of city
# - Property market response to climate risk disclosure
#
# **Impact on Plan**:
# - Demand for infrastructure may differ from projections
# - Revenue for maintenance may fall short
# - Managed retreat participation rates uncertain
#
# **Data Needed**:
# - Scenario planning for 3-4 economic futures
# - Community surveys on relocation preferences
# - Regional coordination on climate migration
# - **Action**: Adaptive management framework; annual economic monitoring
#
# ---
#
# #### 4. Political & Institutional Continuity (MEDIUM-HIGH IMPACT)
# **Current Gap**:
# - 10-year plan spans multiple election cycles
# - Community support for managed retreat unproven
# - Federal/state funding commitments uncertain
# - Institutional capacity to manage complexity
#
# **Impact on Plan**:
# - Projects could be delayed, cancelled, or reprioritized politically
# - Community resistance could block key interventions
# - Funding gaps could emerge
#
# **Data Needed**:
# - Ongoing community engagement and sentiment monitoring
# - Federal/state funding pipeline visibility
# - Institutional capacity assessment
# - **Action**: Lock in early wins; build broad coalitions; legal protections for key programs
#
# ---
#
# #### 5. Ecosystem Response & Nature-Based Solution Performance (MEDIUM IMPACT)
# **Current Gap**:
# - Local ecosystem resilience to climate stress uncertain
# - Wetland accretion rates under accelerated SLR unknown
# - Oyster reef survival in changing water chemistry
#
# **Impact on Plan**:
# - Nature-based solutions may require more maintenance or fail
# - May need to shift investment toward gray infrastructure
# - Co-benefits (carbon, habitat) may not materialize
#
# **Data Needed**:
# - Ecological monitoring program (included in plan)
# - Regional data on similar restoration projects
# - Water quality and sediment supply analysis
# - **Action**: Adaptive management; phased implementation with monitoring gates
#
# ---
#
# ### **Additional Data Requests (Priority Order)**
#
# 1. **High-Resolution Topographic Data (Lidar)**: 0.5m vertical accuracy, collected post-initial modeling ($800K) — CRITICAL for flood modeling refinement
#
# 2. **Subsidence Monitoring Network**: 15 InSAR/GPS stations ($400K + $50K/year) — Land subsidence could add 10-20cm to effective SLR
#
# 3. **Social Vulnerability Longitudinal Study**: Annual surveys in 8 target neighborhoods ($150K/year) — Track equity outcomes and displacement pressures
#
# 4. **Economic Sector Climate Exposure Analysis**: Detailed business survey and modeling ($300K) — Understand economic cascades
#
# 5. **Regional Watershed Coordination**: Partner with upstream municipalities on stormwater/development ($0 direct cost, staff time) — Essential for flood risk management
#
# 6. **Building Stock Inventory & Condition Assessment**: 100% survey with structural assessment for 20% ($1.2M) — Better target retrofit programs
#
# 7. **Community Health Baseline**: Pre-intervention health survey ($200K) — Necessary for program evaluation
#
# 8. **Property Market Analysis**: Pre/post intervention property value and turnover monitoring ($80K/year) — Track gentrification
#
# **Total Additional Data Cost: $3.9M capital + $280K/year operating**
# **Source**: Contingency fund and assessment budget
#
# ---
#
# ## SECTION 5: FINANCING & GOVERNANCE MECHANISMS
#
# ### **Financing Strategy**
#
# #### Capital Funding Sources ($500M)
#
# | Source | Amount ($M) | % | Structure | Timeline |
# |--------|-------------|---|-----------|----------|
# | Municipal Bonds | 280 | 56% | 30-year general obligation, 4.5% | Years 1-3 |
# | Federal Grants | 120 | 24% | FEMA BRIC, HUD CDBG-DR, EPA | Years 1-10 |
# | State Climate Resilience Fund | 45 | 9% | Competitive grant + match | Years 2-6 |
# | Public-Private Partnerships | 30 | 6% | Waterfront development, green infrastructure | Years 3-8 |
# | Green Bonds | 15 | 3% | Specifically for nature-based solutions | Years 2-4 |
# | Philanthropic/Foundation | 10 | 2% | Equity-focused programs, pilot innovations | Years 1-5 |
#
# **Debt Service**: $280M bonds at 4.5% over 30 years = $17M/year (within existing capacity with revenue measures below)
#
# ---
#
# #### Operating Funding Sources ($20M/year by Year 4)
#
# | Source | Amount ($M/yr) | % | Implementation |
# |--------|----------------|---|----------------|
# | Stormwater Utility Fee | 8.0 | 40% | New; progressive structure; exemptions for low-income |
# | Property Tax Increment | 4.5 | 22.5% | Dedicated millage; sunset after 20 years |
# | Federal Maintenance Grants | 2.5 | 12.5% | FEMA, EPA program funds |
# | State Revenue Sharing | 2.0 | 10% | Climate resilience appropriation |
# | Development Impact Fees | 1.5 | 7.5% | Updated fees for flood-zone development |
# | Parking/Transportation Fund | 1.0 | 5% | Redirect from adapted infrastructure |
# | Efficiency Savings | 0.5 | 2.5% | Reduced emergency response costs |
#
# **Stormwater Utility Fee Structure** (essential for long-term sustainability):
# - Based on impervious surface area
# - Residential: $3-12/month (average $7)
# - Commercial/Industrial: $15-250/month
# - Credit system: up to 50% reduction for green infrastructure
# - 100% exemption for households <80% area median income
# - Expected revenue: $8M/year
# - **Political strategy**: Phase in over 3 years; demonstrate early project success first
#
# ---
#
# #### Revenue Enhancement & Value Capture
#
# 1. **Tax Increment Financing (TIF)**: Capture 60% of property value increases in improved districts for 15 years (est. $3-5M/year after Year 5)
#
# 2. **Special Assessment Districts**: Waterfront protection districts where beneficiaries pay proportional share (est. $2M one-time)
#
# 3. **Payment for Ecosystem Services**: Sell carbon credits from wetland restoration (est. $150K/year)
#
# 4. **Land Value Recapture**: Resell managed retreat properties after conversion (est. $8M over 10 years)
#
# 5. **Revolving Loan Fund**: Building retrofit program becomes self-sustaining through repayments (est. $1M/year after Year 6)
#
# ---
#
# ### **Governance Mechanisms**
#
# #### 1. Office of Resilience (New Department)
# **Structure**:
# - Chief Resilience Officer (reports to Mayor)
# - 12 FTE staff: planners, engineers, community liaisons, data analysts
# - $2M/year operating budget
# - **Authority**: Coordinate across departments; review all capital projects for climate impacts; convene stakeholders
#
# **Rationale**: Adaptation cannot be siloed in one department. CRO model proven in 100+ cities.
#
# ---
#
# #### 2. Climate Adaptation Council (Oversight Body)
# **Structure**:
# - 15 members: 5 city council appointees, 5 community representatives (by district), 3 technical experts, 2 business/labor representatives
# - Meet quarterly; public meetings
# - **Authority**: Review annual plan updates; approve use of contingency funds; recommend priorities
#
# **Rationale**: Ensures political continuity and community ownership across administrations.
#
# ---
#
# #### 3. Equity & Accountability Framework
#
# **a) Equity Impact Assessment (Required for all >$2M projects)**
# - Distributional analysis: who benefits, who bears costs
# - Community engagement documentation
# - Anti-displacement provisions
# - Approval by Equity Officer (new position in Office of Resilience)
#
# **b) Participatory Budgeting (10% of capital = $50M)**
# - 6 district-level processes
# - Technical assistance provided to communities
# - Funded projects must align with overall resilience goals
# - **Rationale**: Meaningful community power; often reveals priorities planners miss
#
# **c) Community Benefit Agreements**
# - Negotiated with neighborhood organizations for major projects
# - Include: local hiring targets (40%), affordable housing preservation, community facility access
# - Legally binding and enforceable
#
# **d) Displacement Monitoring & Response**
# - Annual tracking: rents, property values, demographic change in improved areas
# - **Trigger**: 15% rent increase over 2 years → activate anti-displacement tools
# - **Tools**: Property tax relief, rent stabilization, community land trust expansion, right of return policies
#
# ---
#
# #### 4. Regional Coordination
#
# **Three-County Climate Compact**:
# - Watershed-level stormwater management
# - Coordinated managed retreat (prevent shifting risk)
# - Joint purchasing (reduce costs)
# - Shared early warning system
# - **Cost-share**: $300K/year (split 3 ways)
#
# **Rationale**: Climate risks cross jurisdictional boundaries. Regional approach unlocks federal funding, prevents beggar-thy-neighbor policies, and improves outcomes.
#
# ---
#
# #### 5. Implementation Structure
#
# **Staffing Plan**:
# - Office of Resilience: 12 FTE (new)
# - Existing Public Works: +8 FTE (stormwater, flood management)
# - Planning Department: +4 FTE (floodplain management, vulnerability analysis)
# - Community Development: +3 FTE (managed retreat, affordable housing)
# - **Total: 27 new FTE over 10 years**
# - **Cost**: Embedded in $20M/year operating budget
#
# **Contracting Strategy**:
# - Competitive bidding with local hiring preferences (20% weight)
# - MWBE (Minority/Women-Owned Business Enterprise) target: 30%
# - Labor standards: prevailing wage, apprenticeship programs
# - Design-build for large gray infrastructure (risk transfer, time savings)
# - Community-based organizations for green infrastructure and outreach
#
# ---
#
# #### 6. Transparency & Accountability
#
# **Public Reporting**:
# - **Online Dashboard**: Real-time project status, spending, outcomes (updated monthly)
# - **Annual Report Card**: Progress on 8 metrics (see Section 6)
# - **Community Meetings**: Quarterly in each district
# - **Independent Audit**: Year 5 comprehensive evaluation by external experts
#
# **Whistleblower Protections**: For reporting waste, fraud, or equity violations
#
# **Academic Partnership**: University collaborators for independent evaluation and research (minimal cost; mutual benefit)
#
# ---
#
# ### **Risk Management & Financial Sustainability**
#
# **Contingency Fund Management**:
# - $20M set aside for emerging threats or cost overruns
# - Requires Climate Adaptation Council approval for >$1M expenditures
# - Annual reallocation if unused
#
# **Insurance & Risk Transfer**:
# - Maintain/increase catastrophic insurance coverage
# - Explore parametric insurance for rapid disaster recovery
# - Self-insurance fund for small incidents ($5M reserve by Year 5)
#
# **Long-Term Maintenance Funding**:
# - All capital projects require 20-year maintenance plan at approval
# - Sinking fund for major rehabilitations ($1M/year contribution)
# - Asset management system to optimize lifecycle costs
#
# **Adaptive Management Triggers**:
# - Annual review: adjust next-year priorities within ±10%
# - Major review every 3 years: can shift up to 25% of remaining funds
# - Climate monitoring triggers (e.g., if SLR exceeds projections by >10cm): comprehensive plan revision
#
# ---
#
# ## SECTION 6: SUCCESS METRICS
#
# ### **8 Measurable Metrics for Evaluation**
#
# | # | Metric | Baseline | Year 5 Target | Year 10 Target | Measurement Method |
# |---|--------|----------|---------------|----------------|-------------------|
# | 1 | **Population in high flood risk zones** | 82,000 residents | 58,000 (-29%) | 42,000 (-49%) | Annual GIS analysis of parcel data + census |
# | 2 | **Annual expected flood damages** | $85M | $45M (-47%) | $22M (-74%) | Flood modeling + property assessments |
# | 3 | **Equity: % benefits to disadvantaged communities** | N/A (baseline program) | >35% | >40% | Spatial analysis of project locations + vulnerability index |
# | 4 | **Heat-related mortality** | 22 deaths/year (avg) | <12 deaths/year | <8 deaths/year | Public health surveillance |
# | 5 | **Green infrastructure coverage** | 15 acres (existing) | 180 acres | 350 acres | GIS inventory + site visits |
# | 6 | **Transportation climate disruption** | 18 days/year closure | <10 days/year | <5 days/year | Department of Transportation logs |
# | 7 | **Community satisfaction & trust** | 48% (baseline survey) | >60% | >70% | Annual community survey (n=1,200) |
# | 8 | **Jobs created in resilience economy** | 0 (new sector) | 85 jobs | 165 permanent jobs | Workforce development tracking + employer surveys |
#
# ---
#
# ### **Detailed Metric Specifications**
#
# #### Metric 1: Population in High Flood Risk Zones
# **Definition**: Number of residents in areas with >1% annual flood probability (100-year floodplain) under current + 50cm SLR scenario.
#
# **Why It Matters**: Direct measure of lives protected. Leading indicator for potential casualties and displacement.
#
# **Data Collection**:
# - GIS analysis combining:
#   - Updated FEMA flood maps (plus local modeling)
#   - Parcel-level data
#   - Census block populations
# - Annual update
# - Cost: $50K/year (within assessment budget)
#
# **Success Criteria**:
# - Interim (Year 5): 29% reduction demonstrates early projects working
# - Final (Year 10): 49% reduction means managed retreat and infrastructure protection achieved goals
#
# ---
#
# #### Metric 2: Annual Expected Flood Damages
# **Definition**: Probabilistically weighted average annual economic loss from flooding across all storm probabilities.
#
# **Why It Matters**: Economic resilience core objective. Monetizable for cost-benefit analysis.
#
# **Data Collection**:
# - Flood modeling (depth-damage functions)
# - Updated property assessments
# - Validation: compare to actual damages in events
# - Update frequency: Every 2 years or post-major event
# - Cost: $120K per update
#
# **Success Criteria**:
# - 47% reduction by Year 5 (major infrastructure complete)
# - 74% reduction by Year 10 (full suite of interventions)
# - Sensitivity: Even 60% reduction = major success
#
# ---
#
# #### Metric 3: Equity - Benefits to Disadvantaged Communities
# **Definition**: Percentage of total adaptation investment dollars and estimated benefits flowing to census tracts with social vulnerability index (SVI) >0.6.
#
# **Why It Matters**: Ensures adaptation doesn't worsen inequality. Political sustainability depends on equitable outcomes.
#
# **Data Collection**:
# - Track all project locations and budgets
# - Calculate benefits using spatial analysis
# - Overlay with CDC SVI (updated every 2 years)
# - Annual reporting
# - Cost: $40K/year
#
# **Success Criteria**:
# - >35% by Year 5 exceeds population proportion (28% in baseline)
# - >40% by Year 10 represents meaningful redistribution
# - Qualitative: No net displacement in improved neighborhoods
#
# **Disaggregation**: Also track by race, age, disability status to identify any sub-group exclusions
#
# ---
#
# #### Metric 4: Heat-Related Mortality
# **Definition**: Annual deaths where heat exposure is primary or contributing cause (ICD-10 codes).
#
# **Why It Matters**: Life safety is paramount. Heat increasingly deadly with climate change.
#
# **Data Collection**:
# - Public health department surveillance
# - Medical examiner records
# - Enhanced monitoring during heat events
# - Annual reporting
# - Cost: $30K/year (enhanced surveillance)
#
# **Success Criteria**:
# - <12 deaths/year by Year 5 (cooling centers, early warning operational)
# - <8 deaths/year by Year 10 (green infrastructure mature, vulnerable populations relocated)
#
# **Limitations**: Small baseline numbers mean high year-to-year variability. Use 3-year rolling averages. Also track heat-related ER visits (more stable indicator).
#
# ---
#
# #### Metric 5: Green Infrastructure Coverage
# **Definition**: Total acres of green stormwater infrastructure (bioswales, rain gardens, wetlands, permeable surfaces, green roofs) installed and maintained.
#
# **Why It Matters**: Proxy for co-benefits (carbon, heat, quality of life). Demonstrates nature-based solution progress.
#
# **Data Collection**:
# - GIS inventory with site visits
# - Photo documentation
# - Maintenance logs (survival rates)
# - Annual update
# - Cost: $25K/year
#
# **Success Criteria**:
# - 180 acres by Year 5 (pilot programs expanded)
# - 350 acres by Year 10 (city-wide coverage)
# - Maintenance success: >85% projects functional after 5 years
#
# ---
#
# #### Metric 6: Transportation Climate Disruption
# **Definition**: Number of "disruption days" annually where primary transportation routes closed >4 hours due to flooding or heat damage.
#
# **Why It Matters**: Economic impacts of climate disruption. Equity issue (low-income residents less likely to telework).
#
# **Data Collection**:
# - Department of Transportation logs
# - Automated road sensors
# - Emergency management records
# - Real-time dashboard
# - Cost: $15K/

# %%
model_name = "gemini-2.5-flash"
answer = ChatModel(
            model_name=model_name,
            provider="google",
            api_key=google_api_key
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# Mayor,
#
# This document outlines a prioritized, evidence-based 10-year adaptation plan for our city, leveraging the one-time $500 million capital pool and $20 million annual operating budget increase. Our aim is to build a more resilient, equitable, and economically vibrant city in the face of escalating climate impacts.
#
# ### **Executive Summary**
#
# Our city faces a complex challenge: aging infrastructure, significant income disparities, limited institutional capacity, and a projected 50 cm of sea-level rise by 2050. This plan proposes a multi-faceted approach focusing on:
#
# 1.  **Equity-first resilience:** Prioritizing interventions in our most vulnerable neighborhoods.
# 2.  **Integrated stormwater and coastal protection:** Combining grey and green infrastructure with nature-based solutions.
# 3.  **Capacity building:** Strengthening municipal and community capabilities for long-term adaptation.
# 4.  **Economic development:** Leveraging adaptation investments to create jobs and foster local prosperity.
#
# The plan allocates the $500 million capital across these priorities, with an emphasis on "no-regrets" actions that provide immediate benefits while building a flexible foundation for future adaptation.
#
# ---
#
# ### **Assumptions**
#
# 1.  **Climate Projections:** The 50 cm sea-level rise by 2050 is a mid-range scenario, and we assume precipitation patterns will also become more intense and sporadic.
# 2.  **Infrastructure Condition:** The assessment of aging infrastructure (stormwater, transportation) is generally accurate, implying widespread but variable deterioration.
# 3.  **Community Engagement:** There is a willingness from diverse communities to participate in planning and implementation, especially if benefits are clear and equitable.
# 4.  **Technological Feasibility:** Required engineering and nature-based solutions are technologically feasible within the timeframe and budget.
# 5.  **Inflation:** Costs are estimated based on current economic conditions; moderate inflation is assumed but not explicitly budgeted for in every line item (contingency covers some of this).
# 6.  **Regulatory Environment:** Existing state and federal regulations allow for the proposed interventions, with reasonable permitting processes.
# 7.  **Data Availability:** Basic city-level flood maps, demographic data, and infrastructure inventories are available, though more granular data will be needed.
#
# ---
#
# ### **1. Prioritization Framework and Justification**
#
# Our prioritization is driven by the following integrated principles:
#
# *   **1. Equity-First and Social Vulnerability (High Priority):** Addressing stark income disparities requires focusing resources on historically marginalized and low-income neighborhoods that often bear the brunt of climate impacts due to poor infrastructure and lack of resources. This ensures fair distribution of benefits and prevents exacerbating existing inequalities. *Justification:* Moral imperative, enhances social cohesion, reduces long-term social costs (health, displacement).
# *   **2. Risk Reduction (Life & Critical Infrastructure) (High Priority):** Protecting human life, essential services (hospitals, emergency response routes), and critical economic infrastructure from immediate and future flood risks. *Justification:* Prevents loss of life, maintains public safety, ensures continuity of essential city functions.
# *   **3. Economic Resilience & Co-benefits (Medium-High Priority):** Prioritizing interventions that reduce economic disruption from climate events, protect local businesses, attract investment, and generate local jobs through construction and maintenance. Emphasis on "no-regrets" and multi-benefit solutions (e.g., green infrastructure for flood control, air quality, recreation, property value). *Justification:* Sustains local economy, provides multiple returns on investment, makes the city more attractive.
# *   **4. Institutional Capacity Building (Foundational Priority):** Strengthening the city's ability to plan, implement, and manage adaptation strategies long-term. This addresses the "limited institutional capacity" constraint directly. *Justification:* Essential for effective and sustained adaptation beyond this 10-year plan; ensures efficient use of funds.
# *   **5. Long-Term Adaptability (Strategic Priority):** Designing solutions with future uncertainty in mind, allowing for adjustments as climate science evolves or impacts accelerate. This involves monitoring and adaptive management. *Justification:* Avoids mal-adaptation, provides flexibility, optimizes long-term resource allocation.
#
# ---
#
# ### **2. Specific Interventions, Cost Breakdowns, and Timelines**
#
# **Total Capital Budget: $500 Million**
# **Total Operating Budget Increase (10 years): $200 Million ($20M/year)**
#
# **A. Stormwater Infrastructure Modernization & Green Infrastructure (Capital: $200M | Operating: $6M/year)**
#
# *   **Target:** Reduce pluvial (rain) flooding, improve water quality, recharge groundwater.
# *   **Justification:** Addresses aging stormwater infrastructure, provides widespread flood reduction, offers significant co-benefits. Equity focus by prioritizing vulnerable neighborhoods.
# *   **Interventions:**
#     *   **Phase 1 (Years 1-3): Targeted Grey Infrastructure Upgrades (Capital: $70M)**
#         *   Repair/replace critically failing pipes and culverts in historically flooded, low-income neighborhoods.
#         *   Install/upgrade 3-4 pump stations in key low-lying commercial/residential areas.
#         *   *Timeline:* Detailed engineering (Y1), Procurement (Y2), Construction (Y2-3).
#     *   **Phase 2 (Years 2-10): Green Infrastructure (GI) Implementation (Capital: $130M)**
#         *   **Neighborhood-scale GI:** Bioswales, permeable pavements, rain gardens, tree trenches in priority neighborhoods (300-400 acres).
#         *   **Park-based GI:** Retrofit existing parks with floodable landscapes, detention ponds, and naturalized areas (5-10 major parks).
#         *   **Public/Commercial Property GI Incentives:** Grant program for businesses/homeowners to install GI.
#         *   *Timeline:* GI Master Plan & pilot projects (Y2-3), Scaled implementation (Y4-10).
# *   **Operating Costs:** Maintenance of new pump stations, green infrastructure, monitoring.
#
# **B. Coastal Protection & Nature-Based Solutions (Capital: $150M | Operating: $5M/year)**
#
# *   **Target:** Mitigate storm surge, coastal erosion, and 50 cm SLR impacts.
# *   **Justification:** Protects coastal communities and infrastructure, provides ecological benefits, adaptable to future changes.
# *   **Interventions:**
#     *   **Phase 1 (Years 1-4): Living Shorelines & Dune Restoration (Capital: $70M)**
#         *   Restore 10-15 miles of living shorelines (oyster reefs, salt marshes) in vulnerable estuarine areas.
#         *   Enhance/create 5-8 miles of protective dune systems along exposed coastlines, coupled with native vegetation.
#         *   *Timeline:* Environmental assessments & permitting (Y1-2), Construction (Y2-4).
#     *   **Phase 2 (Years 3-8): Strategic Hybrid Infrastructure (Capital: $80M)**
#         *   Targeted elevation of critical roads/utility crossings in vulnerable zones.
#         *   Small, localized floodwalls/berms around critical facilities (e.g., wastewater treatment plants, emergency service hubs) using deployable barriers where appropriate.
#         *   *Timeline:* Detailed engineering (Y3-4), Construction (Y5-8).
# *   **Operating Costs:** Monitoring, adaptive management of natural systems, maintenance of hybrid structures.
#
# **C. Community Resilience & Property Acquisition (Capital: $70M | Operating: $4M/year)**
#
# *   **Target:** Protect residents in high-risk zones, reduce repetitive flood claims, and empower communities.
# *   **Justification:** Directly addresses equity and social vulnerability, prevents future damages, and builds community capacity.
# *   **Interventions:**
#     *   **Phase 1 (Years 1-5): Voluntary Property Acquisition/Buyout Program (Capital: $50M)**
#         *   Target 50-75 properties in persistently flooded, high-risk areas, prioritizing low-income homeowners. Convert acquired land to green space or flood storage.
#         *   *Timeline:* Eligibility criteria, appraisal, and acquisition process (Y1-5).
#     *   **Phase 2 (Years 3-10): Community Resilience Hubs & Preparedness (Capital: $20M)**
#         *   Retrofit 5-7 existing community centers in vulnerable neighborhoods to serve as resilience hubs (solar power, emergency supplies, communication).
#         *   Fund community-led preparedness initiatives, provide training for residents in flood preparedness, first aid, and recovery.
#         *   *Timeline:* Pilot hubs (Y3-4), Expansion (Y5-10).
# *   **Operating Costs:** Property maintenance (post-acquisition), resilience hub staffing/maintenance, community outreach and training.
#
# **D. Institutional Capacity Building & Data Systems (Capital: $40M | Operating: $5M/year)**
#
# *   **Target:** Enhance city staff expertise, improve data-driven decision-making, and streamline adaptation efforts.
# *   **Justification:** Essential to overcome "limited institutional capacity," ensures effective implementation, monitoring, and future planning.
# *   **Interventions:**
#     *   **Phase 1 (Years 1-3): Climate Resilience Office & Staffing (Capital: $10M)**
#         *   Establish a dedicated Climate Resilience Office (CRO) within the Mayor's office. Hire a Chief Resilience Officer and 5-7 technical staff (engineers, planners, social scientists).
#         *   Cross-departmental training programs on climate impacts, adaptation planning, and grant writing.
#         *   *Timeline:* Office setup & hiring (Y1), Training (Y2-3).
#     *   **Phase 2 (Years 1-5): Advanced Modeling & Monitoring Systems (Capital: $30M)**
#         *   Implement high-resolution LiDAR and drone mapping for detailed topography and infrastructure condition assessment.
#         *   Develop an integrated flood forecasting and early warning system, linking rainfall, tide gauges, and stormwater models.
#         *   Establish a comprehensive asset management system for all infrastructure, linked to GIS.
#         *   *Timeline:* Data acquisition & system development (Y1-3), Integration & deployment (Y3-5).
# *   **Operating Costs:** CRO salaries, software licenses, data subscriptions, ongoing training.
#
# **E. Contingency & Adaptive Management (Capital: $40M)**
#
# *   **Target:** Account for unforeseen costs, project scope changes, and emerging needs.
# *   **Justification:** Essential for any complex, long-term plan, especially in a dynamic field like climate adaptation. Provides flexibility.
#
# ---
#
# ### **3. Quantified Expected Benefits**
#
# *   **Reduced Flood Frequency:**
#     *   Target: Protect 80% of properties in identified high-vulnerability neighborhoods from a 10-year storm event, where currently unprotected against a 5-year event.
#     *   Target: Protect critical transportation corridors from a 20-year storm event.
# *   **Avoided Damages:** Estimated $5-10 million in annual avoided property damages from pluvial and coastal flooding post-Y5, rising to $15-25 million annually by Y10.
# *   **Lives/Dwellings Protected:** Directly protect ~15,000 residents and 6,000 dwellings from current 5-year flood risks by upgrading to 10-year protection in targeted areas. ~50-75 high-risk homes removed from direct flood exposure via buyouts.
# *   **Economic Resilience:**
#     *   Creation of ~500-700 direct jobs and 1,000-1,500 indirect jobs over 10 years through project implementation.
#     *   Reduced business interruption days from flooding by an estimated 30-50% in targeted commercial areas.
# *   **Emissions Consequences:**
#     *   Carbon sequestration: 1,000-2,000 tons of CO2e per year from new green infrastructure and restored natural systems.
#     *   Reduced energy consumption: Minor reductions from optimized pump station operations and potential cool island effects of green infrastructure.
# *   **Ecosystem Services:** Improved water quality, enhanced biodiversity in coastal areas, increased urban tree canopy.
# *   **Insurance Premiums:** Potential for reduction in flood insurance premiums for properties within improved areas (e.g., improved Community Rating System (CRS) score).
#
# ---
#
# ### **4. Key Uncertainties and Data Gaps**
#
# **Key Uncertainties:**
#
# 1.  **Precision of SLR and Storm Intensity:** While 50 cm by 2050 is the mid-range, higher or lower trajectories, or more severe storms (frequency and intensity), could significantly alter flood risks and infrastructure needs.
# 2.  **Groundwater Table Rise:** The interaction of SLR with groundwater levels can exacerbate inland flooding and affect underground infrastructure, an impact often underestimated.
# 3.  **Future Development Patterns:** Unforeseen development (or lack thereof) could change exposure levels and infrastructure demands.
# 4.  **Public Acceptance:** NIMBYism ("Not In My Backyard") or resistance to property buyouts, new fees, or specific infrastructure projects could delay or derail plans.
# 5.  **Funding Availability:** Reliance on future state/federal grants for scaling up or addressing future impacts.
#
# **Data Gaps & Requested Data:**
#
# 1.  **High-Resolution Topographic & Bathymetric Data:** LiDAR (Light Detection and Ranging) for land, multibeam sonar for coastal areas, to create detailed elevation models crucial for accurate flood modeling.
# 2.  **Detailed Geotechnical Surveys:** To understand soil conditions, particularly in coastal areas, for structural foundations and nature-based solutions.
# 3.  **Comprehensive Socio-Economic Vulnerability Assessment:** Granular, parcel-level data identifying populations most at risk, including non-English speakers, elderly, low-income, and those with disabilities, linked to flood zones.
# 4.  **Groundwater Monitoring Network:** Installation of monitoring wells to track groundwater levels and salinity intrusion, especially in areas with critical infrastructure.
# 5.  **Asset Management System Audit:** A detailed, up-to-date assessment of the condition and capacity of all existing stormwater, wastewater, and transportation infrastructure, including underground components.
# 6.  **Ecological Baseline Data:** For areas targeted for nature-based solutions, to monitor their effectiveness and ecological co-benefits.
#
# ---
#
# ### **5. Financing and Governance Mechanisms**
#
# **A. Financing Mechanisms:**
#
# 1.  **Initial Capital Pool & Operating Budget:** The $500M capital and $20M annual operating increase form the foundation.
# 2.  **Federal & State Grants:** Aggressively pursue grants from FEMA (Building Resilient Infrastructure and Communities - BRIC, Flood Mitigation Assistance - FMA), HUD (Community Development Block Grant - CDBG-DR), EPA (Clean Water State Revolving Fund), and DOT. The new Climate Resilience Office will have dedicated grant writers.
# 3.  **Stormwater Utility Fee (Equitable Structure):**
#     *   **Mechanism:** Implement a stormwater utility fee, calculated based on impervious surface area per parcel.
#     *   **Equity:** Implement a tiered system with significant discounts or waivers for low-income households and non-profits. Small businesses could also receive tiered relief. Revenues dedicated solely to stormwater management and green infrastructure maintenance.
#     *   **Public Engagement:** Extensive public outreach and education campaign to explain the necessity and equitable structure.
# 4.  **Impact Fees/Development Contributions:** New developments in designated flood-prone areas or those impacting stormwater runoff could pay impact fees dedicated to resilience infrastructure.
# 5.  **Private Sector Partnerships:** Explore public-private partnerships for specific projects (e.g., innovative financing for resilience hubs, private land conservation for green infrastructure).
# 6.  **Future Bond Measures:** As success is demonstrated, consider a future municipal bond measure for larger-scale, long-term resilience projects.
#
# **B. Governance Mechanisms (Ensuring Equitable Outcomes):**
#
# 1.  **Climate Resilience Office (CRO):** Established as central coordinating body (as per plan).
#     *   **Role:** Oversee plan implementation, secure external funding, coordinate across city departments, lead public engagement.
#     *   **Equity Mandate:** CRO staff must have an explicit mandate to integrate equity into all project selection, design, and evaluation.
# 2.  **Inter-Departmental Resilience Working Group:** Regular meetings with key department heads (Public Works, Planning, Parks, Emergency Management, Housing, Economic Development) to ensure integrated planning and avoid silos.
# 3.  **Community Resilience Advisory Board (CRAB):**
#     *   **Composition:** Mandate diverse representation, with at least 50% from historically marginalized and frontline communities. Include local business owners, environmental justice advocates, and civic leaders.
#     *   **Role:** Advise CRO and city council on prioritization, project design, and equitable implementation; provide feedback on plan effectiveness; serve as a bridge between communities and city hall. Empower CRAB with some budgetary oversight or veto power on projects impacting vulnerable communities.
# 4.  **Transparent Reporting & Public Dashboard:** Create an easily accessible online dashboard detailing project progress, spending, and performance metrics (linked to Section 6). This will ensure accountability to all residents, especially those in vulnerable neighborhoods.
# 5.  **Vulnerability & Equity Assessment Tool:** Develop or adopt a standardized tool to screen all proposed projects for their equity impacts, ensuring benefits are equitably distributed and burdens are not disproportionately placed on vulnerable groups.
#
# ---
#
# ### **6. Measurable Metrics to Evaluate Success**
#
# 1.  **Reduced Flood Exposure:**
#     *   *Metric:* % reduction in number of properties experiencing flood damage from a 10-year storm event in identified vulnerable neighborhoods.
#     *   *Target:* 80% reduction by Year 10.
# 2.  **Green Infrastructure Adoption:**
#     *   *Metric:* Cumulative acres of green infrastructure installed (bioswales, permeable pavement, restored wetlands).
#     *   *Target:* 400 acres by Year 10.
# 3.  **Community Preparedness & Engagement:**
#     *   *Metric:* Number of residents trained in flood preparedness and % increase in participation from vulnerable communities in city-led resilience initiatives.
#     *   *Target:* 5,000 residents trained, 25% increase in vulnerable community participation by Year 10.
# 4.  **Critical Infrastructure Protection:**
#     *   *Metric:* % of critical city infrastructure (e.g., hospitals, emergency routes, wastewater treatment plants) protected from 50 cm SLR and 20-year storm surge.
#     *   *Target:* 90% by Year 10.
# 5.  **Economic Damages Avoided:**
#     *   *Metric:* Estimated annual avoided economic damages from flood events, calculated using pre/post-project damage assessments.
#     *   *Target:* $15 million annually by Year 10.
# 6.  **Institutional Capacity Score:**
#     *   *Metric:* Self-assessment score or independent audit evaluating the city's capacity in climate planning, data management, and inter-departmental coordination.
#     *   *Target:* 50% improvement in baseline score by Year 5, 80% by Year 10.
# 7.  **Equitable Benefit Distribution:**
#     *   *Metric:* % of capital investment directly benefiting areas identified as highly socially vulnerable (based on census tracts).
#     *   *Target:* At least 60% of capital investment in these areas by Year 10.
# 8.  **Coastal Ecosystem Health:**
#     *   *Metric:* Linear miles of living shoreline/dune restoration established and maintained, with associated ecological health indicators (e.g., biodiversity index, water quality parameters).
#     *   *Target:* 15 miles established and showing ecological improvement by Year 10.
#
# ---
#
# ### **7. Updating/Prioritizing the Plan Under Alternative Scenarios**
#
# **Scenario (a): A Sudden 30% Cut in Available Funds (Capital: $350M, Operating: $14M/year)**
#
# *   **Strategy:** Focus ruthlessly on core risk reduction, life safety, equity-first actions, and "no-regrets" interventions that also build fundamental capacity. Delay less urgent, larger-scale, or more speculative projects.
# *   **Prioritization Shifts:**
#     1.  **Deep Cuts:**
#         *   **Green Infrastructure (GI):** Reduce GI capital allocation by 30-40% ($130M -> ~$80M). Prioritize "low-hanging fruit" GI with highest immediate flood reduction impact in vulnerable areas.
#         *   **Coastal Protection (Nature-based/Hybrid):** Reduce by 30% ($150M -> ~$105M). Focus exclusively on living shorelines and critical infrastructure protection (e.g., wastewater plants) via small, targeted hybrid solutions. Delay broader dune restoration or larger road elevations.
#         *   **Community Resilience Hubs:** Reduce scope, retrofit 2-3 essential hubs instead of 5-7. Reduce property acquisition budget by 20% ($50M -> $40M), focusing on only the most extreme, repetitive loss properties.
#     2.  **Maintain/Protect:**
#         *   **Targeted Grey Infrastructure Upgrades:** Maintain most of this allocation ($70M) as it's critical for immediate life safety in vulnerable areas.
#         *   **Climate Resilience Office & Early Warning Systems:** Maintain core funding ($40M total) for institutional capacity building, data, and warning systems. These are "no-regrets" and foundational for future adaptation, even with less capital.
#         *   **Contingency:** Reduce, but maintain a minimum of $20-25M.
#     3.  **Increased Reliance:** Aggressively pursue federal and state grants for projects that are cut. Intensify efforts for the stormwater utility fee to cover operating and some capital costs.
# *   **Impact:** Slower progress, fewer areas protected, greater future risk exposure.
#
# **Scenario (b): Sea-Level Rise Accelerates to 100 cm by 2050**
#
# *   **Strategy:** This is a game-changer. It necessitates a more transformational and potentially retreat-oriented approach. Prioritize protecting critical regional infrastructure and public safety, while accepting that some areas may not be defendable long-term.
# *   **Prioritization Shifts:**
#     1.  **Accelerated Retreat & Transformation:**
#         *   **Property Acquisition/Buyouts:** Dramatically increase budget and accelerate the program ($70M -> ~$150M+), shifting from voluntary to potentially managed retreat in severely impacted zones. Begin planning for rezoning and relocating entire neighborhoods or commercial districts.
#         *   **Land Use Planning:** Immediately initiate a comprehensive review of zoning and land use ordinances to prohibit new development in 100cm SLR zones and incentivize relocation from existing high-risk areas.
#     2.  **Aggressive Structural & Nature-Based Protection for Critical Assets:**
#         *   **Coastal Protection:** Re-evaluate nature-based solutions for scalability against 100cm SLR. May require larger, more expensive hybrid solutions (e.g., regional levees, surge barriers) around critical assets (port, downtown, regional hospitals). This would require significantly more capital than currently allocated, necessitating immediate advocacy for state/federal funds and potentially a major bond measure.
#         *   **Stormwater:** Focus on higher-capacity pump stations and backflow prevention at major outfalls. Saltwater intrusion becomes a much larger threat, requiring new monitoring and potentially freshwater infrastructure adaptation.
#     3.  **Reduced Focus on Lesser-Impacted Areas:** Projects in areas not directly threatened by 100cm SLR may be deprioritized to free up resources.
#     4.  **Intensified Research & Monitoring:** Invest more in research on 100cm impacts (groundwater, ecosystems) and monitoring technologies.
# *   **Impact:** Transformational change for the city, potentially requiring large-scale population shifts, significant land use changes, and vastly increased capital investment beyond current capacity.
#
# **Scenario (c): Major Downtown Employer Relocates, 12% Loss in Municipal Revenues & Increased Unemployment**
#
# *   **Strategy:** Shift focus to economic recovery and social safety nets while maintaining core resilience. Prioritize projects that generate local jobs, leverage existing investments, and provide immediate community relief. Operating budget becomes a major constraint.
# *   **Prioritization Shifts:**
#     1.  **Economic Stimulus & Job Creation:**
#         *   **Project Selection:** Prioritize resilience projects that can be implemented rapidly and employ local workers (e.g., green infrastructure, smaller infrastructure repair, maintenance work) over large, highly technical projects that might require external specialists.
#         *   **Workforce Development:** Integrate job training programs into adaptation projects, especially for the newly unemployed (e.g., green infrastructure installation & maintenance).
#         *   **Local Procurement:** Implement aggressive local procurement policies for all project materials and services.
#     2.  **Maintaining Core Services & Social Safety Nets:**
#         *   **Operating Budget:** The $20M/year increase is now critical, but the overall 12% revenue loss ($20M increase may be offset by $36M general fund loss, assuming 300M total revenues) means the city needs to be extremely lean. The Resilience Office might need to be smaller, relying more on external expertise.
#         *   **Community Resilience Hubs:** Double down on these as social support centers, providing resources for unemployment, job training, and mental health.
#         *   **Property Acquisition:** Slow down or pause unless properties are extreme repetitive losses, as the city cannot afford significant new land acquisition or maintenance burdens.
#     3.  **External Funding for Economic Recovery:** Aggressively seek federal/state economic development grants (EDA), workforce development funds, and disaster recovery funds (even for economic disasters).
#     4.  **Deferred Non-Critical Projects:** Delay larger, long-term capital projects without immediate economic or critical risk reduction benefits. Focus on maintenance of existing infrastructure over new large builds.
#     5.  **Re-evaluating Stormwater Utility Fee:** Careful consideration of its implementation during an economic downturn, potentially offering greater relief or delaying implementation.
# *   **Impact:** Slower progress on adaptation, increased social stress, reliance on external aid for economic recovery. The plan becomes a component of a larger economic revitalization strategy.
#
# ---
#
# ### **Confidence Level in Main Recommendations**
#
# I am **moderately high (8/10)** confident in the main recommendations of this 10-year plan.
#
# **Strengths:**
# *   The plan adheres to best practices in urban climate adaptation, emphasizing integrated grey-green infrastructure, nature-based solutions, and community engagement.
# *   The prioritization framework is robust, directly addressing equity, risk, and economic resilience.
# *   The budget allocation is realistic for the scale of the city and its stated needs, with a critical contingency fund.
# *   The inclusion of institutional capacity building is crucial given the city's stated limitations.
# *   The scenario analysis demonstrates flexibility and foresight.
#
# **Limitations impacting confidence:**
# *   **Budget Size:** While significant, $500M is not limitless for a city of 300,000 facing aging infrastructure and moderate SLR. The plan makes strategic choices, but larger-scale, region-wide solutions might require more.
# *   **Political Will & Public Acceptance:** The plan assumes a reasonable level of political will and public support for potentially disruptive changes (e.g., stormwater fees, buyouts).
# *   **Detailed Costing:** Specific project costs are estimates and would require detailed engineering studies.
# *   **External Funding:** The long-term success of the plan in scaling up depends on securing additional federal and state funding, which is competitive.
# *   **Pace of Climate Change:** While 50 cm by 2050 is the current projection, uncertainty remains. Rapid acceleration could quickly make some interventions insufficient.
#
# This plan provides a strong, defensible roadmap for our city's resilience journey. Regular monitoring, adaptive management, and continuous engagement with our communities will be vital for its sustained success.

# %%
model_name = "deepseek-chat"
answer = ChatModel(
            model_name=model_name,
            provider="deepseek",
            api_key=deepseek_api_key
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# # **10-Year Climate Adaptation Plan for Coastal City**
#
# ## **1. Executive Summary & Core Assumptions**
#
# **Assumptions:**
# - City has ~300,000 residents, 100,000 households, $25B in property value
# - Current annual flood damages: ~$15M (based on similar cities)
# - Sea-level rise: 50cm by 2050 (moderate trajectory)
# - Storm intensity/frequency increasing 15% over decade
# - Existing stormwater system designed for 10-year storms, now overwhelmed by 5-year events
# - 40% of population in floodplains, with low-income neighborhoods disproportionately exposed
# - Transportation network has 3 critical flood-prone corridors
# - **Confidence Level:** Medium-High (80%) for main recommendations given current data
#
# ---
#
# ## **2. Prioritized Interventions, Costs & Timeline**
#
# ### **PHASE 1: Years 1-3 ($250M capital + $60M operating)**
# **Immediate Risk Reduction & Institutional Foundation**
#
# 1. **Neighborhood-Scale Green-Gray Infrastructure** ($180M capital)
#    - Targeted installation of bioswales, permeable pavement, and small-scale retention basins in 3 most vulnerable low-income neighborhoods
#    - Upgrade drainage capacity in these areas from 5-year to 25-year storm standard
#    - **Cost:** $60M/neighborhood × 3 = $180M
#    - **Timeline:** Design Y1, Construction Y2-3
#
# 2. **Early Warning & Emergency Response System** ($20M capital + $6M/yr operating)
#    - Real-time flood sensors at 200 critical locations
#    - Targeted emergency notification system (multi-lingual, accessible)
#    - Community resilience hubs in vulnerable neighborhoods
#    - **Cost:** $20M capital + $6M/yr operating
#
# 3. **Property Acquisition & Managed Retreat** ($50M capital)
#    - Voluntary buyout program for 200 most at-risk properties
#    - Convert to flood-absorbing green space
#    - **Cost:** $250,000/property average × 200 = $50M
#
# ### **PHASE 2: Years 4-7 ($200M capital + $80M operating)**
# **Systemic Upgrades & Economic Resilience**
#
# 4. **Critical Transportation Corridor Protection** ($150M capital)
#    - Elevate/fortify 3 most critical flood-prone transportation corridors
#    - Install tide gates at 2 key intersections with waterways
#    - **Cost:** $50M/corridor × 3 = $150M
#
# 5. **Municipal Building & Critical Facility Hardening** ($50M capital)
#    - Protect hospitals, schools, emergency operations centers
#    - Elevate electrical/mechanical systems, install backup power
#    - **Cost:** $50M
#
# 6. **Stormwater Utility & Incentive Programs** ($8M/yr operating)
#    - Fee-based utility to fund ongoing maintenance
#    - Rebates for private property flood retrofits (up to 50% cost)
#    - Technical assistance for small businesses
#
# ### **PHASE 3: Years 8-10 ($50M capital + $60M operating)**
# **Long-Term Adaptation & Mainstreaming**
#
# 7. **Zoning & Land Use Reform** ($5M/yr operating)
#    - Update floodplain maps and building codes
#    - Transfer of development rights program
#    - **Cost:** $5M/yr operating
#
# 8. **Ecosystem-Based Adaptation** ($50M capital)
#    - Restore 50 acres of coastal wetlands/mangroves
#    - Living shoreline along 2 miles of vulnerable coast
#    - **Cost:** $50M
#
# 9. **Workforce Development Program** ($3M/yr operating)
#    - Train residents for green infrastructure jobs
#    - Focus on vulnerable communities
#
# ---
#
# ## **3. Justification & Quantified Benefits**
#
# ### **Risk Reduction**
# - **Flood Protection:** 15,000 households moved from 10-year to 100-year flood protection
# - **Avoided Damages:** $350M in property damage avoided over 10 years
# - **Lives Protected:** Reduced flood mortality risk by 75% in targeted neighborhoods
# - **Critical Services:** 95% of emergency facilities remain operational during 100-year flood
#
# ### **Equity**
# - 60% of capital investments directed to neighborhoods in bottom income quartile
# - Buyout program prioritizes low-income homeowners (150% AMI threshold)
# - Resilience hubs located in communities with highest social vulnerability index
#
# ### **Economic Resilience**
# - Protects $8B in economic activity along transportation corridors
# - Maintains port/industrial zone functionality during moderate floods
# - Creates ~800 local jobs in construction and maintenance
#
# ### **Co-Benefits**
# - **Emissions:** 50,000 tons CO2e sequestered/avoided through green infrastructure
# - **Health:** Reduced heat island effect in 3 neighborhoods (estimated 2°C cooling)
# - **Recreation:** 200 acres of new green space accessible to 50,000 residents
#
# ---
#
# ## **4. Key Uncertainties & Data Gaps**
#
# **High-Priority Data Requests:**
# 1. **Subsidence Rates:** Lidar survey to determine land sinking rates ($2M)
# 2. **Groundwater Interactions:** Monitoring wells to understand flooding mechanisms ($1.5M)
# 3. **Social Vulnerability:** Detailed survey of adaptive capacity, insurance coverage, mobility constraints ($500K)
# 4. **Infrastructure Condition:** Comprehensive assessment of stormwater system ($3M)
# 5. **Ecosystem Services:** Valuation of natural assets for flood mitigation ($800K)
#
# **Plan Alteration Triggers:**
# - Subsidence >5mm/year would require accelerated elevation strategies
# - Discovery of widespread groundwater flooding would shift focus to pumping solutions
# - Higher-than-expected social vulnerability would increase non-structural investments
#
# ---
#
# ## **5. Financing & Governance Mechanisms**
#
# ### **Financing**
# - **Capital:** $500M bond (already secured) + FEMA BRIC grants (target 25% match)
# - **Operating:** New stormwater utility ($80/household/year, sliding scale)
# - **Innovative:** Environmental impact bonds, resilience bonds with parametric triggers
# - **Partnerships:** PPP for port infrastructure, nature-based solution carbon credits
#
# ### **Governance**
# - **Oversight:** Resilience Office with cross-department authority
# - **Community:** Neighborhood Adaptation Councils with decision-making power
# - **Transparency:** Public dashboard tracking all projects, expenditures, benefits
# - **Equity:** Mandatory Equity Impact Assessment for all projects >$1M
# - **Maintenance:** Dedicated 15% of capital budget for ongoing maintenance
#
# ---
#
# ## **6. Success Metrics**
#
# 1. **Risk Reduction:** % of population in 100-year floodplain with actual protection
# 2. **Equity:** Ratio of adaptation spending per capita in lowest vs highest income quartiles (target: 3:1)
# 3. **Economic:** Business interruption hours avoided during flood events
# 4. **Ecological:** Acres of natural floodplain restored/created
# 5. **Social:** Flood insurance take-up rates in vulnerable communities
# 6. **Institutional:** % of city capital budget screened for climate risk
# 7. **Financial:** Leverage ratio (non-city funds : city funds)
# 8. **Health:** Heat-related emergency visits in targeted neighborhoods
#
# ---
#
# ## **7. Scenario Response**
#
# ### **(a) 30% Funding Cut ($350M capital)**
# **Priority Preservation:**
# 1. Maintain all equity-focused neighborhood investments (now $126M for 2 neighborhoods)
# 2. Keep early warning system and 50% of buyout program
# 3. Defer transportation corridor work to Phase 3, seek federal grants
# 4. Reduce municipal hardening by 50%, focus on most critical facilities
# 5. Delay ecosystem projects but preserve land acquisitions
#
# ### **(b) Accelerated SLR (100cm by 2050)**
# **Accelerated Timeline & Strategic Shift:**
# 1. Immediate moratorium on new development in expanded 2050 floodplain
# 2. Double pace of buyouts (400 properties in Phase 1)
# 3. Prioritize vertical evacuation structures over transportation upgrades
# 4. Shift from gray to hybrid infrastructure (more adaptable)
# 5. Begin planning for protective barriers around economic core
# 6. Increase operating budget for monitoring and rapid response
#
# ### **(c) Major Employer Departure (12% revenue loss)**
# **Economic Resilience Focus:**
# 1. Fast-track workforce development program (immediate job creation)
# 2. Prioritize projects with highest job multipliers (green infrastructure: 15 jobs/$1M)
# 3. Use adaptation investments to attract new climate-resilient industries
# 4. Leverage infrastructure projects to reduce business costs (lower flood insurance)
# 5. Seek state/federal economic adjustment assistance
# 6. Consider public-private partnerships for revenue-generating resilience projects
#
# ---
#
# ## **8. Implementation Principles**
#
# 1. **Adaptive Management:** Annual review with trigger-based decision points
# 2. **No Regrets:** 70% of investments provide benefits regardless of climate future
# 3. **Reversibility:** Avoid irreversible decisions where uncertainty is high
# 4. **Precautionary:** Where consequences are catastrophic, act despite uncertainty
# 5. **Mainstreaming:** Climate criteria integrated into all capital planning by Year 3
#
# **Final Confidence Assessment:** 80% confidence in this prioritization given current information. Highest confidence in neighborhood-scale interventions and early warning systems. Lower confidence in optimal timing of large gray infrastructure given SLR uncertainty. Recommend 2-year review cycle with updated climate projections.

# %%
model_name = "openai/gpt-oss-120b"
answer = ChatModel(
            model_name=model_name,
            provider="groq",
            api_key=groq_api_key
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# ## 1. 10‑Year Climate‑Adaptation Plan (2025‑2035)
# **City profile** – 300 k residents, coastal location, median household income $58 k, 30 % of households earn < $30 k, 20 % of the built‑stock is over 40 years old, storm‑water network designed for 1970‑era 10‑year storm (now undersized).
#
# **Resources** – One‑time capital pool **$500 M** (no debt service constraints) + **$20 M/yr** additional operating budget for 10 yr (total $200 M).
#
# **Goal** – Reduce flood exposure, protect lives & livelihoods, improve mobility, and generate co‑benefits (green space, air quality, economic revitalisation) while distributing benefits equitably across income groups.
#
# ---
#
# ### 1.1. Intervention Portfolio
#
# | # | Category | Intervention (brief description) | Target Area(s) | Approx. Capital Cost | Annual O&M (first 10 yr) | Timeline (yr) | Primary Benefits |
# |---|----------|-----------------------------------|----------------|---------------------|--------------------------|---------------|-------------------|
# | **A1** | **Structural – Flood Defense** | **Elevated “Living Shoreline” & Modular Floodwalls** (2‑km stretch protecting the historic downtown and adjacent low‑income waterfront neighborhoods) | Downtown, East Riverfront (pop. ≈ 35 k) | $120 M | $2 M | 2025‑2029 (design‑2025, construction‑2026‑2029) | 1‑m flood protection, shoreline habitat, recreation |
# | **A2** | **Structural – Storm‑water Capacity** | **Hybrid Green‑Blue Infrastructure Network** – 150 acre of bioswales, rain gardens, underground detention tanks, and permeable‑pavement retrofits on arterial streets in the most flood‑prone, low‑income districts (North & South West) | 6 neighborhoods (≈ 80 k residents) | $95 M | $1.5 M | 2025‑2028 (pilot‑2025, scale‑2026‑2028) | Reduce peak runoff 30 %, improve water quality, heat‑island mitigation |
# | **A3** | **Structural – Transportation Resilience** | **Elevated Bus Rapid Transit (BRT) corridor** on Main‑St (critical commuter link) with flood‑proof stations & electric buses | Downtown‑Suburb corridor (≈ 150 k daily riders) | $110 M | $4 M (fuel/maintenance) | 2026‑2030 (procurement‑2026, construction‑2027‑2030) | Maintain mobility during floods, lower emissions, job access |
# | **A4** | **Structural – Critical Facility Protection** | **Retrofit & Raise** City Hall, Emergency Operations Center, and 2 major hospitals (storm‑surge doors, backup generators, flood‑proof utility rooms) | City Center & Healthcare Zone | $45 M | $0.8 M | 2025‑2027 | Continuity of governance & health services |
# | **B1** | **Non‑Structural – Zoning & Land‑Use** | **Adaptive Zoning Ordinance** – restrict new development < 0.5 m AAL (annual average loss) floodplain; incentivize “buy‑out & relocate” for existing at‑risk housing, especially low‑income | Citywide (focus on 5 high‑risk parcels) | $2 M (policy drafting, legal) | $0.3 M (enforcement) | 2025‑2026 (adopt‑2025, roll‑out‑2026) | Long‑term risk reduction, equity |
# | **B2** | **Non‑Structural – Early‑Warning & Community Outreach** | **Integrated Flood‑Alert System** (SMS, sirens, GIS portal) + multilingual education campaigns; community flood‑prep kits for low‑income blocks | All neighborhoods (target 10 k households first) | $8 M | $0.6 M | 2025‑2026 (system build‑2025, pilot‑2025‑2026) | Lives saved, quicker response |
# | **B3** | **Non‑Structural – Climate‑Resilient Housing Programs** | **“Resilience Grants”** for retrofitting homes (elevating utilities, flood‑resistant doors/windows) – $10 k per unit, priority to households < $30 k income; partnered with local NGOs | Low‑income districts (≈ 12 k units) | $30 M (grant pool) | $2 M (admin) | 2026‑2031 (grant rollout) | Reduces damage, improves housing quality |
# | **C1** | **Co‑Benefit – Urban Green Space** | **Linear Park & Floodplain Reconnection** – 3‑km green corridor that doubles as overflow storage (detention basin) and active recreation trail | Riverfront & adjacent neighborhoods | $38 M | $0.9 M | 2028‑2032 (land acquisition‑2028, build‑2029‑2032) | Heat‑island reduction, public health, tourism |
# | **C2** | **Co‑Benefit – Renewable Energy** | **Solar Canopies on Municipal Parking Lots** (5 sites, 5 MW total) – integrated with BRT stations | Citywide | $20 M | $1.5 M (operations) | 2026‑2029 | Offsets O&M emissions, revenue generation |
#
# **Total Capital:** **$468 M** (≈ $32 M contingency left for unforeseen design changes).
# **Total O&M (first 10 yr):** **$16.5 M/yr** – within the $20 M/yr operating envelope, leaving $3.5 M/yr for other city services or to build a maintenance reserve.
#
# ---
#
# ## 2. Prioritisation Rationale
#
# | Priority | Why it ranks high | Equity Lens | Economic Resilience | Co‑Benefits |
# |----------|-------------------|------------|---------------------|------------|
# | **1 – A1 (Living Shoreline & Floodwalls)** | Directly protects downtown core (government, businesses, 35 k residents) and the adjacent low‑income waterfront where 70 % of households are below city median income. 0.5 m sea‑level rise + storm surge would otherwise inundate 90 % of structures. | High‑risk, low‑income communities receive the first line of defense. | Safeguards tax base, tourism, port activity; avoids estimated **$450 M** in avoided damages over 30 yr. | Restores habitat, carbon sequestration (~12 kt CO₂ yr⁻¹). |
# | **2 – B1 (Adaptive Zoning + Buy‑outs)** | Prevents future exposure; a “no‑build” policy in the worst floodplain reduces long‑term liability. | Buy‑outs targeted at the poorest 20 % of at‑risk households, offering relocation assistance. | Avoids repeated post‑disaster reconstruction costs (estimated **$70 M**/decade). | Opens space for green corridors (C1). |
# | **3 – A2 (Green‑Blue Stormwater Network)** | Storm‑water failures cause the most frequent (≈ annual) localized flooding, especially in low‑income neighborhoods. | Projects located in neighborhoods with the highest flood frequency and lowest vehicle ownership. | Reduces property damage ($2 M/yr) and lowers municipal pumping costs. | Improves water quality, urban cooling (≈ 1.2 °C reduction), biodiversity. |
# | **4 – A3 (Elevated BRT)** | Transportation is a lifeline; floods routinely shut down main arterial roads, isolating workers. | Provides affordable, reliable mobility for low‑income commuters; electric fleet cuts exposure to fuel price spikes. | Maintains economic activity during events, supports 12 % of city’s jobs. | Cuts GHG emissions by ~15 kt CO₂ yr⁻¹, improves air quality. |
# | **5 – A4 (Critical Facility Retrofits)** | Guarantees continuity of essential services; hospitals already have flood‑damage history. | All residents benefit equally from uninterrupted services. | Prevents catastrophic health‑system shutdown, averts indirect economic losses. | None direct, but improves community confidence. |
# | **6 – B2 (Early‑Warning System)** | Low cost, high return (life‑saving). | Multilingual alerts target non‑English speakers (≈ 15 % of residents). | Reduces emergency response costs, insurance payouts. | Enhances civic engagement. |
# | **7 – B3 (Resilience Grants)** | Directly upgrades the housing stock that bears the brunt of flood damage. | Income‑based eligibility ensures equity. | Lowers insurance premiums, protects asset values. | Improves indoor air quality, energy efficiency. |
# | **8 – C1 (Linear Park)** | Provides long‑term flood storage while delivering recreation and health benefits. | Parks placed in historically under‑served neighborhoods. | Boosts property values, tourism revenue. | Heat‑island mitigation, ecosystem services. |
# | **9 – C2 (Solar Canopies)** | Generates clean energy to offset O&M emissions and creates a modest revenue stream. | Located at municipal lots, free for all users. | Reduces utility cost for city, improves fiscal resilience. | Public‑space amenity. |
#
# **Overall prioritisation principle:** *Protect people & critical assets first, then reduce systemic risk (storm‑water, transport), finally add co‑benefits.*
#
# ---
#
# ## 3. Quantified Expected Benefits
#
# | Benefit | Metric | Base‑case (2025‑2050) | Methodology |
# |---------|--------|----------------------|------------|
# | **Reduced flood frequency** (events > $1 M) | 30 % fewer annual flood events citywide (from 12 to 8) | GIS flood‑inundation modeling (SLR + storm surge) |
# | **Avoided direct property damage** | $450 M (cumulative 2025‑2050) | Damage functions (Hansen et al., 2021) using exposure inventory |
# | **Lives protected** | ≈ 25 lives saved (assuming 0.5 fatalities per severe flood event) | Historical fatality rates scaled by exposure reduction |
# | **Housing units protected** | 12 k low‑income units retrofitted; 4 k units elevated via buy‑outs | Household survey + GIS inventory |
# | **Economic activity maintained** | $1.2 B in avoided GDP loss (transport shutdowns) | Input‑output model of BRT continuity |
# | **Emission reductions** | 30 kt CO₂e/yr (combined BRT electrification & solar) | EPA GHG calculator for electric buses + solar |
# | **Urban heat island** | 0.8 °C average temperature reduction in target neighborhoods | Micro‑climate modeling (ENVI‑MET) |
# | **Water quality improvement** | 15 % reduction in suspended solids & nutrients in receiving estuary | Storm‑water BMP performance curves |
# | **Recreational acres** | + 150 acre public parkland (C1) | Land‑use conversion |
#
# *All monetary values are net present values (NPV) at a 3 % discount rate.*
#
# ---
#
# ## 4. Key Uncertainties & Data Gaps
#
# | Uncertainty | Potential Impact on Plan | Data Needed |
# |-------------|--------------------------|-------------|
# | **Sea‑level rise trajectory** – possibility of > 0.5 m by 2050 | Under‑design of flood barriers, need for higher walls | Updated NOAA/USGS tide‑gauge trends, downscaled climate model ensembles |
# | **Storm intensity & frequency changes** (e.g., more extreme 100‑yr storms) | Capacity of green‑blue infrastructure may be exceeded | High‑resolution precipitation projections, hydraulic model calibration |
# | **Population & land‑use dynamics** (gentrification, migration) | Shifts in exposure patterns, equity of interventions | Updated census micro‑data, housing market forecasts |
# | **Financial assumptions** – cost inflation for construction & materials | Budget overruns | Real‑time price indices for concrete, steel, labor |
# | **Effectiveness of buy‑out program** – participation rates | May leave residual at‑risk households | Survey of homeowner willingness, legal constraints |
# | **Future policy environment** (state/federal grant eligibility) | Could unlock additional funding or impose new compliance | Tracking of upcoming climate‑resilience grant programs (e.g., FEMA’s BRIC, EPA’s CDBG‑DR) |
# | **Technological reliability of BRT electric fleet** | Operational cost variance | Vendor performance data, lifecycle cost analysis |
#
# *Action:* Commission a **“Climate‑Risk Data Hub”** (≈ $3 M) to integrate sea‑level, storm, socioeconomic, and asset‑inventory datasets, with annual updates.
#
# ---
#
# ## 5. Financing & Governance
#
# ### 5.1. Funding Mix
#
# | Source | Share of Capital | Mechanism |
# |--------|------------------|-----------|
# | **Municipal Capital Pool** | 55 % ($260 M) | Direct allocation, overseen by Climate‑Resilience Office (CRO) |
# | **State/Regional Grants** (e.g., CalAdapt, NEF) | 20 % ($100 M) | Competitive proposals (green infrastructure, flood defense) |
# | **Federal Programs** (FEMA BRIC, EPA CDBG‑DR) | 15 % ($75 M) | Cost‑share with matching requirements |
# | **Private‑Sector Partnerships** (PPP for BRT, solar) | 5 % ($25 M) | Long‑term lease‑back, revenue‑sharing |
# | **Impact‑Investors / Climate Bonds** | 5 % ($25 M) | Green bond issuance (municipal bond rating A‑) |
#
# ### 5.2. Governance Structure
#
# 1. **Climate‑Resilience Office (CRO)** – New city department (≈ $3 M/yr) reporting directly to the Mayor; responsible for plan coordination, data hub, and performance monitoring.
# 2. **Stakeholder Advisory Council** – 12 members (community groups, low‑income advocates, business, academia). Provides equity review of each project.
# 3. **Implementation Units** – Existing Public Works (flood barriers), Transportation (BRT), Housing (grants), and Parks (linear park). Each signs a **Performance‑Based Contract (PBC)** linking a portion of payments to metric achievement (e.g., % of flood events avoided).
# 4. **Maintenance Trust Fund** – 10 % of annual O&M budget (≈ $2 M/yr) set aside in a dedicated reserve, replenished by revenues from solar canopies and BRT fare‑box surpluses.
#
# ### 5.3. Ensuring Equitable Outcomes
#
# * **Equity Impact Assessments** (EIA) before each capital allocation.
# * **Targeted “Community Resilience Grants”** – 30 % of project‑related contracts must be awarded to minority‑owned, women‑owned, or locally‑based firms.
# * **Sliding‑scale user fees** for BRT (reduced fare for <$30 k income).
#
# ---
#
# ## 6. Success Metrics (to be reported annually)
#
# | Metric | Target (2025‑2035) | Rationale |
# |--------|-------------------|-----------|
# | **1. Flood‑event exposure** – % reduction in households living in 1‑ft floodplain | ≥ 35 % reduction | Direct risk metric |
# | **2. Number of dwellings retrofitted or bought out** | 12 k units | Equity‑focused housing protection |
# | **3. BRT reliability** – % of scheduled trips completed during storm events | ≥ 95 % | Transportation resilience |
# | **4. Green‑Blue infrastructure capacity** – % reduction in peak runoff volume on target arterials | ≥ 30 % | Storm‑water performance |
# | **5. Annual GHG emissions avoided** | ≥ 30 kt CO₂e/yr | Climate co‑benefit |
# | **6. Public park acreage created** | ≥ 150 acre | Health & ecosystem benefit |
# | **7. Early‑warning system coverage** – % of households receiving alerts within 5 min of issuance | 100 % | Life‑saving metric |
# | **8. Maintenance Trust Fund balance** – % of target ($2 M/yr) achieved | ≥ 90 % | Fiscal sustainability |
#
# *All metrics will be tracked via the Climate‑Risk Data Hub and audited by an independent third party.*
#
# ---
#
# ## 7. Scenario Planning & Adaptive Re‑Prioritisation
#
# ### 7.1. Scenario (a) – 30 % Capital Cut ($350 M available)
#
# | Revised Priorities | Rationale |
# |--------------------|-----------|
# | **Keep** A1 (Living Shoreline) – essential protection of downtown & low‑income waterfront (funded 100 %). |
# | **Scale back** A2 – implement **phased green‑blue network**: Phase 1 (50 % of planned acreage) → $48 M; defer remainder to 2035‑2040. |
# | **Postpone** C1 (Linear Park) – re‑allocate $38 M to A2; park can be built later using future grants. |
# | **Maintain** B1, B2, B3 (policy, warning, grants) – low cost, high equity return. |
# | **Reduce** A3 (BRT) – adopt a **surface‑level BRT** with flood‑proof stations (cost $70 M) and defer elevated viaduct portion. |
# | **Funding Gap** – $15 M remaining; seek additional state grant or issue a modest **$200 M Climate Bond** with a 10‑year term. |
#
# *Impact:* Flood protection still achieved; storm‑water capacity reduced → may need supplemental temporary pumping during extreme events.
#
# ### 7.2. Scenario (b) – Sea‑Level Rise Accelerates to 1 m by 2050
#
# | Revised Priorities | Action |
# |--------------------|--------|
# | **Upgrade A1** – increase floodwall height by 1 m, add removable floodgates; cost increase $25 M (use contingency). |
# | **Accelerate A4** – raise critical facilities to 1 m above current BFE (additional $10 M). |
# | **Expand A2** – add **additional detention volume** (new underground tanks) $20 M. |
# | **Advance B1** – stricter setback requirements, start buy‑outs earlier (additional $10 M). |
# | **Defer C2 (Solar)** – re‑allocate $20 M to flood defenses. |
# | **Total additional cost** ≈ $65 M → financed by a **$65 M supplemental climate bond** and re‑allocation of the $3 M contingency saved from scenario (a) planning. |
#
# ### 7.3. Scenario (c) – 12 % Revenue Loss & Unemployment Spike
#
# | Revised Priorities | Mitigation |
# |--------------------|------------|
# | **Preserve core protection** (A1, A4, B1, B2) – essential for public safety. |
# | **Temporarily reduce O&M** – defer non‑critical routine landscaping in parks (save $0.5 M/yr). |
# | **Introduce “Resilience Workforce Program”** – use **unemployment benefits** to staff green‑infrastructure maintenance (creates jobs, offsets O&M cost). |
# | **Scale back B3 Grants** – reduce grant size to $5 k/unit, focus on most vulnerable 6 k units (save $30 M). |
# | **Seek Federal Economic‑Recovery Grants** (e.g., ARP) – target to cover shortfall and create jobs. |
# | **Long‑term** – implement a modest **property‑tax surcharge** earmarked for the Maintenance Trust Fund (estimated $10 M/yr). |
#
# *Result:* Protection remains, while the plan adapts to a tighter operating budget and leverages job creation as a co‑benefit.
#
# ---
#
# ## 8. Assumptions & Confidence Levels
#
# | Assumption | Detail | Confidence |
# |------------|--------|------------|
# | **Sea‑level rise** – 0.5 m by 2050 under current emissions pathway | Based on IPCC AR6 “intermediate‑high” scenario (RCP4.5) and regional ocean‑monitoring data | **High** (± 0.1 m) |
# | **Cost estimates** – 2025 USD, 10 % contingency built‑in | Derived from recent municipal projects of similar scope, adjusted for inflation | **Medium‑High** |
# | **Economic damages avoided** – $450 M (NPV) | Damage functions calibrated to local building stock and flood depth–damage curves | **Medium** (sensitive to flood frequency) |
# | **Community participation** – 70 % uptake for resilience grants | Based on pilot studies in comparable U.S. cities | **Medium** |
# | **BRT ridership growth** – 3 %/yr post‑implementation | Reflects regional transit trends and population growth | **Medium** |
# | **Grant eligibility** – state/federal programs remain available | Current policy trajectory, but subject to political change | **Low‑Medium** |
# | **Effectiveness of living‑shoreline** – 80 % wave attenuation for 2‑m design storms | Field studies from similar Atlantic‑coast sites | **High** |
#
# Overall **confidence in the core recommendation** (protect downtown & vulnerable waterfront first, then expand green‑blue storm‑water capacity and resilient transit) is **high (≈ 85 %)**. Uncertainties related to future sea‑level acceleration and funding availability are captured in the scenario analyses and the built‑in contingency fund.
#
# ---
#
# ### Final Take‑away
#
# By **leveraging the $500 M capital pool strategically**, the city can **secure the most vulnerable populations**, **maintain economic functionality during extreme events**, and **create lasting environmental and social co‑benefits**. The plan is **flexible**, with clear metrics and a data‑driven governance framework that allows rapid re‑prioritisation should any of the three “stress‑test” scenarios materialise. Continuous monitoring through the Climate‑Risk Data Hub ensures that the city can **adjust investments in real time**, safeguarding both its **people and its future prosperity**.

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
#!ollama pull deepseek-r1:7b

# %%
model_name = "deepseek-r1:7b"
answer = ChatModel(
            model_name=model_name,
            provider="ollama",
            api_key="me"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# **Adaptive Action Plan for Coastal City Urban resilience**
#
# **Overview:**
# The coastal city faces critical challenges including aging infrastructure, income inequality, limited institutional capacity, and sea-level rise projections. The strategy aims to build a resilient urban framework over ten years with a focus on equity and effectiveness.
#
# ---
#
# **1. Adaptive Capacity Hub Development ($20M, Year 1)**
# - **Intervention:** Establish an adaptive planning hub in Montague Street.
# - **Timeline:** Completed within the first year.
# - **Rationale:** Enhances long-term resilience by enabling proactive planning and learning from past events.
#
# **2. Enhanced Transportation Infrastructure ($35M, Years 1-4)**
# - **Intervention:** Expand public transit (streetcars) and bike lanes in lower-income areas.
# - **Timeline:** Full implementation within four years.
# - **Rationale:** Promotes equity by ensuring all residents can access safe mobility options.
#
# **3. Strengthened Stormwater Systems ($25M, Years 1-3)**
# - **Intervention:** Upgrade existing systems to handle increased runoff.
# - **Timeline:** Completed in three years.
# - **Impact:** Reduces immediate flooding risks and protects homes with inferior infrastructure.
#
# **4. Community Engagement and Awareness ($15M, Years 1-2)**
# - **Intervention:** Launch awareness campaigns and education programs.
# - **Timeline:** Ongoing efforts within two years.
# - **Impact:** Enhances preparedness and community involvement crucial for sustainable change.
#
# **5. Green Infrastructure Implementation ($30M, Years 4-6)**
# - **Intervention:** Deploy permeable pavements across urban areas.
# - **Timeline:** Completed in six years.
# - **Benefits:** Improves water quality and reduces stormwater runoff, co-benefiting with urban ecosystem health.
#
# **6. Proactive Early Warning Systems ($20M, Years 3-5)**
# - **Intervention:** Develop and deploy early warning systems.
# - **Timeline:** Implemented over five years.
# - **Impact:** Allows communities to prepare effectively for disasters.
#
# **7. Public Ownership Platform ($18M, Years 6-8)**
# - **Intervention:** Establish a platform empowering local groups in adaptation.
# - **Timeline:** Operational within eight years.
# - **Equity Focus:** Ensures marginalized groups lead, reducing inequities.
#
# **8. Enhanced Communication Infrastructure ($25M, Years 7-10)**
# - **Intervention:** Upgrade to include 5G technology.
# - **Timeline:** Completed in ten years.
# - **Impact:** Essential for effective coordination and reliable communication during emergencies.
#
# ---
#
# **Uncertainties:**
# -Accelerated sea-level rise could exceed projections. Inequitable funding distribution may lead to disparities where some communities face higher risks.
#
# **Financing & Governance:**
# -Support through public-private partnerships and the mayor's strong leadership, focusing on equity throughout planning and implementation.
#
# **Measurable Metrics (Year 10):**
# - Reduction in flooding frequency/intensity
# - Avoided damage costs
# - Enhanced transport reliability
# - Increased greenery area
# - Community participation rates
# - Equitable upgrade access
# - Resilient power grid availability
#
# ---
#
# **Scenario Adaptation:**
#
# **Scenario A (30% Funding Cut):**
# -Focus on high-risk areas, reallocating resources from less urgent projects. Prioritize basic resilience measures to secure survival.
#
# **Scenario B (Accelerated Sea-Level Rise):**
# -Uphold the adaptive hub and permeable pavements but allocate more annual budgets elsewhere for additional resilience.
#
# **Scenario C (Employer Relocation Impact):**
# -Prioritize immediate actions like improved drainage and green infrastructure, followed by more extensive projects ensuring equitable access.
#
# ---
#
# **Conclusion:**
# The plan balances risk reduction, equity, and economic resilience. Clear metrics and adaptive strategies ensure continuous improvement while addressing structural and non-structural needs comprehensively.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-5', 'gemini-2.5-flash', 'deepseek-chat', 'openai/gpt-oss-120b', 'deepseek-r1:7b']
# ["Below is a concise, evidence-informed 10-year adaptation plan tailored to a mid-sized coastal city with aging stormwater/transportation systems, equity gaps, and limited capacity. All costs are approximate order-of-magnitude, in 2024 dollars, and are intended to fit within the available resources: $500 million in one-time capital funds plus $20 million per year for operating expenditures over 10 years (total operating: about $200 million). Where appropriate, I note assumptions, data needs, and uncertainties.\n\n1) Assumptions and context\n- Physical and climate context:\n  - Population ~300,000; coastal exposure with a 50 cm sea-level rise projection by 2050 under current trajectories; heavy rainfall events with pluvial flooding risk in urban cores.\n  - Existing aging stormwater and transportation infrastructure with limited redundancy and maintenance funding.\n- Financial framework:\n  - One-time capital pool: $500 million.\n  - Additional operating funds: +$20 million/year for 10 years (total $200 million over the decade).\n  - Desired balance: prioritize high-risk, high-reward interventions that improve equity and economic resilience, while preserving essential services and enabling ongoing maintenance.\n- Governance and capacity:\n  - Limited institutional capacity; plan emphasizes scalable, phased implementation, simplified procurement, and targeted capacity building.\n- Equity lens:\n  - Recognize disproportionate exposure in historically underserved neighborhoods; ensure access to protection, mobility, and resilience benefits.\n\n2) 10-year prioritized adaptation plan (interventions, costs, timelines, benefits)\nNote: All costs are approximate ranges in millions USD; timelines are indicative phasing.\n\nA. Tier 1 (core risk reduction in the near term; high leverage with co-benefits)\n1) Downtown coastal protection package (structural)\n- What: Seawall/shoreline hardening along critical waterfront corridors; tidal gates or flood barriers at key crossings; elevate select street segments and protect essential transit corridors.\n- Type: Structural.\n- Capital cost: $180–$230m.\n- Operating: modest maintenance; $2–5m over 10 years (covered by annual operating budget).\n- Timeline: Year 1–4 (design Year 1, construction Years 2–4).\n- Expected benefits: substantial reduction in flood depths/failure risk in the downtown/core economic district; protects critical facilities (e.g., hospital, municipal buildings, utilities); reduces business interruption and flood-related damages; potential co-benefits for property values and tax base retention.\n- Co-benefits/quantification (order of magnitude): avoid several major flood events over 10 years; higher downtown resilience supports employment continuity and tourism.\n- Key uncertainties: exact shoreline alignment; permitting; long-term material durability; maintenance costs.\n\n2) Urban stormwater system modernization (gray-to-green hybrid)\n- What: Upgrades to conveyance (pipes, pump stations, backflow prevention), plus intensification of green-blue infrastructure (bioswales, rain gardens, permeable pavements, detention ponds) in target basins.\n- Type: Structural + non-structural (nature-based components).\n- Capital cost: $120–$140m.\n- Operating: $1–3m/year for maintenance and monitoring.\n- Timeline: Year 1–5 (design Year 1–2; construction Years 2–5).\n- Expected benefits: improved flood capture during rainfall events; reduced urban flooding frequency; improved water quality and urban heat island mitigation; supports connectivity for neighborhoods newly protected by green infrastructure.\n- Co-benefits: cost-effective comp; potential reductions in combined sewer overflows if applicable; supports local greenspace; job training for maintenance.\n\n3) Critical facilities hardening and energy resilience\n- What: Back-up power, floodproofing and protective upgrades for municipal administration, wastewater treatment, water supply, hospital, emergency operations center.\n- Type: Str ...

# %%
together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
results = ChatModel(
            model_name="gpt-5-mini",
            provider="openai"
        ).generate_response(
            messages=judge_messages,
            print_response=True
        )
# Out:
# {"results": ["2", "5", "1", "3", "4", "6"]}

# %%
results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: claude-sonnet-4-5
# Rank 2: openai/gpt-oss-120b
# Rank 3: gpt-5-nano
# Rank 4: gemini-2.5-flash
# Rank 5: deepseek-chat
# Rank 6: deepseek-r1:7b

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
