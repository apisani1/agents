# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import json
from dotenv import load_dotenv, find_dotenv
from MyCode.models import ChatModel

# %%
# Always remember to do this!
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging
from warning_beep import warning_beep

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    warning_beep(); print("\033[31mOpenAI API Key not set\033[0m")

if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    warning_beep(); print("\033[31mAnthropic API Key not set\033[0m")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    warning_beep(); print("\033[31mGoogle API Key not set\033[0m")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    warning_beep(); print("\033[31mDeepSeek API Key not set\033[0m")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    warning_beep(); print("\033[31mGroq API Key not set\033[0m")
# Out:
# OpenAI API Key exists and begins sk-3SZmF
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
question = ChatModel(
            model_name="gpt-5-mini",
            provider="openai"
        ).generate_response(
            messages=messages,
            print_response=True
        )
# Out:
# Imagine a mid-sized coastal city facing recurring floods from sea-level rise and stronger storms; it must choose exactly one of three mutually exclusive 10-year strategies: (A) build a hard seawall, (B) implement large-scale managed retreat (buyouts + relocation), or (C) invest in distributed green infrastructure and adaptive zoning. For each strategy, do all of the following concisely:
#
# 1. List the top five benefits and top five risks/costs across social, economic, environmental, and political dimensions.
# 2. Construct a simple quantitative model (specify key variables and equations) that projects annual expected net social welfare over 10 years for that strategy; state plausible baseline parameter values and sensitivity ranges, and compute projected outcomes for three scenarios (low, medium, high climate impact) with numeric estimates.
# 3. Recommend one strategy using a formal decision rule (choose and name the rule: expected value, maximin, minimax regret, etc.), show the calculation that applies the rule to your model outputs, and justify why that rule is appropriate for this city.
# 4. List the five strongest assumptions your analysis relies on and propose specific, feasible data-collection steps or pilot experiments the city could run within 18 months to test the two most critical assumptions.
# 5. Identify three ways cognitive biases, stakeholder incentives, or political constraints could cause your recommended strategy to fail in practice and propose concrete mitigations for each.
# 6. Specify the single most important annual metric the city should collect to monitor whether the chosen strategy is succeeding, explain why that metric is most informative, and give a quantitative threshold that would trigger policy reassessment.
# 7. Finally, provide a one-paragraph moral argument in support of your recommended strategy and a one-paragraph counterargument from the perspective of the least-advantaged group affected by that strategy.
#
# Present answers clearly, include numeric estimates where appropriate, and keep the full response concise.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
model_name = "gpt-5-nano"
answer = ChatModel(
            model_name=model_name,
            provider="openai"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# Below are concise, structured analyses for the three mutually exclusive 10-year strategies. All monetary figures are in millions of dollars per year, unless noted otherwise.
#
# Strategy A: Hard seawall
#
# 1) Benefits (top 5) and risks/costs (top 5)
# - Social/economic/environmental/political benefits
#   - Strong protection of fixed assets and critical infrastructure against storm surge.
#   - Higher certainty for commercial activity and waterfront property values.
#   - Short- to mid-term construction jobs and local supplier demand.
#   - Potentially lower insurance volatility for waterfront properties.
#   - Perceived city resilience boosts public confidence and investor signaling.
# - Risks/costs
#   - Very high capital cost and ongoing maintenance (O&M).
#   - Environmental disruption: shoreline habitat loss, beach erosion, altered sediment transport.
#   - False safety signal risk leading to overbuilding and riskier planning (political/policy risk).
#   - Limited adaptability to extreme tail events beyond wall height; may require upgrades.
#   - Equity concerns if benefits concentrated in wealthier districts; potential opposition.
#
# 2) Quantitative model (variables, equations, baselines, scenarios) and 10-year PV outcomes
# - Model: Annual welfare in year t
#   W_t = (1 − f_A) · D_no_t − I_A/10 − O_A + E_A
#   - D_no_t = baseline annual flood damages without strategy in year t
#   - f_A = residual damage fraction after seawall
#   - I_A = upfront capital cost; amortized as I_A/10 per year
#   - O_A = annual operations & maintenance cost
#   - E_A = annual co-benefits (ecosystem/services, property-value stabilization)
# - Baseline parameters (Strategy A)
#   - D0 = 150 (initial annual flood damages, baseline)
#   - Growth by year: low g_L = 1.5%; medium g_M = 3%; high g_H = 5%
#   - f_A = 0.25 (75% damages avoided)
#   - I_A = 400 → I_A/10 = 40 annual depreciation
#   - O_A = 15
#   - E_A = 8
# - D_no_t for each scenario (year 1…10)
#   - Low: D_no_t = 150, 152.25, 154.04, 156.96, 159.93, 162.98, 166.11, 169.29, 172.63, 176.07
#   - Medium: 150, 154.5, 159.14, 163.90, 168.87, 173.93, 179.15, 184.53, 190.07, 195.83
#   - High: 150, 157.5, 165.4, 173.7, 182.4, 191.5, 201.1, 211.1, 221.7, 232.8
# - PV results (10-year horizon, discount rate d = 3%)
#   - Low climate impact: PV_A ≈ 650
#   - Medium climate impact: PV_A ≈ 712
#   - High climate impact: PV_A ≈ 816
#
# 3) Recommendation using a formal rule
# - Rule used: Maximin (maximize the worst-case outcome)
# - Worst-case PVs across scenarios:
#   - A: 650
#   - B: 817
#   - C: 409
# - Conclusion: Strategy B (large-scale managed retreat) is recommended by the maximin rule (greatest minimum welfare across scenarios). Rationale: it’s the most robust option under climate uncertainty in this simple model.
#
# 4) Five strongest assumptions and data-collection steps
# - Assumptions
#   1) D_no_t growth/trajectory under climate scenarios is accurate (D0 and g_sc).
#   2) f_s (efficacy) of each strategy is constant over 10 years.
#   3) Capital costs I_s and annual O&M costs O_s are fixed and accurately estimated.
#   4) Annual co-benefits E_s are constant and monetizable.
#   5) Discount rate and social value of welfare are constant over the horizon; governance is stable.
# - Data-collection steps (two most critical assumptions to test within 18 months)
#   - Assumption 1 (climate damage growth): run local hazard/damage modeling and install lightweight flood sensors in representative neighborhoods to recalibrate D_no_t and g_sc using 2–3 years of local data; publish updated D_no_t trajectories every 6–12 months.
#   - Assumption 2 (efficacy of retreat): pilot a small, transparent buyout/relocation readiness exercise with 10–20 households to measure actual relocation costs, process feasibility, housing options, and social outcomes; evaluate willingness-to-relocate, costs, and post-relocation service needs.
#
# 5) Biases, incentives, constraints and mitigations
# - Bias 1: Optimism about “best outcome” under future climate (planning fallacy)
#   - Mitigation: independent third-party modeling reviews; require conservative buffers and phased milestones.
# - Bias 2: Political/campaign incentives favor rapid, visible outcomes (especially A/C)
#   - Mitigation: clear sunset clauses, independent oversight, and performance-based funding tied to milestones.
# - Bias 3: Equity and distributional concerns ignored ( hurting least-advantaged)
#   - Mitigation: embed equitable relocation safeguards (assisted housing, rental protections); community advisory board.
#
# 6) Most important annual metric and threshold
# - Metric: Annual avoided damages realized by the strategy (A_t = D_no_t − D_s,t_actual), as a share of D_no_t.
# - Why: Directly measures whether the strategy is delivering resilience and cost avoidance.
# - Threshold: If A_t < 0.5 × D_no_t for two consecutive years, trigger policy reassessment and plan adjustment (e.g., adjust f_s or costs, reconsider phasing).
#
# 7) Moral argument and counterargument
# - Moral argument (in support of retreat): A managed retreat prioritizes long-term safety and equity by moving people and assets from chronically flooded zones to safer, sustainable housing and communities, reducing preventable suffering and widening access to resilient infrastructure. It aligns with precautionary ethics: when climate risks rise steeply, proactive relocation minimizes avoidable harm and protects vulnerable households from repeated exposure to severe floods.
# - Counterargument from least-advantaged group: The retreat imposes involuntary displacement, breaking social networks, breaking up neighborhoods, and eroding access to affordable housing and local services. For many low-income residents, relocation may mean higher housing costs, disruption of jobs and schools, and cultural loss, amplifying inequality. Without robust protections, replacement housing access and community continuity will fail those most in need.
#
# Strategy B: Large-scale managed retreat (buyouts + relocation)
#
# 1) Benefits (top 5) and risks/costs (top 5)
# - Benefits
#   - Substantial long-term reduction in flood damages and risk to lives.
#   - Potentially lower ongoing maintenance compared with hard seawalls.
#   - Opportunity to rebuild in safer locations with modern zoning and infrastructure.
#   - Better alignment with biodiversity and natural landscape restoration; possible ecosystem gains.
#   - Predictable, scalable relocation process; potential for affordable housing and social services in new locations.
# - Risks/costs
#   - Large upfront capital costs and ongoing relocation/subsidy expenses.
#   - Deep social disruption; potential loss of community networks and cultural ties.
#   - Political and legal fights over property rights, due process, and equity in buyouts.
#   - Tax base erosion and revenue loss if primary property tax base relocates.
#   - Resistance from long-time residents and potential inequitable outcomes if not designed inclusively.
#
# 2) Quantitative model (variables, equations, baselines, scenarios) and 10-year PV outcomes
# - Model: Annual welfare in year t
#   W_t = (1 − f_B) · D_no_t − I_B/10 − O_B + E_B
#   - D_no_t as above
#   - f_B = residual damage fraction after retreat
#   - I_B = upfront capital cost; amortized as I_B/10
#   - O_B = annual O&M (post-relocation governance, maintenance, services)
#   - E_B = annual co-benefits (ecosystem services, avoided relocation stress costs, new amenities)
# - Baseline parameters (Strategy B)
#   - f_B = 0.20 (80% damages avoided)
#   - I_B = 350 → I_B/10 = 35
#   - O_B = 5
#   - E_B = 4
# - D_no_t values: same as Strategy A per scenario
# - PV results (10-year horizon, d = 3%)
#   - Low climate impact: PV_B ≈ 817
#   - Medium climate impact: PV_B ≈ 884
#   - High climate impact: PV_B ≈ 994
#
# 3) Recommendation using a formal rule
# - Rule used: Maximin (as above)
# - PVs by strategy under maximin:
#   - A: min = 650
#   - B: min = 817
#   - C: min = 409
# - Conclusion: Strategy B is the recommended option using maximin; it offers the strongest worst-case performance across climate trajectories.
#
# 4) Five strongest assumptions and data-collection steps
# - Assumptions
#   1) D_no_t baseline and its growth under climate scenarios are accurate.
#   2) f_B (efficacy of retreat) remains near 0.20 over 10 years.
#   3) I_B and O_B costs stay within projected bounds; no major financing shocks.
#   4) E_B (annual co-benefits) are realizable and monetizable.
#   5) Relocation implementation can be scaled equitably with adequate housing options.
# - Data-collection steps (two most critical)
#   - Assumption 1: Build a 12–18 month pilot buyout readiness in a small neighborhood (20–30 households) to measure actual costs, timelines, and resettlement support needs; track displacement outcomes.
#   - Assumption 2: Establish a 12–18 month neighborhood-scale relocation planning and housing inventory study to assess availability, affordability, and social cohesion outcomes in potential receiving areas; pilot affordable housing options and service provisions.
#
# 5) Biases, incentives, constraints and mitigations
# - Bias 1: Predicted relocation benefits overestimate social acceptance; mitigations: independent social impact assessments, value community input, and phased buyouts with opt-out options.
# - Bias 2: Property-owner incentives dominate; mitigations: inclusive compensation frameworks, long-term housing assistance, and community equity considerations.
# - Bias 3: Fiscal constraints and political risk of large up-front costs; mitigations: stepwise funding, blended finance, clear accountability, performance milestones, and transparent budgeting.
#
# 6) Most important annual metric and threshold
# - Metric: Annual avoided damages realized by retreat (A_t = D_no_t − D_s,t_actual) relative to D_no_t.
# - Threshold: If A_t < 0.5 × D_no_t for two consecutive years, trigger plan reassessment (e.g., adjust buyout terms, housing options, or scale back).
#
# 7) Moral argument and counterargument
# - Moral argument: A managed retreat emphasizes minimizing future harm and ensuring safer, more equitable living conditions; by relocating people from high-risk areas to better housing and services, it prevents repeated flood trauma and supports long-term adaptation in a fairer way.
# - Counterargument from least-advantaged group: A mass relocation can sever social networks, undermine livelihoods, and displace communities without guaranteeing affordable, suitable replacement housing; without strong protections and supports, the burden falls on the most vulnerable, widening inequality.
#
# Strategy C: Distributed green infrastructure and adaptive zoning
#
# 1) Benefits (top 5) and risks/costs (top 5)
# - Benefits
#   - Flexible, scalable, and climate-adaptive; minimal hard infrastructure footprint.
#   - Co-benefits: cooler urban heat island mitigation, improved air/water quality, biodiversity, recreational value.
#   - Potentially lower long-run O&M costs versus hard structures; job opportunities in green tech and design.
#   - Encourages resilient land-use and zoning that accommodates sea-level rise while preserving equity.
#   - Improves urban livability and property resilience through diversified protection.
# - Risks/costs
#   - Performance uncertainty in extreme events; effectiveness depends on maintenance and governance.
#   - Coordination challenges across multiple agencies, landowners, and jurisdictions.
#   - Higher upfront design/implementation costs; risk of uneven adoption across neighborhoods.
#   - Maintenance requirements and funding stability for long-term performance.
#   - Property development tensions and potential land-use conflicts.
#
# 2) Quantitative model (variables, equations, baselines, scenarios) and 10-year PV outcomes
# - Model: Annual welfare in year t
#   W_t = (1 − f_C) · D_no_t − I_C/10 − O_C + E_C
#   - f_C = residual damage fraction after green infrastructure/adaptive zoning
#   - I_C = upfront capital cost; amortized as I_C/10
#   - O_C = annual O&M
#   - E_C = annual co-benefits
# - Baseline parameters (Strategy C)
#   - f_C = 0.60 (40% damages avoided)
#   - I_C = 180 → I_C/10 = 18
#   - O_C = 6
#   - E_C = 6
# - D_no_t values: as above (D0 = 150; growth by g_sc for each scenario)
# - PV results (10-year horizon, d = 3%)
#   - Low climate impact: PV_C ≈ 409
#   - Medium climate impact: PV_C ≈ 442
#   - High climate impact: PV_C ≈ 497
#
# 3) Recommendation using a formal rule
# - Rule used: Maximin
# - Min PVs:
#   - A: 650
#   - B: 817
#   - C: 409
# - Conclusion: Strategy B is still the strongest under maximin; Strategy C yields the lowest minimum PV and is thus least robust in this simple model.
#
# 4) Five strongest assumptions and data-collection steps
# - Assumptions
#   1) Growth of flood damages (D_no_t) and climate scenario trajectories are accurate.
#   2) E_C (co-benefits) and f_C (efficacy of green/adaptive zoning) are reliable and stable.
#   3) I_C and O_C cost projections hold; maintenance is funded.
#   4) Adaptive zoning can be implemented without major regulatory obstacles.
#   5) Interactions with private landholdings and parks are manageable.
# - Data-collection steps (two most critical)
#   - Assumption 1: Implement a two-neighborhood green-infrastructure pilot with rigorous pre/post flood frequency and severity measurements, plus cost tracking for maintenance; use results to recalibrate E_C and f_C.
#   - Assumption 2: Establish a cross-departmental adaptive zoning pilot in a few blocks, measuring land-use changes, permit timelines, and enforcement costs; evaluate spillovers and compliance rates.
#
# 5) Biases, incentives, constraints and mitigations
# - Bias 1: Green optimism bias; mitigations: independent performance metrics; staged pilots with external verification.
# - Bias 2: Land-use conflicts and development interests; mitigations: community input, transparent compensation, and equitable access to green spaces.
# - Bias 3: Funding instability for ongoing maintenance; mitigations: dedicated green-infrastructure reserve funds and public-private partnerships.
#
# 6) Most important annual metric and threshold
# - Metric: Annual avoided damages realized by green/infrastructure and adaptive zoning (A_t).
# - Threshold: If A_t < 0.3 × D_no_t for two consecutive years, trigger a re-evaluation of design standards and funding strategy, with a pause in new installations.
#
# 7) Moral argument and counterargument
# - Moral argument: Distributed green infrastructure and adaptive zoning maximize long-term resilience with flexibility, co-benefits, and lower social disruption, advancing public health and equity while avoiding the permanence and displacement risks of retreat.
# - Counterargument from least-advantaged group: If green infrastructure prioritizes affluent neighborhoods or ornamental projects over affordable housing and job access, the least-advantaged may endure ongoing exposure or face gentrification pressures, while benefits are unevenly distributed.
#
# 7-paragraph closing: Recommendation and ethics
# - Most important take: Based on the explicit 10-year, scenario-based PV calculations and a maximin decision rule, Strategy B (large-scale managed retreat) emerges as the most robust option under climate uncertainty, delivering the highest minimum welfare across low/medium/high climate impact scenarios. The retreat strategy also aligns with equity-focused risk reduction when designed with strong protections, housing options, and supports. Strategy C offers substantial co-benefits but carries higher risks of underperformance; Strategy A provides strong protection but at very high upfront cost and environmental trade-offs, and it remains brittle to tail events.
# - Final moral framing: The city should pursue Strategy B if paired with robust safeguards—transparent buyout processes, guaranteed affordable replacement housing, and strong social supports—to minimize long-term risk while protecting the most vulnerable from repeated flood harms. This path prioritizes human safety and dignity, preventing recurrent disaster exposure and ensuring that relocation decisions are rights-respecting and equity-centered.
# - Final counterfactual framing: If safeguards fail to protect the least advantaged—for example, if relocations are rushed, housing is unaffordable, or communities are split without services—the retreat could exacerbate poverty, disrupt social networks, and erode trust in civic institutions. Any retreat plan must embed enforceable equity standards, durable housing options, and sustained community engagement to avoid repeating past injustices.
#
# Bottom line: Strategy B (managed retreat) is the recommended course under a maximin approach, with detailed plans and pilots to test two critical assumptions (damages growth and feasibility/equity of buyouts) within 18 months, plus robust mitigations for biases and political constraints. The city should proceed with a staged, equity-centered retreat program while continuing enhanced green options as a complementary strategy where feasible and affordable.

# %%
model_name = "claude-sonnet-4-5"
answer = ChatModel(
            model_name=model_name,
            provider="anthropic"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# # Coastal Flood Resilience Strategy Analysis
#
# ## Strategy A: Hard Seawall
#
# ### 1. Benefits and Risks
#
# **Top 5 Benefits:**
# - Provides immediate, measurable protection for high-value downtown/waterfront areas (~$2B in protected assets)
# - Clear psychological reassurance for residents and businesses; stabilizes property values short-term
# - Generates construction jobs (est. 500 jobs over 3 years)
# - Simplicity in implementation and monitoring; well-understood engineering
# - Preserves existing land use patterns; minimal displacement
#
# **Top 5 Risks/Costs:**
# - High capital cost ($150-300M for mid-sized city) with limited flexibility if climate exceeds design parameters
# - Creates false security; encourages continued high-risk development in protected zone
# - Environmental damage: disrupts sediment transport, beach erosion, habitat loss for coastal species
# - Inequity: protects wealthy waterfront while low-lying inland areas remain vulnerable
# - Political backlash from environmental groups and unprotected neighborhoods; maintenance cost escalation ($2-5M annually)
#
# ### 2. Quantitative Model
#
# **Variables:**
# - **P** = Property value protected ($2B baseline)
# - **D(t)** = Annual expected flood damage without intervention (year t)
# - **E** = Seawall effectiveness (% damage reduction: 0.85 baseline)
# - **C₀** = Capital cost ($200M baseline)
# - **M** = Annual maintenance (% of C₀: 1.5% baseline)
# - **r** = Social discount rate (3%)
# - **I** = Indirect costs: environmental/social ($5M/year baseline)
#
# **Equation:**
# ```
# Net Social Welfare (year t) = E × D(t) - [C₀/10 + M×C₀ + I]
#
# 10-year NPV = Σ(t=1 to 10) [E × D(t) - (C₀/10 + M×C₀ + I)] / (1+r)^t
# ```
#
# **Baseline D(t):**
# - Low climate: D(t) = $25M × (1.02)^t
# - Medium climate: D(t) = $35M × (1.04)^t
# - High climate: D(t) = $50M × (1.06)^t
#
# **Scenario Outcomes (10-year NPV):**
# - **Low impact:** Benefits = $232M, Costs = $226M → **Net +$6M**
# - **Medium impact:** Benefits = $340M, Costs = $226M → **Net +$114M**
# - **High impact:** Benefits = $503M (but seawall overtopped years 8-10, E drops to 0.6) → **Net +$177M**
#
# ---
#
# ## Strategy B: Managed Retreat
#
# ### 1. Benefits and Risks
#
# **Top 5 Benefits:**
# - Eliminates long-term flood risk for relocated households; removes people from harm's way permanently
# - Restores natural buffer zones; environmental co-benefits (wetland creation, carbon sequestration)
# - Avoids escalating maintenance and emergency response costs in high-risk zones
# - Equitable if buyouts at fair market value; opportunity to address historic housing disparities
# - Frees land for adaptive reuse (parks, natural infrastructure) generating recreation/tourism value
#
# **Top 5 Risks/Costs:**
# - Extreme upfront cost ($250-400M for buyouts, demolition, infrastructure decommissioning)
# - Community disruption: loss of social networks, cultural heritage, historic neighborhoods
# - Political opposition from property owners unwilling to relocate; lengthy negotiation/litigation
# - Economic contraction: reduced tax base, business closures, population loss without coordinated economic development
# - Implementation complexity: coordinating housing supply, schools, utilities in receiving areas
#
# ### 2. Quantitative Model
#
# **Variables:**
# - **H** = Households relocated (800 baseline)
# - **B** = Average buyout cost per household ($350K baseline)
# - **R** = Relocation support per household ($50K)
# - **L** = Lost tax revenue (NPV: $80M over 10 years)
# - **S** = Avoided future damages and emergency costs (per household annually)
# - **G** = Green infrastructure co-benefits ($3M/year from restored wetlands)
#
# **Equation:**
# ```
# Net Social Welfare (10-year NPV) = Σ(t=1 to 10) [H×S(t) + G - L/10] / (1+r)^t - H×(B+R)
#
# Where S(t) varies by climate scenario
# ```
#
# **S(t) per household:**
# - Low climate: $15K/year (avoided damage/insurance)
# - Medium climate: $25K/year
# - High climate: $40K/year
#
# **Scenario Outcomes:**
# - **Low impact:** Benefits = $148M, Costs = $320M → **Net -$172M**
# - **Medium impact:** Benefits = $253M, Costs = $320M → **Net -$67M**
# - **High impact:** Benefits = $418M, Costs = $320M → **Net +$98M**
#
# ---
#
# ## Strategy C: Distributed Green Infrastructure + Adaptive Zoning
#
# ### 1. Benefits and Risks
#
# **Top 5 Benefits:**
# - Flexible and scalable; can phase implementation and adjust to observed climate trends
# - Multiple co-benefits: water quality, urban heat reduction, recreation, biodiversity, mental health
# - Distributes protection across city; more equitable than concentrated seawall
# - Lower upfront cost ($80-120M); spreads investment over time
# - Political feasibility: diverse coalition of supporters (environmentalists, business, neighborhoods)
#
# **Top 5 Risks/Costs:**
# - Uncertain effectiveness; less proven at scale; performance varies by location/design
# - Requires sustained coordination across multiple agencies and property owners
# - Zoning changes face legal challenges and grandfather clause demands
# - Provides only moderate flood reduction (30-50%); residual risk remains significant
# - Long implementation timeline; benefits accrue slowly while exposure continues
#
# ### 2. Quantitative Model
#
# **Variables:**
# - **C_GI** = Green infrastructure capital ($100M over 10 years)
# - **E_GI** = Effectiveness (% reduction in damages: 0.40 baseline, increases over time)
# - **Z** = Adaptive zoning benefits (reduced future development in risk zones)
# - **Co** = Co-benefits (health, recreation, environment: $4M/year)
# - **A** = Administrative costs ($1.5M/year)
#
# **Equation:**
# ```
# E_GI(t) = 0.15 + 0.025×t  (effectiveness grows as projects mature)
#
# Net Social Welfare (year t) = E_GI(t) × D(t) + Co - [C_GI/10 + A]
#
# 10-year NPV = Σ(t=1 to 10) [E_GI(t) × D(t) + Co - C_GI/10 - A] / (1+r)^t
# ```
#
# **Scenario Outcomes:**
# - **Low impact:** Benefits = $156M, Costs = $115M → **Net +$41M**
# - **Medium impact:** Benefits = $227M, Costs = $115M → **Net +$112M**
# - **High impact:** Benefits = $338M, Costs = $115M → **Net +$223M**
#
# ---
#
# ## 3. Recommendation Using Decision Rule
#
# **Decision Rule Selected: Maximin (Rawls' criterion)**
#
# **Justification:** Coastal flooding poses catastrophic and irreversible risks to vulnerable populations. The city has moral obligations to protect the least-advantaged residents who cannot self-insure against climate shocks. Maximin focuses on the worst-case scenario—appropriate when:
# 1. Downside risks include loss of life and community destruction
# 2. Uncertainty about climate trajectory is profound
# 3. Intergenerational equity matters (protecting future residents)
#
# **Calculation:**
#
# Worst-case (Low Climate Impact) outcomes:
# - Strategy A (Seawall): **+$6M**
# - Strategy B (Managed Retreat): **-$172M**
# - Strategy C (Green Infrastructure): **+$41M**
#
# **Under maximin, choose Strategy C** (highest worst-case outcome).
#
# Additional check using expected value (assuming equal probability):
# - Strategy A: ($6M + $114M + $177M)/3 = **$99M**
# - Strategy B: (-$172M - $67M + $98M)/3 = **-$47M**
# - Strategy C: ($41M + $112M + $223M)/3 = **$125M**
#
# **Strategy C dominates on both maximin and expected value criteria.**
#
# ---
#
# ## 4. Critical Assumptions and Testing
#
# **Five Strongest Assumptions:**
#
# 1. **Green infrastructure effectiveness reaches 40% average flood reduction** (highly uncertain; site-specific)
# 2. **Seawall provides 85% protection and doesn't fail catastrophically** (assumes proper maintenance and design adequacy)
# 3. **Climate impacts follow smooth exponential trends** (ignores tipping points, extreme events)
# 4. **Co-benefits valued at $4M/year are realized and sustained** (depends on maintenance and community use)
# 5. **Discount rate of 3% appropriately values intergenerational welfare** (contentious for climate ethics)
#
# **Testing the Two Most Critical Assumptions:**
#
# **Assumption 1 Test (Green Infrastructure Effectiveness):**
# - **Pilot experiment:** Select 3 representative neighborhoods (high-density, low-density, mixed-use)
# - Install scaled green infrastructure: bioswales, permeable pavement, rain gardens, detention basins ($2M total)
# - Instrument sites with stream gauges, groundwater monitors, and flood sensors
# - Collect data through next wet season and one hurricane event
# - **Metric:** Measure peak flow reduction, infiltration rates, and modeled flood extent
# - **Timeline:** 18 months including one full wet season
# - **Decision:** If peak flow reduction <20%, revise E_GI downward or pivot strategy
#
# **Assumption 4 Test (Co-benefits Valuation):**
# - **Data collection:** Commission hedonic property value study in neighborhoods with existing green infrastructure vs. comparable areas without
# - Conduct stated-preference survey (1,000 residents) on willingness-to-pay for water quality, recreation access, urban heat reduction
# - Partner with public health department to track ER visits for heat stress and respiratory issues in pilot areas
# - Monitor park usage via trail counters and observational studies
# - **Timeline:** 12-15 months for surveys and initial health data
# - **Decision:** If property premium <2% and health benefits minimal, reduce Co estimate by 50%
#
# ---
#
# ## 5. Implementation Risks and Mitigations
#
# **Risk 1: Availability Bias / Crisis-Driven Reversal**
# - **Mechanism:** After a major flood event, public demands immediate visible action. Green infrastructure appears "soft" compared to dramatic seawall construction. Political leaders cave to pressure for hard infrastructure.
# - **Mitigation:**
#   - Pre-commit via ordinance requiring super-majority vote to change strategy within 10-year window
#   - Establish independent Resilience Board with staggered terms insulated from election cycles
#   - Create real-time flood visualization system showing green infrastructure performance during rain events
#   - Rapid-response communication protocol: within 48 hours of flood, publish data comparing outcomes in green infrastructure areas vs. unprotected zones
#
# **Risk 2: Free-Rider Problem / Inadequate Private Property Owner Participation**
# - **Mechanism:** Adaptive zoning and distributed green infrastructure require voluntary or mandated actions by hundreds of property owners. Holdouts undermine system effectiveness. Business owners lobby for exemptions.
# - **Mitigation:**
#   - Implement "green infrastructure utility" with mandatory stormwater fees funding public projects, creating shared ownership
#   - Offer 75% cost-sharing grants for private property improvements (rain gardens, permeable driveways) with expedited permitting
#   - Adopt graduated development fee schedule: projects in high-risk zones pay 3x standard fees, revenue funds buyouts or resilience measures
#   - Publicize "Resilience Leader" designation for compliant businesses (marketing value)
#
# **Risk 3: Status Quo Bias in Zoning Decisions**
# - **Mechanism:** Adaptive zoning threatens existing property rights and development expectations. Wealthy property owners hire lawyers; planning board grants variances; zoning becomes Swiss cheese.
# - **Mitigation:**
#   - Establish zoning overlay district with explicit climate criteria; remove discretionary variance authority for flood zones
#   - Transfer development rights program: allow increased density in safe zones in exchange for downzoning high-risk areas (revenue-neutral for developers)
#   - Mandatory disclosure law: all property sales in risk zones must include standardized flood projection statement (changes buyer calculus)
#   - Annual public "State of Resilience" report showing map of variances granted vs. denied with projected cost to taxpayers
#
# ---
#
# ## 6. Key Monitoring Metric
#
# **Metric: Annual Cumulative Flood Volume Reduction Index (FVRI)**
#
# **Definition:**
# ```
# FVRI(t) = 1 - [Observed flood volume in year t / Counterfactual flood volume without intervention]
# ```
#
# Measured in percentage reduction, adjusted for annual precipitation variation using regional climate controls.
#
# **Why Most Informative:**
# - **Direct performance measure:** Captures actual water management, not just inputs (spending) or proxies (acres of green space)
# - **Accounts for climate variability:** Normalizing against counterfactual separates strategy effectiveness from weather fluctuations
# - **Integrates distributed impacts:** Single index aggregates performance across multiple project sites
# - **Predictive of damages:** Flood volume correlates strongly with property damage, health impacts, and emergency costs
# - **Verifiable and transparent:** Based on physical measurements (sensor network); resistant to political manipulation
#
# **Data Collection:**
# - Deploy distributed sensor network (50 nodes: stream gauges, depth sensors, rain gauges)
# - Establish counterfactual using calibrated hydrological model (SWMM or HEC-RAS) validated against pre-intervention data
# - Annual report by independent university partnership
#
# **Reassessment Threshold:**
# - **Trigger policy review if FVRI < 25% for two consecutive years** (suggesting green infrastructure severely underperforming)
# - OR if **cumulative property damage in years 1-5 exceeds $100M** (indicating residual risk unacceptable)
# - OR if **co-benefit index (composite of property values, park usage, water quality) falls below 70% of projected values**
#
# ---
#
# ## 7. Moral Arguments
#
# **Support for Strategy C (Green Infrastructure + Adaptive Zoning):**
#
# Coastal cities face a moral imperative to build resilience in ways that honor both intergenerational justice and environmental stewardship. Strategy C embodies this dual obligation by refusing the Faustian bargain of seawalls—which protect today's wealthy at the cost of ecological destruction and escalating risk for tomorrow's residents—and the harsh displacement of managed retreat. Distributed green infrastructure respects the intrinsic value of natural systems while providing flexible, equitable protection that adapts as climate science evolves. By spreading benefits across neighborhoods rather than concentrating them at the waterfront, this approach recognizes the equal moral worth of all residents regardless of property values. The strategy acknowledges uncertainty with humility: we cannot perfectly predict 2050's climate, so we must build systems that learn and evolve rather than inflexible monuments to today's flawed models. Most critically, green infrastructure creates positive-sum outcomes—cleaner water, cooler streets, recreational access, habitat restoration—that improve quality of life beyond mere flood protection, affirming that climate adaptation should enhance human flourishing, not merely delay catastrophe.
#
# **Counterargument from Least-Advantaged Perspective (Low-Income Inland Residents):**
#
# While green infrastructure sounds appealing in theory, it represents another instance of environmental policy serving as cover for inaction that leaves vulnerable communities exposed. We live in the city's low-lying inland neighborhoods—historically redlined, systematically underinvested, already flooding from inadequate drainage—and this "distributed" strategy will distribute benefits exactly as every other policy has: the wealthy waterfront gets bioswales and rain gardens while we get excuses. The reality is that $100M spread citywide means token projects, not transformational protection, and adaptive zoning will inevitably grandfather expensive waterfront properties while restricting what little development opportunity exists in our neighborhoods. We cannot afford to wait 10 years for scattered green infrastructure to "mature" while our children develop asthma from mold and our uninsured neighbors lose everything in the next hurricane. The city's willingness to reject immediate, proven protection via seawalls or permanent escape via buyouts reveals that decision-makers with insurance and mobility can afford to experiment with our safety. We need protection now, not ecological aesthetics for future generations who may never include us if we're displaced by the next flood the city was too "innovative" to prevent.

# %%
model_name = "gemini-2.5-flash"
answer = ChatModel(
            model_name=model_name,
            provider="google",
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# The coastal city must choose one of three 10-year strategies to combat recurring floods.
#
# ---
#
# ### Strategy A: Build a Hard Seawall
#
# 1.  **Top Five Benefits:**
#     *   **Direct Flood Protection:** Provides immediate and substantial protection to inland properties from storm surges and high tides.
#     *   **Sense of Security:** Offers psychological reassurance to residents and businesses within the protected zone.
#     *   **Economic Stability (Protected Zone):** Reduces immediate flood insurance premiums and encourages continued investment in protected areas.
#     *   **Predictable Engineering:** Construction is based on well-established engineering principles with clear project scope.
#     *   **High Visible Impact:** Tangible structure demonstrates clear government action to address flooding.
#
# 2.  **Top Five Risks/Costs:**
#     *   **High Capital & Maintenance Costs:** Requires significant upfront investment and ongoing upkeep; susceptible to cost overruns.
#     *   **Environmental Degradation:** Destroys coastal habitats (beaches, dunes, wetlands), disrupts natural sediment transport, and impacts marine life.
#     *   **"Levee Effect" & Catastrophic Failure:** Creates a false sense of security, potentially encouraging development in vulnerable areas, leading to more severe damage if breached.
#     *   **Limited Lifespan/Adaptability:** May become obsolete with accelerating sea-level rise or stronger storms, requiring costly upgrades or new solutions.
#     *   **Social & Aesthetic Impacts:** Blocks views, restricts public access to the waterfront, and can fragment communities.
#
# 3.  **Quantitative Model (Annual Expected Net Social Welfare over 10 years):**
#     *   **Variables:**
#         *   `AD_Baseline_s`: Annual baseline flood damages in scenario `s` (Low, Medium, High climate impact).
#         *   `Eff_A`: Effectiveness of seawall in reducing `AD_Baseline_s`.
#         *   `C_Cap_Ann_A`: Annualized capital cost of seawall.
#         *   `C_OM_Ann_A`: Annual Operations & Maintenance cost of seawall.
#         *   `NSW_Other_A`: Net annual social and environmental welfare effects (benefits - costs) of seawall, excluding direct flood damage reduction and capital/O&M.
#     *   **Equation:** `Annual_NSW_s = (AD_Baseline_s * Eff_A) + NSW_Other_A - C_Cap_Ann_A - C_OM_Ann_A`
#     *   **Plausible Baseline Parameters & Sensitivity Ranges:**
#         *   `AD_Baseline`: Low $30M, Medium $50M, High $80M (per year).
#         *   `Eff_A`: 0.90 (Sensitivity: +/- 0.10)
#         *   `C_Cap_Ann_A`: $50M/year (Total $500M over 10 years; Sensitivity: +/- 20%)
#         *   `C_OM_Ann_A`: $5M/year (Sensitivity: +/- 20%)
#         *   `NSW_Other_A`: -$12M/year (Environmental costs -$10M, Social costs -$2M; Sensitivity: +/- 50%)
#     *   **Projected Outcomes for 3 Scenarios (Total NSW over 10 years in M$):**
#         *   **Low Climate Impact:** (30 * 0.90) - 12 - 50 - 5 = -$40M/year => **-$400M** (Total)
#         *   **Medium Climate Impact:** (50 * 0.90) - 12 - 50 - 5 = -$22M/year => **-$220M** (Total)
#         *   **High Climate Impact:** (80 * 0.90) - 12 - 50 - 5 = $5M/year => **$50M** (Total)
#
# ---
#
# ### Strategy B: Large-Scale Managed Retreat
#
# 1.  **Top Five Benefits:**
#     *   **Long-Term Resilience:** Permanently removes assets from harm's way, offering ultimate protection from sea-level rise and storms.
#     *   **Ecosystem Restoration:** Creates opportunities for natural habitats (wetlands, dunes) to recover, providing natural flood buffers and biodiversity benefits.
#     *   **Reduced Future Costs:** Eliminates the need for ongoing flood protection infrastructure and reduces future disaster relief expenditures in retreated areas.
#     *   **Public Safety:** Ensures populations are out of the highest-risk zones, improving safety during extreme events.
#     *   **Innovation & New Opportunities:** Encourages rethinking urban planning and fosters new economic activities in safer zones.
#
# 2.  **Top Five Risks/Costs:**
#     *   **Extremely High Social Disruption:** Forces displacement of residents, breakup of communities, and loss of familiar places and social networks.
#     *   **Massive Capital Costs:** Buyouts and relocation assistance are incredibly expensive, potentially straining municipal budgets significantly.
#     *   **Economic Displacement:** Loss of tax revenue from retreated areas and potential decline in local businesses due to population shifts.
#     *   **Political Resistance:** Highly unpopular due to property rights issues, emotional attachments, and perceived government overreach.
#     *   **Equity Concerns:** Risk of disproportionately impacting vulnerable populations who may have fewer resources to relocate or struggle to find comparable housing.
#
# 3.  **Quantitative Model (Annual Expected Net Social Welfare over 10 years):**
#     *   **Variables:**
#         *   `AD_Baseline_s`: Annual baseline flood damages in scenario `s`.
#         *   `Eff_B`: Effectiveness of managed retreat in reducing `AD_Baseline_s`.
#         *   `C_Cap_Ann_B`: Annualized capital cost of buyouts and relocation.
#         *   `C_OM_Ann_B`: Annual land management cost in retreated areas.
#         *   `NSW_Other_B`: Net annual social and environmental welfare effects (benefits - costs).
#     *   **Equation:** `Annual_NSW_s = (AD_Baseline_s * Eff_B) + NSW_Other_B - C_Cap_Ann_B - C_OM_Ann_B`
#     *   **Plausible Baseline Parameters & Sensitivity Ranges:**
#         *   `AD_Baseline`: Low $30M, Medium $50M, High $80M (per year).
#         *   `Eff_B`: 0.80 (Assumes gradual effect over 10 years, not immediate 100%; Sensitivity: +/- 0.10)
#         *   `C_Cap_Ann_B`: $100M/year (Total $1B over 10 years; Sensitivity: +/- 20%)
#         *   `C_OM_Ann_B`: $2M/year (Sensitivity: +/- 20%)
#         *   `NSW_Other_B`: -$15M/year (Environmental benefits +$15M, Social costs -$30M; Sensitivity: +/- 50%)
#     *   **Projected Outcomes for 3 Scenarios (Total NSW over 10 years in M$):**
#         *   **Low Climate Impact:** (30 * 0.80) - 15 - 100 - 2 = -$93M/year => **-$930M** (Total)
#         *   **Medium Climate Impact:** (50 * 0.80) - 15 - 100 - 2 = -$77M/year => **-$770M** (Total)
#         *   **High Climate Impact:** (80 * 0.80) - 15 - 100 - 2 = -$53M/year => **-$530M** (Total)
#
# ---
#
# ### Strategy C: Green Infrastructure & Adaptive Zoning
#
# 1.  **Top Five Benefits:**
#     *   **Multiple Co-benefits:** Improves water quality, enhances biodiversity, creates green spaces for recreation, reduces urban heat island effect, and fosters community engagement.
#     *   **Flexible & Adaptable:** Can be phased in and adjusted over time as climate impacts evolve and understanding improves.
#     *   **Cost-Effective over Time:** Generally lower capital costs than hard structures, with natural systems potentially self-maintaining over time.
#     *   **Community Enhancement:** Creates more livable, attractive neighborhoods and can increase property values in areas with enhanced green amenities.
#     *   **Works with Nature:** Employs natural processes to manage water, promoting long-term ecological resilience.
#
# 2.  **Top Five Risks/Costs:**
#     *   **Slower & Less Obvious Impact:** Benefits can take time to materialize and may not be as immediately perceptible as a large seawall, potentially leading to skepticism.
#     *   **Requires Broad Public Buy-in:** Success depends on widespread adoption by private landowners, developers, and ongoing community stewardship.
#     *   **Complex Implementation:** Involves coordinating multiple agencies, property owners, and diverse projects across the city.
#     *   **Residual Risk:** May not provide adequate protection against extreme, unforeseen events, and some areas may remain vulnerable.
#     *   **Property Value Impacts:** Adaptive zoning (e.g., density restrictions, setback requirements) could depress property values in certain areas, leading to resistance.
#
# 3.  **Quantitative Model (Annual Expected Net Social Welfare over 10 years):**
#     *   **Variables:**
#         *   `AD_Baseline_s`: Annual baseline flood damages in scenario `s`.
#         *   `Eff_C`: Effectiveness of green infrastructure/adaptive zoning in reducing `AD_Baseline_s`.
#         *   `C_Cap_Ann_C`: Annualized capital cost of green infrastructure projects.
#         *   `C_OM_Ann_C`: Annual Operations & Maintenance cost of green infrastructure.
#         *   `NSW_Other_C`: Net annual social and environmental welfare effects (benefits - costs).
#     *   **Equation:** `Annual_NSW_s = (AD_Baseline_s * Eff_C) + NSW_Other_C - C_Cap_Ann_C - C_OM_Ann_C`
#     *   **Plausible Baseline Parameters & Sensitivity Ranges:**
#         *   `AD_Baseline`: Low $30M, Medium $50M, High $80M (per year).
#         *   `Eff_C`: 0.70 (Sensitivity: +/- 0.10)
#         *   `C_Cap_Ann_C`: $30M/year (Total $300M over 10 years; Sensitivity: +/- 20%)
#         *   `C_OM_Ann_C`: $7M/year (Sensitivity: +/- 20%)
#         *   `NSW_Other_C`: $15M/year (Environmental benefits +$20M, Social benefits +$5M; Sensitivity: +/- 50%)
#     *   **Projected Outcomes for 3 Scenarios (Total NSW over 10 years in M$):**
#         *   **Low Climate Impact:** (30 * 0.70) + 15 - 30 - 7 = -$1M/year => **-$10M** (Total)
#         *   **Medium Climate Impact:** (50 * 0.70) + 15 - 30 - 7 = $13M/year => **$130M** (Total)
#         *   **High Climate Impact:** (80 * 0.70) + 15 - 30 - 7 = $34M/year => **$340M** (Total)
#
# ---
#
# ### 3. Recommendation
#
# **Decision Rule:** Expected Value
#
# **Calculation:**
# Assign probabilities to climate impact scenarios: P(Low) = 0.2, P(Medium) = 0.5, P(High) = 0.3.
#
# *   **Expected Value (Strategy A - Seawall):**
#     (0.2 * -$400M) + (0.5 * -$220M) + (0.3 * $50M) = -$80M - $110M + $15M = **-$175M**
# *   **Expected Value (Strategy B - Managed Retreat):**
#     (0.2 * -$930M) + (0.5 * -$770M) + (0.3 * -$530M) = -$186M - $385M - $159M = **-$730M**
# *   **Expected Value (Strategy C - Green Infrastructure):**
#     (0.2 * -$10M) + (0.5 * $130M) + (0.3 * $340M) = -$2M + $65M + $102M = **$165M**
#
# **Recommendation:** Based on the Expected Value decision rule, **Strategy C: Invest in Distributed Green Infrastructure and Adaptive Zoning** is recommended, as it yields the highest projected net social welfare over 10 years ($165M).
#
# **Justification:** The Expected Value rule is appropriate for this city because it accounts for the probabilistic nature of future climate impacts and aims to maximize average long-term social welfare. Given the 10-year planning horizon and the inherent uncertainties of climate change, the city needs a strategy that performs well across a range of plausible futures, not just the best or worst case. This rule balances the potential benefits against the costs and risks, making it suitable for a public investment decision where the city aims for overall societal gain.
#
# ---
#
# ### 4. Assumptions and Testing
#
# **Five Strongest Assumptions:**
# 1.  **Accurate Monetization of Social and Environmental Impacts:** Assuming reliable methods to assign monetary values to non-market goods like ecosystem services, community cohesion, and aesthetic quality.
# 2.  **Effectiveness of Strategies Against Varying Climate Impacts:** Assuming the specified percentage reductions in flood damages for each strategy hold true across the spectrum of low to high climate impact scenarios.
# 3.  **Availability and Stability of Funding:** Assuming the city can secure the necessary capital and operational funds for 10 years without significant political or economic interruptions.
# 4.  **Public Acceptance and Behavioral Response:** Assuming residents and businesses will comply with zoning changes, participate in green infrastructure initiatives, or accept relocation.
# 5.  **Predictability of Climate Impact Scenarios:** Assuming the probabilities and characteristics of low, medium, and high climate impact scenarios are reasonably accurate.
#
# **Data Collection/Pilot Experiments for Two Most Critical Assumptions (within 18 months):**
#
# *   **Critical Assumption 1: Accurate Monetization of Social and Environmental Impacts.**
#     *   **Data Collection Steps:**
#         *   **Contingent Valuation Surveys:** Conduct city-wide surveys to elicit residents' Willingness-To-Pay (WTP) for specific environmental benefits (e.g., restored wetlands, clean beaches) and Willingness-To-Accept (WTA) for negative social impacts (e.g., loss of community ties). Focus groups can refine survey instruments.
#         *   **Hedonic Pricing Study:** Analyze property sales data over the past 5-10 years, correlating property values with proximity to green spaces, access to waterfronts, or specific zoning restrictions. This can help monetize amenity values or disamenities.
#     *   **Pilot Experiment:** Implement small-scale "living shoreline" green infrastructure projects in 2-3 diverse neighborhoods. Track property value changes, resident satisfaction, and environmental indicators (e.g., water quality, bird sightings) in these areas compared to control areas.
#
# *   **Critical Assumption 2: Effectiveness of Strategies Against Varying Climate Impacts.**
#     *   **Data Collection Steps:**
#         *   **Hydrodynamic Modeling & Downscaled Climate Projections:** Partner with regional climate scientists and engineers to run advanced hydrodynamic models (e.g., Delft3D, ADCIRC) simulating storm surges and sea-level rise scenarios, layering in the proposed interventions (e.g., specific green infrastructure designs like dune restoration or stormwater retention). This can refine damage reduction percentages.
#         *   **Post-Event Damage Assessments:** For any minor flood events that occur, meticulously map flood extents and conduct detailed damage assessments across areas with varying levels of existing green infrastructure or protective features.
#     *   **Pilot Experiment:** Implement a pilot "managed wetland" area or large-scale permeable pavement project in a vulnerable low-lying neighborhood. Instrument these sites with flood sensors, soil moisture meters, and water level gauges. Monitor their performance during moderate rainfall and storm events, comparing actual flood depths/durations against pre-implementation baselines or adjacent control areas.
#
# ---
#
# ### 5. Failure Modes and Mitigations for Strategy C
#
# 1.  **Cognitive Bias (Optimism Bias/Status Quo Bias):**
#     *   **Failure Mode:** Citizens, developers, and even city officials may underestimate the urgency of climate impacts or overestimate the effectiveness of current small-scale actions (optimism bias), leading to insufficient political will to implement broad adaptive zoning or invest consistently in green infrastructure. Status quo bias might make them prefer current practices over new, potentially disruptive, zoning.
#     *   **Mitigation:** Implement a persistent, data-driven public awareness campaign using local examples (e.g., "before/after" flood maps, testimonials from affected residents). Establish a visible "Resilience Dashboard" showing real-time flood risk, project progress, and economic/environmental benefits. Engage trusted community leaders as champions for the strategy.
#
# 2.  **Stakeholder Incentives (Developer Opposition):**
#     *   **Failure Mode:** Developers may resist adaptive zoning (e.g., stricter setbacks, reduced density, mandatory green infrastructure components) if they perceive it as reducing buildable area, increasing costs, or lowering profit margins, leading to lobbying efforts or legal challenges.
#     *   **Mitigation:** Create incentive programs (e.g., tax abatements, density bonuses for off-site green infrastructure contributions, fast-tracked permitting for compliant developments) to offset perceived costs. Involve developers early in the planning process to co-create solutions and build consensus around mutually beneficial outcomes. Develop a transparent "Green Building Standard" with clear benefits and a streamlined approval process.
#
# 3.  **Political Constraints (Short-Term Political Cycles):**
#     *   **Failure Mode:** Green infrastructure and adaptive zoning offer long-term benefits that may not fully materialize within a typical 2-4 year political cycle. Politicians focused on re-election may prefer "harder," more visible, and immediately impactful (or less controversial) solutions, leading to inconsistent funding or abandonment of the strategy over time.
#     *   **Mitigation:** Establish a non-partisan, independent "Coastal Resilience Commission" with long-term oversight and a mandate to report on progress regardless of changing administrations. Lock in funding mechanisms through dedicated revenue streams (e.g., a stormwater utility fee, green bonds) that are less susceptible to annual budget cuts. Foster cross-party political champions who understand and advocate for the long-term vision.
#
# ---
#
# ### 6. Monitoring Metric
#
# **Single Most Important Annual Metric:** **Total Avoided Flood Damages (in M$)**
#
# **Why it's Most Informative:** This metric directly quantifies the primary goal of any flood mitigation strategy: reducing the economic impact of flooding. It aggregates the effectiveness of various green infrastructure projects and adaptive zoning measures into a single, comprehensive, and monetizable value. It allows for direct comparison against investment costs and helps assess whether the strategy is delivering on its core promise. Tracking avoided damages provides a clear feedback loop for policymakers and the public on the tangible benefits of their investments.
#
# **Quantitative Threshold for Policy Reassessment:** If the 3-year rolling average of **Total Avoided Flood Damages drops below 50% of the projected Medium Impact scenario's avoided damages ($35M/year for strategy C) or below 30% of actual annual baseline damages for the year**, it would trigger a policy reassessment. For Strategy C, projected medium impact avoided damages are 35M (50M * 0.70). So, if 3-year average < $17.5M, or if avoided damages for any single year are less than 30% of what would have happened (e.g., if a $50M damage year happens, but only $15M are avoided, rather than $35M), it indicates significant underperformance.
#
# ---
#
# ### 7. Moral Arguments
#
# **Moral Argument in Support of Strategy C (Green Infrastructure & Adaptive Zoning):**
# Choosing green infrastructure and adaptive zoning embodies a moral commitment to intergenerational equity and a harmonious relationship with our natural world. This strategy prioritizes long-term resilience, recognizing that future generations deserve a city that is not only protected from rising seas but also enriched by vibrant ecosystems, cleaner air and water, and accessible green spaces. It promotes a just transition by distributing benefits broadly, fostering community engagement in local solutions, and avoiding the concentrated harms and environmental injustices often associated with large-scale, hard infrastructure. By working with nature, not against it, we affirm our responsibility to be stewards of the environment, ensuring the sustained well-being of both human and non-human communities.
#
# **Counterargument from the Perspective of the Least-Advantaged Group:**
# From the perspective of the city's least-advantaged residents, particularly those in older, often neglected coastal neighborhoods, this "green" strategy can feel like another form of neglect or displacement. Adaptive zoning changes, while seemingly equitable on paper, can disproportionately affect those with limited resources by devaluing their property without adequate compensation or making it harder to rebuild after minor floods. The long-term, diffuse benefits of green infrastructure might not address their immediate, acute vulnerability to flooding or the pre-existing lack of resources for relocation or home repairs. They might perceive this strategy as prioritizing environmental amenities for the affluent over direct, robust protection for those who can't afford to "adapt" by moving or investing in new, expensive building codes, leaving them in vulnerable areas with insufficient tangible safeguards against rising waters.

# %%
model_name = "deepseek-chat"
answer = ChatModel(
            model_name=model_name,
            provider="deepseek",
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# ## **Strategy A: Build a Hard Seawall**
#
# **1. Top 5 Benefits & Risks**
# *Benefits*: (1) Immediate physical protection for existing property/assets. (2) Preserves current tax base & land use. (3) Psychological security for residents. (4) Clear, visible political “action.” (5) Protects critical infrastructure (ports, roads).
# *Risks/Costs*: (1) High upfront capital cost ($1–2B). (2) Can increase risk behind wall if overtopped/fails. (3) Environmental harm to coastal ecosystems. (4) False sense of permanence, discouraging adaptation. (5) Equity issues: protects wealthy coastal property more.
#
# **2. Quantitative Model**
# - **Variables**:
#   \( C_0 \): Initial construction cost ($1.5B).
#   \( M_t \): Annual maintenance cost ($10M).
#   \( B_t \): Annual avoided flood losses (depends on climate impact).
#   \( E_t \): Annual environmental/social cost ($5M).
#   \( r \): Discount rate (3%).
#   \( T \): 10 years.
# - **Equation**: Annual net social welfare \( NSW_t = B_t - M_t - E_t \) for \( t=1..10 \), with Year 0: \( -C_0 \).
#   Total NPV of NSW over 10 yrs = \( -C_0 + \sum_{t=1}^{10} \frac{B_t - M_t - E_t}{(1+r)^t} \).
# - **Baseline parameters**:
#   Low climate impact: \( B_t = $50M \)
#   Medium: \( B_t = $100M \)
#   High: \( B_t = $150M \)
#   Sensitivity: \( B_t \) ±50%, \( C_0 \) ±30%.
# - **Projected 10-year NPV**:
#   Low: \( -1500 + \sum \frac{50-10-5}{1.03^t} = -$1.12B \)
#   Medium: \( -1500 + \sum \frac{100-10-5}{1.03^t} = -$0.77B \)
#   High: \( -1500 + \sum \frac{150-10-5}{1.03^t} = -$0.42B \)
#
# **3. Recommended Strategy & Decision Rule**
# - **Rule**: Maximin (prioritize avoiding worst-case outcomes under uncertainty).
# - **Calculation**:
#   Worst-case NPVs:
#   A: -$1.12B (low benefit)
#   B: -$0.90B (calculated for B)
#   C: -$0.30B (calculated for C)
#   Maximin selects strategy with best (least bad) worst-case: **C**.
# - **Justification**: High uncertainty in climate impacts and funding; city cannot risk catastrophic failure of a single large investment.
#
# **4. Key Assumptions & Tests**
# *Assumptions*:
# 1. Discount rate (3%) reflects social time preference.
# 2. Maintenance costs predictable.
# 3. No catastrophic wall failure.
# 4. Environmental costs constant.
# 5. No behavioral risk increase (levee effect).
# *Tests for two most critical*:
# - **Assumption 3**: Pilot a 1 km seawall segment, monitor overtopping & erosion in storms.
# - **Assumption 5**: Survey households in pilot area for risk perception changes before/after.
#
# **5. Biases & Mitigations**
# 1. *Sunk cost fallacy*: Continue funding failing project.
#    **Mitigation**: Independent review panel with sunset clause.
# 2. *Political short-termism*: Prioritize ribbon-cutting over long-term maintenance.
#    **Mitigation**: Legally mandate maintenance trust fund.
# 3. *Equity blindness*: Wall protects wealthy areas only.
#    **Mitigation**: Require cross-subsidy for inland community benefits.
#
# **6. Monitoring Metric**
# - **Metric**: Annual flood losses per $1M of protected property (normalized loss ratio).
# - **Why**: Captures efficiency, controls for exposure.
# - **Threshold**: If ratio increases >10% year-on-year for 2 years, reassess.
#
# **7. Moral Argument & Counterargument**
# - **For C**: Green infrastructure distributes protection across communities, enhances ecological health, and avoids locking future generations into rigid, unequal defenses. It adapts flexibly to changing climate, embodying stewardship and resilience justice.
# - **Against C (least-advantaged perspective)**: This strategy experiments with our safety. While the wealthy can insure or move, we rely on immediate protection; green infrastructure may take years to mature, leaving us exposed to storms now. It feels like sacrificing our security for abstract ecological benefits enjoyed by others.
#
# ---
#
# *(Strategies B and C similarly detailed in full analysis; final recommendation is **C** based on maximin rule. Above shows template for one strategy; full answer would repeat for B and C, then compare.)*

# %%
model_name = "openai/gpt-oss-120b"
answer = ChatModel(
            model_name=model_name,
            provider="groq",
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# **NOTE:** All numbers are illustrative (rounded) and meant to show a *framework* rather than a definitive engineering study.
#
# ---
#
# ## 1.  Strategy‑by‑Strategy Quick‑Look
#
# | **Strategy** | **Top 5 Benefits** (social‑economic‑environmental‑political) | **Top 5 Risks / Costs** |
# |--------------|---------------------------------------------------------------|--------------------------|
# | **A – Hard seawall** | 1. Immediate, visible protection → lower perceived risk.<br>2. Protects existing property values → tax‑base stability.<br>3. Reduces insurance premiums and FEMA flood‑zone costs.<br>4. Short construction horizon (3‑5 yr) → quick political win.<br>5. Can be bundled with ports/transport upgrades (co‑benefits). | 1. High capital outlay ($1.8 bn) + O&M (~2 %/yr).<br>2. “Levee effect” – encourages further development in the protected zone.<br>3. Loss of shoreline habitat → coastal squeeze, biodiversity loss.<br>4. Vulnerable to overtopping under extreme events → catastrophic failure risk.<br>5. Hard to modify later → political lock‑in. |
# | **B – Managed retreat** | 1. Eliminates exposure for the most vulnerable parcels → long‑term safety.<br>2. Opens land for natural marshes → ecosystem services (carbon, flood attenuation).<br>3. Reduces future emergency‑response costs.<br>4. Aligns with climate‑justice narratives → higher community trust.<br>5. Low long‑term maintenance cost (once land is restored). | 1. Large upfront buy‑out cost ($1.2 bn) and relocation assistance.<br>2. Social disruption, loss of place‑based identity.<br>3. Potential “white flight” if buy‑outs concentrate on low‑income neighborhoods.<br>4. Legal challenges over property rights.<br>5. Requires coordinated land‑use planning – politically complex. |
# | **C – Distributed green + adaptive zoning** | 1. Multifunctional: flood storage, heat‑island mitigation, recreation.<br>2. Scalable and can be retro‑fitted to existing blocks.<br>3. Generates jobs in construction/landscape design.<br>4. Increases property values where green amenities are added.<br>5. Politically palatable – “nature‑based solutions” enjoy broad support. | 1. Lower protection level per dollar → may need supplemental measures.<br>2. High O&M (vegetation, dredging) and land‑acquisition costs in dense areas.<br>3. Effectiveness depends on proper zoning enforcement (political risk).<br>4. Time to mature (e.g., wetland establishment 5‑7 yr).<br>5. Benefit distribution can be uneven – affluent neighborhoods may capture most green space. |
#
# ---
#
# ## 2.  Simple Quantitative Welfare Model
#
# ### Common notation
#
# | Symbol | Meaning | Typical baseline (per year) |
# |--------|---------|-----------------------------|
# | \(F_t\) | Expected annual flood damage *without* the strategy (in $M) | 120 |
# | \(A\) | Annual *avoided* damage thanks to the strategy (in $M) |
# | \(C_0\) | One‑time capital cost (in $M) |
# | \(M\) | Annual O&M/maintenance cost (in $M) |
# | \(R\) | Annual relocation assistance (only for B) (in $M) |
# | \(E\) | Annual ecosystem‑service value (e.g., carbon, recreation) (in $M) |
# | \(D\) | Annual dis‑benefit (loss of amenity, social disruption) (in $M) |
# | \(\delta\) | Discount rate (3 %) |
# | \(W\) | Present value of net social welfare over 10 yr |
#
# Net welfare each year:
#
# \[
# \text{NW}_t = A_t - M_t - R_t + E_t - D_t
# \]
#
# Present value:
#
# \[
# W = -C_0 + \sum_{t=1}^{10}\frac{\text{NW}_t}{(1+\delta)^t}
# \]
#
# ### Parameterisation by strategy
#
# | **Variable** | **A (avoided damage)** | **M (O&M)** | **C0** | **R** | **E** | **D** |
# |--------------|------------------------|------------|--------|------|-------|------|
# | **A – Seawall** | \(A = \alpha_F \,F_t\) ; \(\alpha_F = 0.85\) (85 % damage avoided) | 36 (2 % of C0) | 1,800 | 0 | 5 (small habitat loss) | 10 (visual impact) |
# | **B – Retreat** | \(A = \beta_F \,F_t\); \(\beta_F = 0.60\) (60 % of damage avoided, because land is removed) | 12 (monitoring) | 1,200 | 30 (relocation grants) | 30 (new marsh services) | 25 (community disruption) |
# | **C – Green/Zoning** | \(A = \gamma_F \,F_t\); \(\gamma_F = 0.45\) (distributed measures cut damage by 45 %) | 24 (land‑scape O&M) | 600 | 0 | 45 (recreation, carbon) | 12 (implementation friction) |
#
# *All values in $M per year.*
#
# ### Climate‑impact scenarios (modify \(F_t\))
#
# | Scenario | Multiplier on baseline flood damage \(F_t\) | Probability (used in EV) |
# |----------|---------------------------------------------|--------------------------|
# | Low   | 0.8 → \(F_t = 96\) | 0.2 |
# | Medium| 1.0 → \(F_t = 120\) | 0.5 |
# | High  | 1.3 → \(F_t = 156\) | 0.3 |
#
# Using the equations above, we compute \(W\) for each strategy and scenario (rounded to $M):
#
# | Strategy | Low | Medium | High |
# |----------|-----|--------|------|
# | **A – Seawall** | **‑1,020** | **‑1,050** | **‑1,150** |
# | **B – Retreat** | **‑820** | **‑750** | **‑590** |
# | **C – Green/Zoning** | **‑610** | **‑540** | **‑470** |
#
# *(Negative values = net cost; the less negative, the better.)*
#
# *Sensitivity ranges* (±20 % on avoidance coefficients) shift each cell by roughly ±$30 M, showing the model is not overly volatile.
#
# ---
#
# ## 3.  Decision Rule & Recommendation
#
# **Chosen rule:** **Maximin (worst‑case) – “safety‑first”**.
#
# Rationale: The city faces deep uncertainty about storm intensity and political tolerance for catastrophic failure. A rule that safeguards against the worst plausible outcome is prudent for a coastal community with high exposure.
#
# | Strategy | Worst‑case (High‑impact) Net Welfare |
# |----------|--------------------------------------|
# | A | –1,150 |
# | B | –590 |
# | C | –470 |
#
# **Maximin choice = Strategy C (Distributed green + adaptive zoning).**
#
# Even under the most severe climate scenario, C yields the smallest net loss, while also delivering ancillary benefits (heat‑island mitigation, recreation) that are not captured fully in the simple cash‑flow model.
#
# ---
#
# ## 4.  Key Assumptions & Quick‑Test Plan
#
# | # | Assumption (critical) | Why it matters | 18‑month test / data‑collection |
# |---|-----------------------|----------------|---------------------------------|
# | 1 | **Avoidance coefficient** (α,β,γ) correctly reflects actual damage reduction. | Drives the bulk of welfare. | Run a **pilot “green‑belt”** in one flood‑prone district; compare observed flood depths vs. a control block using LiDAR and post‑event surveys. |
# | 2 | **Relocation willingness** – 60 % of at‑risk households will accept buy‑outs (βF). | Determines effectiveness of retreat. | Conduct a **targeted outreach survey** and a **small‑scale voluntary buy‑out** of 50 homes; track acceptance rate. |
# | 3 | O&M costs stay within projected 2 %–5 % of capital. | Affects net cost. | Audit the first 2 yr of seawall maintenance contracts and green‑infrastructure upkeep. |
# | 4 | Ecosystem service valuation (E) at $45 M/yr for green strategy is realistic. | Influences net benefit. | Use **benefit‑transfer** from existing US coastal wetland studies and validate with **local carbon‑stock monitoring**. |
# | 5 | Climate‑impact multipliers (0.8‑1.3) capture plausible future storm frequency. | Shapes scenario weighting. | Install **high‑resolution tide gauges** and **storm‑track model** to update local extreme‑event frequency annually. |
#
# The two most critical (1 & 2) are addressed by a **pilot green‑infrastructure test** and a **voluntary buy‑out trial**, both doable within 18 months and providing hard data on damage avoidance and social acceptance.
#
# ---
#
# ## 5.  Why the Recommended Strategy Might Fail – Cognitive/Political Traps
#
# | Failure mode | Underlying bias / incentive | Mitigation |
# |--------------|-----------------------------|------------|
# | **A. “NIMBY” opposition to green space** – Residents fear loss of parking or parking revenue. | **Loss‑aversion** & status‑quo bias. | Co‑design green corridors with **community benefit agreements** that include shared parking or revenue‑sharing from new amenities. |
# | **B. Political short‑termism** – Council favors visible hard infrastructure for next election. | **Present‑bias** of elected officials. | Tie a portion of the city’s **performance‑based grant funding** to the green‑strategy metric (see §6) so continued funding depends on meeting targets. |
# | **C. Agency turf wars** – Public works wants to control construction, while planning wants zoning flexibility, leading to delays. | **Inter‑agency competition** (self‑interest). | Create an **inter‑departmental “Coastal Resilience Task Force”** with a clear charter, joint budget, and a neutral facilitator. |
#
# ---
#
# ## 6.  Single Most Important Annual Metric
#
# **Metric:** **“Average Annual Flood‑Depth Reduction in the most‑exposed census blocks (cm)”**
#
# *Why:* It directly captures the physical effectiveness of whichever protection measure is in place and is comparable across scenarios. It also links to insurance claims, emergency response costs, and community perception.
#
# **Threshold for reassessment:** **< 12 cm (≈ 5 in) average reduction** after three consecutive years → triggers a policy review (possible hybridization with hard infrastructure).
#
# Data can be collected via **post‑event drone LiDAR surveys** combined with **continuous water‑level sensors** installed in the 10 highest‑risk blocks.
#
# ---
#
# ## 7.  Moral Argument & Counter‑Argument
#
# **Pro‑argument (for Strategy C):**
# Investing in distributed green infrastructure embodies the ethical principle of *intergenerational justice*: it protects today’s residents while restoring natural habitats that future citizens will inherit. By weaving flood buffers, public parks, and climate‑resilient streetscapes into the urban fabric, the city distributes risk reduction equitably across neighborhoods, rather than sheltering only the affluent enclave behind a concrete wall. Moreover, green solutions honor the intrinsic value of coastal ecosystems, preserving biodiversity and cultural ties to the shoreline for all residents, not just property owners.
#
# **Counter‑argument (from the least‑advantaged group – low‑income renters in the historic waterfront district):**
# For many of us, the waterfront is not just a place but a community built over generations. The green‑infrastructure plan threatens to convert our already scarce affordable housing into “parkland” or upscale mixed‑use developments, pricing us out and erasing our cultural heritage. While the city talks about “shared benefits,” the reality is a **displacement risk**: green upgrades often increase property values and taxes, forcing low‑income families to move farther inland—exactly the retreat the plan purports to avoid. Without explicit guarantees of affordable‑housing preservation and genuine community control, the green strategy could become another form of environmental gentrification.
#
# ---
#
# **Bottom line:** Using a *maximin* rule, the city should adopt **Strategy C – Distributed green infrastructure plus adaptive zoning**, while simultaneously running the two pilots identified above, institutionalising cross‑agency coordination, and monitoring the annual flood‑depth reduction metric to ensure that protection gains materialise without sacrificing the most vulnerable residents.

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
#!ollama pull deepseek-r1:7b

# %%
model_name = "deepseek-r1:7b"
answer = ChatModel(
            model_name=model_name,
            provider="ollama",
            api_key="me"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /opt/homebrew/Cellar/python@3.12/3.12.8/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.8/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[24], line 6
#       1 model_name = "deepseek-r1:7b"
#       2 answer = ChatModel(
#       3             model_name=model_name,
#       4             provider="ollama",
#       5             api_key="me"
# ----> 6         ).generate_response(
#       7             messages=messages,
#       8             print_response=True
#       9         )
#      11 competitors.append(model_name)
#      12 answers.append(answer)
#
# File ~/AI/MyCode/agents/1_foundations/MyCode/models.py:33, in ChatModel.generate_response(self, messages, max_tokens, print_response, **kwargs)
#      31 def generate_response(self, messages, *, max_tokens=10000, print_response=False, **kwargs):
#      32     if isinstance(self.client, OpenAI):
# ---> 33         response = self.client.chat.completions.create(model=self.model_name, messages=messages, **kwargs)
#      34         answer = response.choices[0].message.content
#      35     elif isinstance(self.client, Anthropic):
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/AI/MyCode/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1014, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1011         continue
#    1013     log.debug("Raising connection error")
# -> 1014     raise APIConnectionError(request=request) from err
#    1016 log.debug(
#    1017     'HTTP Response: %s %s "%i %s" %s',
#    1018     request.method,
#    (...)   1022     response.headers,
#    1023 )
#    1024 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-5', 'gemini-2.5-flash', 'deepseek-chat', 'openai/gpt-oss-120b']
# ['Below are concise, structured analyses for the three mutually exclusive 10-year strategies. All monetary figures are in millions of dollars per year, unless noted otherwise.\n\nStrategy A: Hard seawall\n\n1) Benefits (top 5) and risks/costs (top 5)\n- Social/economic/environmental/political benefits\n  - Strong protection of fixed assets and critical infrastructure against storm surge.\n  - Higher certainty for commercial activity and waterfront property values.\n  - Short- to mid-term construction jobs and local supplier demand.\n  - Potentially lower insurance volatility for waterfront properties.\n  - Perceived city resilience boosts public confidence and investor signaling.\n- Risks/costs\n  - Very high capital cost and ongoing maintenance (O&M).\n  - Environmental disruption: shoreline habitat loss, beach erosion, altered sediment transport.\n  - False safety signal risk leading to overbuilding and riskier planning (political/policy risk).\n  - Limited adaptability to extreme tail events beyond wall height; may require upgrades.\n  - Equity concerns if benefits concentrated in wealthier districts; potential opposition.\n\n2) Quantitative model (variables, equations, baselines, scenarios) and 10-year PV outcomes\n- Model: Annual welfare in year t\n  W_t = (1 − f_A) · D_no_t − I_A/10 − O_A + E_A\n  - D_no_t = baseline annual flood damages without strategy in year t\n  - f_A = residual damage fraction after seawall\n  - I_A = upfront capital cost; amortized as I_A/10 per year\n  - O_A = annual operations & maintenance cost\n  - E_A = annual co-benefits (ecosystem/services, property-value stabilization)\n- Baseline parameters (Strategy A)\n  - D0 = 150 (initial annual flood damages, baseline)\n  - Growth by year: low g_L = 1.5%; medium g_M = 3%; high g_H = 5%\n  - f_A = 0.25 (75% damages avoided)\n  - I_A = 400 → I_A/10 = 40 annual depreciation\n  - O_A = 15\n  - E_A = 8\n- D_no_t for each scenario (year 1…10)\n  - Low: D_no_t = 150, 152.25, 154.04, 156.96, 159.93, 162.98, 166.11, 169.29, 172.63, 176.07\n  - Medium: 150, 154.5, 159.14, 163.90, 168.87, 173.93, 179.15, 184.53, 190.07, 195.83\n  - High: 150, 157.5, 165.4, 173.7, 182.4, 191.5, 201.1, 211.1, 221.7, 232.8\n- PV results (10-year horizon, discount rate d = 3%)\n  - Low climate impact: PV_A ≈ 650\n  - Medium climate impact: PV_A ≈ 712\n  - High climate impact: PV_A ≈ 816\n\n3) Recommendation using a formal rule\n- Rule used: Maximin (maximize the worst-case outcome)\n- Worst-case PVs across scenarios:\n  - A: 650\n  - B: 817\n  - C: 409\n- Conclusion: Strategy B (large-scale managed retreat) is recommended by the maximin rule (greatest minimum welfare across scenarios). Rationale: it’s the most robust option under climate uncertainty in this simple model.\n\n4) Five strongest assumptions and data-collection steps\n- Assumptions\n  1) D_no_t growth/trajectory under climate scenarios is accurate (D0 and g_sc).\n  2) f_s (efficacy) of each strategy is constant over 10 years.\n  3) Capital costs I_s and annual O&M costs O_s are fixed and accurately estimated.\n  4) Annual co-benefits E_s are constant and monetizable.\n  5) Discount rate and social value of welfare are constant over the horizon; governance is stable.\n- Data-collection steps (two most critical assumptions to test within 18 months)\n  - Assumption 1 (climate damage growth): run local hazard/damage modeling and install lightweight flood sensors in representative neighborhoods to recalibrate D_no_t and g_sc using 2–3 years of local data; publish updated D_no_t trajectories every 6–12 months.\n  - Assumption 2 (efficacy of retreat): pilot a small, transparent buyout/relocation readiness exercise with 10–20 households to measure actual relocation costs, process feasibility, housing options, and social outcomes; evaluate willingness-to-relocate, costs, and post-relocation service needs.\n\n5) Biases, incentives, constraints and mitigations\n- Bias 1: Optimism about “best outcome” under future climate (planning ...

# %%
together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
results = ChatModel(
            model_name="gpt-5-mini",
            provider="openai"
        ).generate_response(
            messages=judge_messages,
            print_response=True
        )
# Out:
# {"results": ["2", "1", "5", "3", "4"]}

# %%
results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: claude-sonnet-4-5
# Rank 2: gpt-5-nano
# Rank 3: openai/gpt-oss-120b
# Rank 4: gemini-2.5-flash
# Rank 5: deepseek-chat

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
