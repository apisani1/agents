# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import json
from dotenv import load_dotenv, find_dotenv
from MyCode.models import ChatModel

# %%
# Always remember to do this!
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging
from warning_beep import warning_beep

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    warning_beep(); print("\033[31mOpenAI API Key not set\033[0m")

if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    warning_beep(); print("\033[31mAnthropic API Key not set\033[0m")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    warning_beep(); print("\033[31mGoogle API Key not set\033[0m")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    warning_beep(); print("\033[31mDeepSeek API Key not set\033[0m")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    warning_beep(); print("\033[31mGroq API Key not set\033[0m")
# Out:
# OpenAI API Key exists and begins sk-3SZmF
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
question = ChatModel(
            model_name="gpt-5-mini",
            provider="openai"
        ).generate_response(
            messages=messages,
            print_response=True
        )
# Out:
# You're advising the mayor of a mid-sized coastal city (population ~300,000) that faces projected sea-level rise likely to render 20% of current urban land unusable within 30 years; the city has limited municipal funds, a large petrochemical plant employing ~12% of the workforce, an ancient historic district central to a racial/ethnic minority, and sharp political polarization—within a 10-year planning horizon, propose a prioritized, actionable strategy that balances protecting lives and property, preserving cultural heritage, maintaining economic stability and jobs, and ensuring equity for vulnerable populations; for each element of the strategy provide specific interventions, order-of-magnitude cost estimates, plausible financing mechanisms, responsible governance and communication steps, measurable performance indicators, and a phased timeline; then list the key assumptions and uncertainties underlying your plan, three alternative strategies with their main trade-offs, and the top five pieces of new data that would most likely change your recommendations and explain how you would update the plan when that data arrives—justify all major choices.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
model_name = "gpt-5-nano"
answer = ChatModel(
            model_name=model_name,
            provider="openai"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# Executive summary
# Working within a 10-year planning horizon and a constrained fiscal environment, the city should pursue a balanced, phased resilience strategy that (1) protects lives and essential property (especially in high-risk flood zones and near the petrochemical cluster), (2) preserves economic stability and jobs (including a safe, continued operation of the major employer while diversifying the economy), (3) safeguards the historic district and supports inclusive, equitable outcomes for vulnerable residents, and (4) builds transparent governance and diversified financing to sustain implementation. The strategy combines hard and nature-based protections where cost-effective, targeted relocation/retreat options only where necessary, workforce retraining and economic diversification, and robust community engagement. It relies on multi-source financing (federal/state grants, resilience bonds, public-private partnerships, special assessments), staged capital investments, and a cross-agency resilience governance structure with strong public communication.
#
# Pillar 1. Protect lives and high-risk property; improve resilience of critical assets (near-term focus)
# Why this is first: 1) saves lives in storms/floods, 2) preserves critical infrastructure and the petrochemical plant’s safety, 3) reduces potential cascading losses to the economy and minority communities.
#
# Interventions, order-of-magnitude costs, financing, governance, metrics, timeline
#
# - A. Critical-infrastructure flood protection and floodproofing
#   - What: Harden emergency services, hospital, and key essential facilities; elevate or floodproof critical electrical and data centers; protect evacuation routes and bridges leading to the Historic District and key economic zones.
#   - Estimated cost (order of magnitude): $50M–$400M (depends on asset inventory and existing protection levels)
#   - Financing mechanisms: municipal bonds (short- to mid-term), federal/State hazard mitigation grants (FEMA, HUD), public-private cost-sharing with critical-service partners, storm-hardening set-aside funds.
#   - Governance/communication: establish a cross-department “Resilience Hardening Team” with periodic briefings to City Council; publish a 24/7 status dashboard during events; bilingual emergency updates; involve the Petrochemical Plant Safety Liaison in planning.
#   - Performance indicators: days of service continuity during storms; percent of critical facilities with floodproofing/upgrades; time to restore essential services after a storm.
#   - Timeline: 0–2 years design and initial upgrades; 2–5 years full implementation in the highest-risk corridors; 5–10 years expanded where needed.
#
# - B. Nature-based coastal protections and hybrid defenses
#   - What: Restored marsh/wetland buffers, dune restoration, living shorelines, and tide/sea-level rise adaptive buffers; where feasible pair with seawalls or flood barriers in the most vulnerable pockets.
#   - Estimated cost: $50M–$600M (high variance based on land ownership and habitat restoration scale)
#   - Financing: federal/state resilience grants, environmental equity funds, watershed/land-conservation funds, debt financing if staged; potential private restoration investment in exchange for long-term public benefits.
#   - Governance/communication: interagency coastal program with capability to implement environmental permits quickly; community engagement in restoration sites; outreach in multiple languages.
#   - Performance indicators: acreage of restored/retained natural buffers; reduction in flood depth in target zones; habitat quality metrics; public blue-green space access.
#   - Timeline: 1–3 years planning and permitting; 3–7 years implementation; monitoring ongoing through year 10 and beyond.
#
# - C. Drainage, floodplain management, and utility hardening
#   - What: Upgraded pumping stations, gravity drainage, reduced culvert bottlenecks, secondary power sources for critical systems; climate-resilient utility corridors.
#   - Estimated cost: $50M–$300M
#   - Financing: state/local infrastructure funds, resilience bonds, operating budget reallocations; cost-sharing with utilities and key employers.
#   - Governance/communication: Utilities/City engineering collaboration; clear public-facing schedules and service-level commitments; provide multilingual notices.
#   - Performance indicators: flood-extents under modeled 100-year/50-year events; uptime of critical utilities during storms; response time to outages.
#   - Timeline: 0–3 years preliminary designs; 3–6 years construction; 6–10 years completion of core upgrades.
#
# - D. Urban form and land-use safeguards in high-risk zones
#   - What: Temporary/no-build policies for new development in highest flood- and erosion-risk corridors; buyouts or buy-down protections for homes most exposed; targeted elevation for affordable housing in risk zones.
#   - Estimated cost: $10M–$150M (depends on buyout scale and incentives)
#   - Financing: federal/state buyout programs, bonding for relocation assistance; local affordable-housing funds; potential reimbursement through FEMA’s voluntary relocation programs.
#   - Governance/communication: legally rigorous zoning amendments; community meetings, with culturally competent outreach; transparent eligibility criteria.
#   - Performance indicators: number of parcels enrolled in buyout/relocation; reductions in new development permits in high-risk zones; housing unit elevation rates.
#   - Timeline: 0–2 years policy adoption; 2–7 years program implementation; 7–10 years monitoring.
#
# Rationale: These interventions focus on preventing loss of life and protecting infrastructure and jobs, while starting to reduce exposure in the highest-risk zones. They also establish necessary protections around the petrochemical cluster (see Pillar 2) and the Historic District (Pillar 3) by mitigating flood risk to the greatest extent possible with a mix of grey/green solutions.
#
# Pillar 2. Economic resilience, jobs, and the petrochemical sector; maintain income security
# Why this is second: the city’s major employer employs ~12% of the workforce; the plan must safeguard jobs and maintain tax base while preparing for longer-term shifts.
#
# Interventions, costs, financing, governance, metrics, timeline
#
# - A. Petrochemical plant safety and resilience upgrades; workforce continuity
#   - What: Safety enhancements, flood/rare-event protection for plant footprints and supply chain nodes; on-site emergency response training; redundancy planning; remote monitoring; community liaison for risk communication.
#   - Estimated cost: $50M–$200M
#   - Financing: plant capital budgets; public-private cost-sharing; potential Clean Energy/Industrial safety grants; state industrial resilience funds; performance-based financing if plant remains operational.
#   - Governance/communication: establish a Plant Resilience Steering Committee with city, plant, and labor representatives; public risk communication plan; quarterly joint briefings.
#   - Performance indicators: incident rate; time-to-incident response; plant downtime avoided; number of workers retained through retraining programs.
#   - Timeline: 0–2 years planning and procurement; 2–4 years installation; ongoing monitoring through year 10.
#
# - B. Workforce retraining and economic diversification
#   - What: Programs to retrain workers for high-skill, climate-resilient sectors (construction, water-smart infrastructure, energy efficiency, port/logistics, carbon management, health services), plus seed funds for small business adaptation and start-ups near the resilience hubs.
#   - Estimated cost: $40M–$200M (over 3–7 years; ongoing post-year 7)
#   - Financing: state workforce funds, federal workforce development grants, city matching, private-sector apprenticeship contributions; foundations and philanthropic grants for equitable access.
#   - Governance/communication: create a City-Employer Partnership Council; ensure bilingual program materials; transparent enrollment and success metrics.
#   - Performance indicators: number of residents retrained; job placement rates; new business licenses; earnings growth for participants.
#   - Timeline: 0–2 years program design; 2–6 years scaling; ongoing evaluation.
#
# - C. Economic diversification and innovation districts
#   - What: Attract green/light-industrial firms, coastal-focused maritime services, climate-tech, retrofit and efficiency services; strategy to cluster jobs near resilience hubs to reduce commute vulnerabilities.
#   - Estimated cost: $100M–$300M (facility incentives, infrastructure upgrades, seed grants)
#   - Financing: public-private partnerships, tax increment financing (TIF) in targeted districts, grants for economic development, state/local incubator programs.
#   - Governance/communication: establish a Resilience-Economy Zone Authority with cross-agency and private-sector representation; regular investor briefings; inclusive outreach to minority-owned businesses.
#   - Performance indicators: private sector investments attracted; jobs created/retained in the resilience economy; number of contracts awarded to local minority firms.
#   - Timeline: 1–3 years policy/design; 3–7 years incentives and build-out; ongoing.
#
# - D. Transportation and critical logistics resilience
#   - What: Ensure redundancies for ferry/road/rail links, resilient harbor/logistics corridors; improve last-mile connectivity to resilient neighborhoods and the Historic District.
#   - Estimated cost: $100M–$400M
#   - Financing: state/federal transportation funds, bond measures, public-private co-funding with logistics/port operators.
#   - Governance/communication: multi-stakeholder transportation working group; real-time travel advisories; multilingual guidance.
#   - Performance indicators: route uptime during events; freight/logistics throughput; resident access to jobs during disruptions.
#   - Timeline: 0–3 years design; 3–6 years implementation; monitoring thereafter.
#
# Rationale: Protecting the petrochemical plant and maintaining job stability are non-negotiable for a stable tax base and social equity. At the same time, workforce retraining and diversification reduce long-term exposure to physical risks and create multiple local pathways for prosperity, reducing reliance on a single employer.
#
# Pillar 3. Historic district protection and cultural heritage; preserve equity in preservation
# Why this is essential: the Historic District is central to a racial/ethnic minority community and to the city’s identity. It requires protection, prudent risk-sharing, and inclusive stewardship.
#
# Interventions, costs, financing, governance, metrics, timeline
#
# - A. Adaptive protection and cultural-preservation upgrades in the Historic District
#   - What: Protective flood defenses tailored to the historic fabric; elevated walkways, reversible floodproofing for storefronts; micro-siting to avoid structural damage; preservation-compatible drainage improvements.
#   - Estimated cost: $50M–$500M (depending on scale and preservation constraints)
#   - Financing: grants for historic preservation, federal/state cultural heritage funds, resilience bonds ensuring preservation outcomes, philanthropic contributions to preservation.
#   - Governance/communication: Historic District Preservation Board with community representation; pre-storm communication plans; culturally competent outreach; translation for minority communities.
#   - Performance indicators: number of historically listed buildings protected; uptime of cultural district facilities; number of preservation permits processed without delays.
#   - Timeline: 0–2 years planning and design; 2–6 years phased implementation; ongoing maintenance.
#
# - B. Adaptive reuse and heritage-driven economic development
#   - What: Incentives for preserving historic storefronts and repurposing them for resilient uses (community markets, resilient housing above shops, cultural centers); support for minority-owned businesses.
#   - Estimated cost: $10M–$100M (incentives and small-scale improvements)
#   - Financing: tax credits, grant programs, public-private partnerships; resilience-oriented storefront improvement programs.
#   - Governance/communication: target outreach to minority business networks; ensure accessible application processes; monitor equity metrics.
#   - Performance indicators: number of adaptive-use projects; minority-owned businesses served; revenue and employment generated in heritage districts.
#   - Timeline: 0–2 years program design; 2–7 years implementation.
#
# - C. Cultural equity and evacuation-center planning
#   - What: Ensure evacuation centers and shelters are accessible to minority populations; language access; culturally appropriate support services during events.
#   - Estimated cost: $10M–$50M (facility upgrades and staffing)
#   - Financing: county/state funds; philanthropic and emergency response grants
#   - Governance/communication: inclusive planning with community groups; multilingual signage and messaging; targeted outreach to vulnerable households.
#   - Performance indicators: shelter utilization equity metrics; time to shelter during events; resident satisfaction surveys.
#   - Timeline: 0–1 year planning; 1–3 years implementation; ongoing.
#
# Rationale: Protecting the Historic District is vital for equity, cultural continuity, and tourism-driven economic activity. Preservation must be integrated into resilience investments rather than treated as separate. This pillar ensures marginalized communities retain agency and benefit from resilience investments.
#
# Pillar 4. Equity, community engagement, and social resilience
# Why this matters: Vulnerable populations bear disproportionately higher climate risks. Equity-focused planning ensures that resilience benefits are shared and that displacement risks are mitigated.
#
# Interventions, costs, financing, governance, metrics, timeline
#
# - A. Inclusive governance and public engagement
#   - What: Create a formal token for public engagement across neighborhoods, with multilingual consultations, deliberative forums, and citizen advisory groups; ensure representation from vulnerable communities.
#   - Estimated cost: $5M–$15M (facilitation, outreach, translation services)
#   - Financing: city budget, foundation grants, and targeted state support for inclusive planning
#   - Governance/communication: establish a Civic Resilience Committee; publish open-data dashboards; ensure real-time feedback channels (hotlines, online surveys)
#   - Performance indicators: participation rates by neighborhood/disciplinary group; satisfaction with engagement process; number of adaptation ideas adopted
#   - Timeline: 0–1 year establishment; ongoing engagement through year 10
#
# - B. Housing affordability and climate-resilient housing
#   - What: Protect and expand affordable housing in resilient locations; subsidize elevation/retrofits; enforce not-to-exceed rent increases in hazard zones; preserve housing stock for vulnerable populations.
#   - Estimated cost: $50M–$500M
#   - Financing: housing trust funds, federal housing grants, inclusionary zoning incentives, state affordable housing programs
#   - Governance/communication: Housing Advisory Board with tenant associations; transparent eligibility criteria
#   - Performance indicators: affordable units protected/created; displacement numbers; rent stabilization metrics
#   - Timeline: 0–2 years policy design; 2–7 years implementation
#
# - C. Evacuation, sheltering, and social services
#   - What: Improve evacuation route clarity, shelter accessibility, energy/water needs in shelters, and social services coordination
#   - Estimated cost: $20M–$100M
#   - Financing: federal emergency management grants, state programs, philanthropic support
#   - Governance/communication: cross-agency shelter coordination, contracted NGOs for language services; regular drills and outreach
#   - Performance indicators: evacuation time reductions; shelter capacity utilization; service access metrics for vulnerable populations
#   - Timeline: 0–2 years planning; 2–5 years implementation; routine drills annually
#
# - D. Climate justice and data-driven equity monitoring
#   - What: Data collection and dashboards to monitor equity in risk exposure, investment distribution, and outcomes
#   - Estimated cost: $2–$10M
#   - Financing: internal funds; grants for data platforms
#   - Governance/communication: establish an Equity and Resilience Data Council; publish quarterly equity reports
#   - Performance indicators: exposure reductions by demographic group; equity-adjusted investment share; transparency score
#   - Timeline: 0–1 year design; ongoing
#
# Rationale: Equity investments prevent climate-related harms from widening existing disparities, protect minority communities (including the Historic District’s residents), and build broad-based political support critical in a polarized environment.
#
# Pillar 5. Governance, financing, and communications
# Why this matters: A credible, transparent governance framework and diversified financing are essential to execute the plan and keep political support, especially in a polarized environment.
#
# Interventions, costs, financing, governance, metrics, timeline
#
# - A. Resilience Authority and cross-agency governance
#   - What: Create a city resilience authority or interdepartmental coordinating body to align planning, budgeting, and procurement; establish clear accountability and performance metrics.
#   - Estimated cost: $5M–$15M (setup and first-year operations)
#   - Financing: seed funds from city budget; grant support; third-party partnerships
#   - Governance/communication: independent oversight committee; quarterly public reporting; cross-sector advisory board including private sector and community groups
#   - Performance indicators: on-time project delivery; variance versus budget; stakeholder satisfaction; interagency coordination score
#   - Timeline: 0–1 year establishment; ongoing
#
# - B. Financing strategy and capital plan
#   - What: Develop a comprehensive resilience finance plan combining general obligation bonds, revenue bonds, state/federal grants, resilience-based financing (e.g., resilience bonds), TIF-like mechanisms, and private-sector co-investments.
#   - Estimated cost: planning costs $0.5–$2M; program-scale financing requirements driven by project pipeline
#   - Financing: mixed instrument approach; default readiness for multiple scenarios
#   - Governance/communication: publish financing strategy; ensure consulting firms with equity and environmental justice expertise
#   - Performance indicators: capital stack diversification; cost-of-capital improvements; leverage ratios; project approval timelines
#   - Timeline: 0–1 year planning; 1–10 years execution
#
# - C. Communications and public trust
#   - What: Proactive risk communication, bilingual outreach, clear explanation of tradeoffs (defense vs. retreat), transparent citizen engagement results
#   - Estimated cost: $2M–$10M
#   - Financing: city budget; grants for public information programs
#   - Governance/communication: a dedicated Chief Communications Officer for resilience; real-time dashboards; regular town halls
#   - Performance indicators: public trust indexes; media sentiment; information-access metrics
#   - Timeline: 0–1 year launch; ongoing
#
# Rationale: A dedicated governance structure and financing plan are the backbone that make the other pillars actionable. Transparent, inclusive communication reduces polarization, builds trust, and accelerates decision-making.
#
# Phased timeline (summary)
# - Year 0–1 (0–12 months):
#   - Establish Resilience Authority; complete risk and asset inventory; adopt the resilience plan; begin public engagement; secure initial seed funding; initiate design for near-term protective works; begin planning for workforce retraining and diversification.
# - Year 1–3:
#   - Implement high-priority protective projects (critical infrastructure hardening; first wave of nature-based protections); start petrochemical safety investments; launch workforce retraining programs; begin historic district adaptive protections.
# - Year 3–5:
#   - Scale up coastal defenses and drainage; advance buyouts/relocation where necessary; expand economic diversification incentives; complete urban form safeguards in high-risk zones; intensify housing and shelter improvements.
# - Year 5–7:
#   - Continue major capital projects; monitor and adjust as required; implement broader resilience financing instruments; expand community-engaged planning and data dashboards.
# - Year 7–10:
#   - Evaluate outcomes and re-align investments; prepare for next phase (beyond 10 years) with updated risk projections; refine policies to address remaining vulnerabilities.
#
# Key assumptions and uncertainties
# Assumptions (central to plan viability)
# - Sea-level rise and storm surge projections under a reasonable set of climate scenarios remain within the mid-to-high end of current projections but are manageable with phased investment.
# - Federal/state funding continues to be available for resilience (grants, loans, and matching funds) and can be accessed with timely applications.
# - The petrochemical plant remains operational in the near term and is receptive to safety upgrades and resilience investments.
# - The city can attract private-sector partners for co-investments and NBD (new business development) in targeted resilience sectors.
# - The tax base supports debt-financing and bond issuance without undue burden on residents.
# - Community organizations will engage with the city and participate constructively in planning processes.
#
# Key uncertainties
# - The pace of policy changes at the state/federal level that would expand resilience funding or create new regulatory hurdles.
# - The actual cost evolution of major protections (e.g., flood barriers vs. nature-based solutions) and the feasibility of certain design elements in the Historic District.
# - Local political dynamics and the potential for litigation or delays around managed retreat or large-scale eminent-domain actions.
# - The pace and scale of private investment in diversification, and wage levels for new jobs.
# - Real-time demographic shifts, housing market shifts, or migration patterns in reaction to climate pressures.
#
# Three alternative strategies (with main trade-offs)
# Alternative 1: Defend aggressively (defense-first, with gradual adaptation)
# - Core idea: Invest heavily in hard defenses along the coast and around critical zones (and in the petrochemical area), with limited early retreat or relocation. Emphasize maintaining existing land uses and economic bases, with incremental nature-based solutions as cost-effective complements.
# - Pros: Immediate protection of life and property; strong signal to investors and workers that the city is "staying put"; preserves current economic structure.
# - Cons: Very high upfront capital costs; potential for stranded assets if sea-level rise accelerates; risk of underutilizing or delaying necessary relocation or diversification; political sensitivity around imposing heavy costs on taxpayers and tenants.
# - Trade-offs: Higher near-term debt and annual service obligations; slower diversification; potential inequities if protections concentrate benefits in wealthier neighborhoods.
#
# Alternative 2: Managed retreat and targeted relocation (retreat-centered)
# - Core idea: Use buyouts and relocation incentives with a prioritized, transparent process for abandoning or re-developing the most exposed areas, especially where protection is unaffordable or inequitable; preserve critical functions and high-value assets with targeted protections elsewhere.
# - Pros: Reduces exposure and long-term cost, aligns with climate-justice ethos; creates opportunities for reimagined, higher-density, resilient developments in safer zones.
# - Cons: Political resistance from property owners and some communities; potential loss of cultural space and neighborhood cohesion; near-term disruption to residents and workers; economic dislocation if not paired with viable relocation options and job opportunities.
# - Trade-offs: Short-term social disruption vs. long-term risk reduction; may reduce tax base in retreat zones; requires robust, well-funded housing and job transition programs.
#
# Alternative 3: Economic diversification plus industrial modernization (greenization and resilience)
# - Core idea: Advance a strategic diversification plan that modernizes the petrochemical cluster for safety and lower emissions while courting green and resilience-focused industries; invest heavily in workforce retraining and infrastructure to support a climate-resilient economy.
# - Pros: Maintains or grows local jobs; reduces long-term exposure through a broadened economic base; aligns with broader climate goals; increases resilience through diversified tax streams.
# - Cons: Requires significant coordination with industry; may take longer to achieve job gains in new sectors; may face political and public resistance from workers and communities tied to traditional energy sectors.
# - Trade-offs: Short-term costs and transition risk vs. long-term economic health and resilience; requires strong policy and incentives to succeed.
#
# Five data items that would most likely shift recommendations and how to update the plan when that data arrives
# 1) High-resolution, city-wide flood hazard maps and sea-level rise projections at neighborhood scale
# - How data would change plan: If hazard zones are larger or more rapid than anticipated, shift toward earlier or deeper protective investments and accelerate retreat plans where cost-effective; if hazard is more localized, focus protections on the most exposed neighborhoods while preserving others.
# - How to update: Re-run cost-benefit analyses; adjust protective priorities; reallocate funding and financing instruments; re-open stakeholder engagement on settlement patterns.
#
# 2) Property exposure values and demographic impacts in flood zones
# - How data would change plan: If exposure disproportionately affects minority/low-income areas, increase equity-focused protections and/or expansion of buyout options; adjust housing/relocation policies to ensure fairness.
# - How to update: Re-prioritize investments to increase protections in vulnerable neighborhoods; adjust disaster assistance and recovery programs; adjust communications to address equity concerns.
#
# 3) Petrochemical plant risk assessment, safety upgrade costs, and possible relocation feasibility
# - How data would change plan: If plant safety upgrades are infeasible or prohibitively expensive, or if relocation becomes necessary or advantageous, push more aggressively toward diversification or relocation planning, with a reallocation of funds toward workforce transition and new industry clusters.
# - How to update: Recompute risk-sharing and financing; adjust the resilience portfolio to emphasize diversification and worker retraining.
#
# 4) Job market projections and retraining capacity (labor supply, time to upskill, and wage outcomes)
# - How data would change plan: If retraining capacity is insufficient or job market uptake is slow, adjust pace and scale of diversification investments; consider accelerated incentives or targeted apprenticeships; ensure safety nets and transitional incomes.
# - How to update: Update workforce development plans; adjust funding for training; broaden or narrow target sectors based on demand.
#
# 5) Federal/state funding trajectories and grant availability for resilience, defense, and economic diversification
# - How data would change plan: If funding becomes more available or more constrained, re-prioritize projects accordingly; more aggressive defense if grants are available; faster progress if leverage is possible.
# - How to update: Rebalance capital plan; adjust bond issuance and debt service estimates; adjust the financing plan and public communications regarding funding sources and long-term commitments.
#
# Justifications for major choices
# - Protecting life and essential infrastructure first is ethically and practically necessary; the cost of inaction is higher in the face of rising flood risks and the concentration of critical assets in high-risk zones.
# - Maintaining the petrochemical plant as a core employer is essential for the city’s economy and tax base; but plan to bolster safety, modernize operations, retrain workers, and diversify the economy to reduce single-point dependency.
# - The Historic District has cultural, social, and economic importance; resilience investments must be compatible with heritage preservation and equitable access for minority residents.
# - Equity considerations are integral to political viability and social stability; climate risk is not evenly distributed, and resilience investments must reduce disparities.
# - A dedicated resilience governance body and diversified financing plan are necessary to coordinate multi-year investments, manage risk, and maintain public trust in a polarized political climate.
#
# If you’d like, I can convert this into:
# - A one-page executive summary with prioritized near-term actions, or
# - A more detailed, department-by-department implementation plan with a line-item budget and sample procurement/timeline templates, or
# - A simplified stakeholder map and comms plan tailored to local media and key community groups.
#
# Notes
# - All cost ranges are order-of-magnitude estimates and will require project scoping, engineering studies, and market testing to refine.
# - The plan emphasizes phased implementation to align with typical state/federal funding cycles and to mitigate near-term fiscal risk.
#
# Would you like me to convert this into a formal memo with a phased Gantt-style timeline and a procurement-ready checklist for the first 12–18 months?

# %%
model_name = "claude-sonnet-4-5"
answer = ChatModel(
            model_name=model_name,
            provider="anthropic"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# # Comprehensive Climate Adaptation Strategy for Coastal City
# ## Executive Summary
#
# This strategy prioritizes immediate risk reduction while building long-term adaptive capacity through a sequenced approach: (1) protect lives through early warning and relocation preparedness, (2) secure critical infrastructure and the economic base, (3) preserve cultural heritage through adaptive reuse, and (4) build community resilience through participatory planning that reduces polarization.
#
# ---
#
# ## PRIORITIZED STRATEGY ELEMENTS
#
# ### **PHASE 1: IMMEDIATE ACTIONS (Years 0-3)**
#
# #### **1.1 Comprehensive Risk Assessment & Transparent Communication**
#
# **Interventions:**
# - High-resolution flood modeling incorporating 30-year projections with 10-, 20-, and 50-year increments
# - Parcel-level vulnerability mapping showing probabilistic flood risks, insurance costs, and property value trajectories
# - Door-to-door outreach in vulnerable neighborhoods with multilingual materials
# - Monthly town halls in each district with data transparency portals
# - Creation of "Citizen Science Corps" (200 trained residents) to monitor flood events and communicate with neighbors
#
# **Cost Estimate:** $3-5M
# - Modeling/GIS: $1.5M
# - Community engagement staff (3 years): $2M
# - Materials and translation: $0.5M
# - Monitoring equipment: $1M
#
# **Financing:**
# - FEMA Building Resilient Infrastructure and Communities (BRIC) grant: $2M
# - NOAA Climate Program Office: $1M
# - Municipal general fund: $2M
#
# **Governance:**
# - Mayor establishes "Climate Adaptation Office" reporting directly to City Manager
# - 15-member "Resilience Commission" (40% from vulnerable communities, includes petrochemical worker representatives, historic district advocates, business leaders, youth)
# - Third-party scientific advisory panel for credibility with polarized constituencies
#
# **Performance Indicators:**
# - 80% of at-risk residents aware of their specific flood risk by Year 2
# - Trust in city government (baseline survey → follow-up) increases by 15%
# - Resilience Commission attendance >70% at meetings
# - >500 residents engaged in town halls quarterly
#
# **Justification:** Without shared understanding of risk and trust in government, all subsequent interventions fail. Transparency about property value impacts is painful but necessary for informed decisions. Early engagement with petrochemical workers and historic district residents prevents defensive coalitions.
#
# ---
#
# #### **1.2 Emergency Preparedness & Early Warning Infrastructure**
#
# **Interventions:**
# - Install 50 IoT flood sensors in vulnerable areas with public real-time dashboard
# - Establish "resilience hubs" in 10 community centers (elevated, with backup power, supplies for 500 people for 72 hours)
# - Create neighborhood-level evacuation plans with buddy systems for elderly/disabled
# - Pre-position emergency housing contracts (FEMA trailers, hotel agreements)
# - Develop "Cultural Heritage Emergency Response Plan" for artifact evacuation from historic district
#
# **Cost Estimate:** $8-12M
# - Sensor network: $2M
# - Resilience hub upgrades: $5M (10 × $500K)
# - Emergency planning and drills: $1M
# - Contracts and legal: $2M
# - Heritage emergency plan: $2M
#
# **Financing:**
# - FEMA Pre-Disaster Mitigation: $5M
# - State emergency management grants: $3M
# - Municipal bonds (20-year): $4M
#
# **Governance:**
# - Joint command structure: Climate Adaptation Office + Emergency Management
# - Annual full-scale evacuation drill with after-action reviews
# - Community Emergency Response Teams (CERT) trained in each vulnerable neighborhood
#
# **Performance Indicators:**
# - <2 hours warning time for 95% of residents before flooding
# - 90% of vulnerable residents know their evacuation route
# - Zero preventable deaths from flooding events
# - Cultural artifacts successfully evacuated in test drills
#
# **Justification:** Protecting lives is non-negotiable and builds political capital for harder decisions. This creates immediate value for all constituencies.
#
# ---
#
# ### **PHASE 2: STRATEGIC PROTECTION & ADAPTATION (Years 2-7)**
#
# #### **2.1 Tiered Infrastructure Protection Strategy**
#
# **Interventions:**
#
# **Tier A - Critical Protection (Full defense):**
# - Petrochemical plant: Construct 3-mile perimeter levee system (15-ft elevation + 5-ft sea wall) with pump stations
# - Power substation hardening (3 facilities)
# - Hospital elevation/flood-proofing
# - Main wastewater treatment plant relocation inland
#
# **Tier B - Adaptive Protection (Moderate defense + managed retreat planning):**
# - Historic district: Deployable flood barriers + elevated pedestrian walkways + drainage improvements
# - Create "Historic District Land Trust" with right of first refusal for at-risk properties
# - Fund elevation of 50 historic structures (prioritize occupied residential, then commercial, then religious/cultural)
#
# **Tier C - Managed Retreat Zones:**
# - Buyout program for 800 most vulnerable residential properties (voluntary, 110% pre-flood fair market value)
# - Conversion to "blue-green infrastructure": tidal wetlands, parks, stormwater management
# - Protective buffer for Tier A/B zones
#
# **Cost Estimate:** $380-520M
# - Petrochemical protection: $120-150M
# - Critical infrastructure: $80-100M
# - Historic district adaptive protection: $60-80M
# - Structure elevations: $50M (50 × $1M avg)
# - Buyout program: $160-200M (800 × $200K avg)
# - Blue-green conversion: $30-40M
#
# **Financing:**
# - **Federal sources ($250-300M):**
#   - Army Corps of Engineers cost-share (65%): $150M
#   - EPA Water Infrastructure Finance and Innovation Act: $50M
#   - HUD Community Development Block Grants: $50M
#   - National Park Service Historic Preservation Fund: $20M
#
# - **State sources ($50-70M):**
#   - State climate resilience bonds
#   - Historic preservation tax credits
#
# - **Local sources ($80-150M):**
#   - Special assessment district (petrochemical plant pays 40%): $60M
#   - Municipal bonds: $40M
#   - Local option sales tax (0.5% for 10 years, referendum required): $40M
#   - Land value capture (from protected properties): $10M
#
# **Governance:**
# - Independent "Property Acquisition Authority" to manage buyouts (prevents conflicts of interest)
# - Petrochemical company board seat on levee management district (since they fund 40%) with public oversight
# - Historic District Trust with 7-member board: 4 residents, 1 preservationist, 1 city appointee, 1 at-large
# - Quarterly public reports on all spending
#
# **Performance Indicators:**
# - Petrochemical plant protected to 100-year + 3ft freeboard standard by Year 5
# - Zero involuntary residential displacements
# - 70% participation rate in voluntary buyout (target 800 properties)
# - 45 of 50 historic structures successfully elevated by Year 7
# - 300 acres of new tidal wetlands created
# - Flood insurance premiums reduced 30% in protected zones
#
# **Justification:**
# - **Petrochemical plant protection is economically non-negotiable** (12% of jobs, massive tax base, environmental catastrophe if flooded), but company must pay proportionate share to maintain equity
# - **Historic district adaptive protection** balances preservation with reality—elevated walkways maintain urban fabric while allowing periodic flooding of streets
# - **Voluntary buyouts at premium rates** (110%) respect property rights while enabling retreat
# - **Tiered approach acknowledges** we cannot protect everything with limited resources—transparent criteria prevent political favoritism
#
# ---
#
# #### **2.2 Economic Diversification & Just Transition Program**
#
# **Interventions:**
# - "Green Industrial Park" (80 acres) on elevated inland site: recruit marine renewable energy, aquaculture, climate adaptation technology companies
# - Maritime heritage tourism expansion in adapted historic district (elevated museums, waterfront promenade)
# - Workforce transition program: 500 petrochemical workers trained in offshore wind installation, wetland restoration, green construction
# - Small business relocation grants ($50K each × 100 businesses) for moving from high-risk zones
# - University partnership for "Coastal Resilience Research Center" (30 permanent jobs, grad students)
#
# **Cost Estimate:** $45-65M
# - Industrial park land acquisition & prep: $15M
# - Recruitment incentives: $10M
# - Workforce training: $8M
# - Business relocation grants: $5M
# - Tourism infrastructure: $15M
# - Research center building: $12M
#
# **Financing:**
# - Economic Development Administration grants: $15M
# - State workforce development funds: $8M
# - New Markets Tax Credits: $12M
# - Regional economic development bonds: $10M
# - University co-investment: $8M
# - Tourism development taxes: $7M
#
# **Governance:**
# - "Economic Transition Commission" with labor union representatives, business community, workforce development board
# - Hiring preferences for local workers and displaced residents
# - Annual economic diversification metrics published
#
# **Performance Indicators:**
# - 300 new jobs created outside petrochemical sector by Year 5
# - Unemployment rate in affected communities remains <1.5× city average
# - 200 workers completed transition training by Year 6
# - Petrochemical employment dependency drops from 12% to 9%
# - $30M private investment leveraged in Green Industrial Park
#
# **Justification:** Economic diversification reduces catastrophic risk if petrochemical facility closes while providing options for workers. Training must begin before displacement crisis. Tourism leverages existing historic assets while creating climate-compatible economy.
#
# ---
#
# #### **2.3 Equitable Housing & Community Preservation**
#
# **Interventions:**
# - Build 600 affordable housing units on elevated inland sites (80% for buyout participants, 20% general affordable housing)
# - "Cultural Continuity Program": Relocate community institutions (churches, cultural centers, social clubs) to new neighborhoods as anchors
# - Historic district "Adaptive Preservation Districts" allowing density bonuses for elevation-compliant development
# - Tenant relocation assistance ($15K per household × 400 renters in buyout zones)
# - Community land trust model to prevent gentrification in receiving neighborhoods
#
# **Cost Estimate:** $95-120M
# - Affordable housing construction: $75M (600 × $125K)
# - Community institution relocation: $10M
# - Tenant assistance: $6M
# - Land trust capitalization: $4M
# - Planning and architecture: $5M
#
# **Financing:**
# - HUD affordable housing grants: $30M
# - Low-Income Housing Tax Credits: $25M
# - State housing trust fund: $15M
# - Municipal housing bonds: $15M
# - Philanthropic (Ford Foundation, MacArthur, etc.): $10M
# - Community land trust loans: $10M
#
# **Governance:**
# - "Community Preservation Taskforce" with majority membership from affected neighborhoods
# - Resident choice in housing placement (not dictated by city)
# - Cultural heritage consultants embedded in design process
# - Anti-displacement monitoring committee
#
# **Performance Indicators:**
# - 100% of buyout participants offered comparable housing within city limits
# - 80% of relocated residents report satisfaction with new housing (survey)
# - Zero net loss of minority-owned businesses from affected areas
# - 4 community institutions successfully relocated
# - Housing cost burden in receiving neighborhoods increases <5%
#
# **Justification:** Climate adaptation typically displaces vulnerable populations and destroys communities of color. Explicit counteraction required for equity. Community-led design maintains cultural fabric. Preventing gentrification in receiving areas is critical—climate migrants should not displace other vulnerable people.
#
# ---
#
# ### **PHASE 3: LONG-TERM TRANSFORMATION (Years 6-10)**
#
# #### **3.1 Blue-Green Infrastructure Network**
#
# **Interventions:**
# - 8-mile "Resilient Waterfront Promenade" through former buyout areas (elevated paths, native vegetation, public art, fishing piers)
# - 500-acre tidal wetland restoration creating ecological buffer
# - "Living shoreline" treatments along 12 miles of coastline
# - Bioswale network for stormwater management citywide
# - Urban agriculture program on 100 acres of buyout land (community gardens, climate-adapted crops)
#
# **Cost Estimate:** $55-75M
# - Promenade construction: $20M
# - Wetland restoration: $15M
# - Living shorelines: $18M
# - Stormwater infrastructure: $12M
# - Urban agriculture: $10M
#
# **Financing:**
# - EPA wetland restoration grants: $15M
# - National Fish & Wildlife Foundation: $10M
# - State green infrastructure fund: $12M
# - Municipal bonds: $15M
# - Conservation easement sales: $8M
#
# **Performance Indicators:**
# - Coastal flood damage reduced 40% vs. no-action baseline
# - 400 acres of new habitat created
# - Water quality improvements (measured nitrogen/phosphorus)
# - 50,000 annual visitors to promenade
# - 200 residents participating in urban agriculture
#
# **Justification:** Blue-green infrastructure provides multiple benefits: flood protection, recreation, ecological restoration, food security, mental health. Converts loss (abandoned homes) into community assets. Creates new identity as "climate-adapted coastal city."
#
# ---
#
# #### **3.2 Adaptive Governance & Learning Systems**
#
# **Interventions:**
# - Institutionalize 5-year adaptation plan updates with community participation
# - Create "Climate Adaptation Trust Fund" ($200M target endowment) for ongoing resilience work
# - Establish "Resilience Academy" training program (share lessons with other coastal cities, generate revenue)
# - Real-time monitoring dashboard for all KPIs (public access)
# - Sister city partnerships for knowledge exchange (Netherlands, Bangladesh, Miami)
#
# **Cost Estimate:** $15-25M
# - Endowment seed capital: $10M
# - Monitoring systems: $5M
# - Academy development: $5M
# - Knowledge exchange: $2M
#
# **Financing:**
# - Federal technical assistance grants: $5M
# - Philanthropic endowment contributions: $8M
# - Revenue from academy programs: $3M (recurring)
# - Municipal commitment: $7M
#
# **Performance Indicators:**
# - Trust fund reaches $50M by Year 10
# - Adaptation plan updated on schedule with >1,000 public comments
# - 200 professionals trained through academy
# - Decision-making response time: new data → plan update <18 months
#
# **Justification:** Climate adaptation is multi-generational. Current leaders must build institutions that survive political turnover. Trust fund provides non-appropriated funding preventing political capture. Learning systems ensure evolution as conditions change.
#
# ---
#
# ## CONSOLIDATED TIMELINE
#
# | Year | Major Milestones |
# |------|------------------|
# | 0-1 | Risk assessment complete; Resilience Commission formed; sensor network installed; first town halls |
# | 1-2 | Emergency plans tested; buyout program launches; petrochemical levee design complete; historic district trust formed |
# | 2-3 | First 200 buyouts complete; workforce training begins; petrochemical levee construction starts |
# | 3-5 | 500 buyouts complete; affordable housing construction; historic structure elevations begin; Green Industrial Park opens |
# | 5-7 | Petrochemical protection complete; 45 historic buildings elevated; first wetland restoration areas functional |
# | 7-10 | Remaining buyouts and housing; promenade construction; trust fund capitalized; comprehensive program evaluation |
#
# ---
#
# ## CONSOLIDATED BUDGET
#
# | Category | Total Cost | Federal | State | Local | Private |
# |----------|-----------|---------|-------|-------|---------|
# | Assessment & Planning | $5M | $3M | - | $2M | - |
# | Emergency Systems | $12M | $5M | $3M | $4M | - |
# | Infrastructure Protection | $360M | $200M | $50M | $70M | $40M |
# | Economic Diversification | $60M | $15M | $8M | $17M | $20M |
# | Equitable Housing | $115M | $55M | $15M | $15M | $30M |
# | Blue-Green Infrastructure | $70M | $25M | $12M | $23M | $10M |
# | Governance & Learning | $20M | $5M | - | $7M | $8M |
# | **TOTAL** | **$642M** | **$308M (48%)** | **$88M (14%)** | **$138M (21%)** | **$108M (17%)** |
#
# **Annual municipal burden:** ~$14M/year over 10 years (manageable for $300K population with ~$300M annual budget = ~5% of budget)
#
# ---
#
# ## KEY ASSUMPTIONS & UNCERTAINTIES
#
# ### **Critical Assumptions:**
#
# 1. **Sea-level rise follows "intermediate" scenario** (1.5-2 feet by 2055) rather than high-end projections (3-4 feet)
#    - *Sensitivity:* High-end scenario makes petrochemical protection significantly more expensive, potentially requiring full relocation
#
# 2. **Federal cost-share programs remain available** at current ~65% levels
#    - *Sensitivity:* 50% reduction in federal funding would require doubling local taxation or cutting protection scope by 40%
#
# 3. **Petrochemical plant remains economically viable** for 30+ years and will co-invest in protection
#    - *Sensitivity:* Early closure eliminates 12% of jobs and major funding source; accelerates need for economic diversification
#
# 4. **70% voluntary buyout participation rate** among targeted properties
#    - *Sensitivity:* <50% participation creates "Swiss cheese" landscape with unprotected holdouts blocking blue-green infrastructure
#
# 5. **Property values in protected zones stabilize** rather than continuing decline
#    - *Sensitivity:* Continued decline reduces tax base and land value capture financing
#
# 6. **Political continuity** allows 10-year implementation (survives 2-3 mayoral elections)
#    - *Sensitivity:* Administration change could halt programs, strand investments
#
# 7. **No major flood events** in Years 0-3 before protection infrastructure complete
#    - *Sensitivity:* Major flood could trigger panic exodus, property value collapse, or demand for faster (more expensive/less equitable) solutions
#
# 8. **State/federal regulations** don't prohibit strategic retreat or development in protected zones
#    - *Sensitivity:* Regulatory changes could invalidate entire approach
#
# ### **Major Uncertainties:**
#
# - **Climate acceleration:** Greenland/Antarctic ice sheet dynamics could accelerate SLR unpredictably
# - **Storm frequency/intensity:** Hurricane behavior under climate change poorly constrained
# - **Social cohesion:** Polarization could worsen, preventing necessary tax increases or program acceptance
# - **Technology development:** New flood protection technologies could change cost-benefit calculations
# - **Regional coordination:** Neighboring jurisdictions' decisions affect flooding patterns and economic competitiveness
# - **Insurance market:** Private flood insurance withdrawal could accelerate exodus regardless of infrastructure
# - **Petrochemical industry transitions:** Global decarbonization could strand local plant sooner than expected
# - **Demographics:** Population growth/decline changes infrastructure needs and tax base
#
# ---
#
# ## ALTERNATIVE STRATEGIES & TRADE-OFFS
#
# ### **Alternative 1: Maximum Protection ("Fortress City")**
#
# **Approach:** Build comprehensive seawall system protecting entire current urban footprint; no managed retreat; rely on engineering.
#
# **Trade-offs:**
# - *Pros:* No displacement; preserves all property rights; maintains tax base; politically easier
# - *Cons:* Estimated cost $1.2-1.8B (3× proposed strategy); requires perpetual maintenance ($15M/year); catastrophic failure risk if overtopped; environmental damage; no adaptation to higher SLR scenarios; entrenches unsustainable development pattern
# - *Equity impacts:* Benefits property owners over renters; uses public funds to protect private property; no economic diversification
# - *Why rejected:* Financially unsustainable for city this size; inflexible; high-consequence failure mode
#
# ### **Alternative 2: Accelerated Retreat ("Planned Shrinkage")**
#
# **Approach:** Immediate comprehensive buyout of all at-risk properties (2,500+ parcels); abandon 20% of urban area in Years 0-5; rebuild compact city on high ground.
#
# **Trade-offs:**
# - *Pros:* Long-term cheapest (~$500M total); removes people from harm's way quickly; creates clean slate for sustainable design; honest about climate reality
# - *Cons:* Massive disruption; community destruction; petrochemical plant likely closes (can't protect in time); 12% unemployment spike; politically impossible; rental housing demolished before alternatives exist
# - *Equity impacts:* Catastrophic displacement of minority historic district; renters displaced first; social networks destroyed
# - *Why rejected:* Social costs exceed financial savings; destroys economic base before alternatives ready; equity disaster; lacks political feasibility
#
# ### **Alternative 3: Market-Based Adaptation ("Disclosure & Retreat")**
#
# **Approach:** Minimal government intervention; require flood risk disclosure; eliminate subsidized flood insurance; allow market-driven migration; focus public funds only on infrastructure that can't relocate.
#
# **Trade-offs:**
# - *Pros:* Low public cost ($50M for critical infrastructure only); respects property rights; economically efficient; avoids picking winners/losers
# - *Cons:* Catastrophic inequity (wealthy can afford elevation, poor cannot); historic district destroyed; chaotic migration; property value collapse; stranded infrastructure; no community planning
# - *Equity impacts:* Worst outcomes for vulnerable populations; racial/ethnic minority historic district abandoned; working-class homeowners lose life savings
# - *Why rejected:* Violates equity principles; destroys cultural heritage; creates slums in unprotected areas; politically/morally unacceptable
#
# ---
#
# ## TOP 5 CRITICAL DATA NEEDS & DECISION TRIGGERS
#
# ### **1. Updated Sea-Level Rise Projections (from IPCC/NOAA)**
#
# **Current uncertainty:** ±0.5-1.0 foot in 30-year projection due to ice sheet dynamics
#
# **Decision rule:**
# - **If SLR projection increases >0.5 feet:**
#   - Elevate petrochemical levee design by additional 2 feet (+$25M)
#   - Expand buyout zone to include properties in new 50-year floodplain (~300 additional homes)
#   - Accelerate timeline by 2 years (front-load protection)
#   - Increase trust fund target to $300M
#
# - **If SLR projection decreases >0.3 feet:**
#   - Reduce levee elevation (save ~$15M)
#   - Redirect savings to economic diversification and historic preservation
#   - Extend timeline to 12 years (allow more planning)
#
# **Monitoring:** Annual NOAA reports; biannual sea-level gauge data analysis; updates every 5 years or when IPCC releases new assessment
#
# ---
#
# ### **2. Petrochemical Plant Economic Viability Assessment**
#
# **Current uncertainty:** Corporate long-term plans; global market for products; decarbonization trajectory
#
# **Decision rule:**
# - **If plant announces closure timeline <15 years:**
#   - Immediately halt levee construction (save $80M unspent)
#   - Redirect 100% of funds to economic diversification and workforce transition
#   - Accelerate Green Industrial Park by 3 years
#   - Expand training programs from 500 to 2,000 workers
#   - Seek state/federal disaster economic assistance designation
#
# - **If plant commits to 30+ year operation with investments:**
#   - Negotiate higher cost-share (from 40% to 50%)
#   - Explore joint workforce development programs
#   - Plan industrial park for compatible industries (supply chain)
#
# **Monitoring:** Annual meetings with plant management; tracking corporate sustainability reports; industry analyst reports; regulatory filings
#
# ---
#
# ### **3. Buyout Program Participation Rates (actual vs. projected 70%)**
#
# **Current uncertainty:** Community willingness to relocate; adequacy of compensation; housing alternatives
#
# **Decision rule:**
# - **If participation <50% after 2 years:**
#   - Increase compensation to 125% pre-flood FMV (+$30M)
#   - Expand affordable housing construction by 200 units (+$25M)
#   - Conduct focus groups to identify barriers
#   - Consider right of first refusal (city can purchase at market value before outside buyers)
#   - May need to revise blue-green infrastructure plans to accommodate holdouts
#
# - **If participation >80%:**
#   - Expand buyout zone to include next-tier moderate-risk properties (voluntary)
#   - Reduce per-property compensation to 105% FMV (save ~$8M)
#   - Accelerate blue-green infrastructure construction
#
# **Monitoring:** Monthly participation tracking; quarterly satisfaction surveys; comparison with similar programs nationally
#
# ---
#
# ### **4. Federal Funding Availability (actual vs. projected $308M)**
#
# **Current uncertainty:** Congressional appropriations; grant competition; program changes; political shifts
#
# **Decision rule:**
# - **If federal funding <$200M (65% shortfall):**
#   - **Tier A (petrochemical):** Maintain full protection but require plant to pay 60% instead of 40% (negotiate as condition of operation)
#   - **Tier B (historic district):** Shift to lower-cost interventions (deployable barriers only, defer elevations)
#   - **Tier C (buyouts):** Reduce from 800 to 500 properties (prioritize most vulnerable + historic district residents)
#   - Seek state disaster declaration for additional resources
#   - Consider municipal tax increase referendum (sales tax 0.75% vs. 0.5%)
#
# - **If federal funding >$350M:**
#   - Expand historic structure elevations from 50 to 75
#   - Increase buyout generosity to 115% FMV
#   - Accelerate timeline by 1 year
#   - Add resilience features (distributed solar, microgrids)
#
# **Monitoring:** Quarterly grant application tracking; federal budget monitoring; relationships with congressional delegation
#
# ---
#
# ### **5. Flood Event Occurrence (before protections complete)**
#
# **Current uncertainty:** Timing and severity of hurricanes/storm surge; compound flooding
#
# **Decision rule:**
# - **If major flood (>$100M damage) occurs in Years 0-3:**
#   - Declare emergency; activate FEMA disaster assistance
#   - Immediately implement temporary flood barriers (T-walls, sandbags) around critical facilities
#   - Accelerate buyout program with emergency funding (target 400 properties in 18 months)
#   - Fast-track petrochemical protection by 1 year (accept higher cost)
#   - Likely triggers federal Community Development Block Grant - Disaster Recovery funding (~$50-100M)
#   - May require shifting from voluntary to incentivized buyouts (higher compensation, relocation assistance)
#   - Expect property value collapse in unprotected areas—may enable cheaper land acquisition
#
# - **If no significant flooding through Year 5:**
#   - Risk of complacency; maintain communication efforts
#   - Opportunity to extend timeline and reduce annual budget burden
#   - Redirect 10% of contingency funds to co-benefits (parks, amenities)
#
# **Monitoring:** Real-time flood sensor network; annual hurricane season preparedness; after-action reviews for all events >6-inch flooding
#
# ---
#
# ## IMPLEMENTATION GOVERNANCE
#
# ### **Accountability Structure:**
#
# 1. **Mayor/City Council:** Policy oversight; budget approval; public accountability
# 2. **Climate Adaptation Office:** Day-to-day management (15 FTE); coordination
# 3. **Resilience Commission:** Community representation; advisory; equity watchdog
# 4. **Scientific Advisory Panel:** Technical review; independent validation
# 5. **Property Acquisition Authority:** Buyout implementation (separate legal entity)
# 6. **Economic Transition Commission:** Workforce and business support
# 7. **Historic District Trust:** Cultural heritage preservation
#
# ### **Communication Strategy:**
#
# - **Monthly:** Council briefings; Commission meetings (public)
# - **Quarterly:** Town halls in each district; published progress reports; KPI dashboard updates
# - **Annually:** Comprehensive report card; independent audit; community survey
# - **Ongoing:** Multilingual materials; door-to-door outreach in vulnerable areas; social media; partnership with local media for fact-based reporting
#
# ### **Conflict Resolution:**
#
# - Ombudsman position for resident complaints
# - Mediation services for property disputes
# - Appeals process for buyout valuations (independent appraisal)
# - Regular dialogue between polarized groups (facilitated by neutral third parties)
#
# ---
#
# ## EQUITY SAFEGUARDS
#
# 1. **No net displacement:** Every household gets comparable housing option
# 2. **Cultural continuity:** Community institutions move together; maintain social networks
# 3. **Economic opportunity:** Job training and hiring preferences for affected workers
# 4. **Wealth preservation:** Above-market buyouts prevent life-savings loss
# 5. **Participation rights:** Meaningful community engagement in all decisions affecting neighborhoods
# 6. **Benefit sharing:** Improvements in protected areas (parks, waterfront access) open to all residents
# 7. **Anti-gentrification:** Community land trust in receiving neighborhoods
# 8. **Language access:** All materials in Spanish, Vietnamese, other dominant languages
# 9. **Monitoring:** Quarterly equity metrics (by race, income, neighborhood)
#
# ---
#
# ## JUSTIFICATION SYNTHESIS
#
# This strategy is built on six core principles:
#
# **1. Protect lives first, property second:** Emergency preparedness is immediate and universal.
#
# **2. Economic realism:** The petrochemical plant is both a risk and necessity. Protect it while diversifying away from dependence.
#
# **3. Equity as strategy, not afterthought:** Displacement destroys communities and generates opposition. Generous buyouts and housing alternatives are investments in social cohesion, not charity.
#
# **4. Cultural heritage has economic and intrinsic value:** The historic district differentiates this city and attracts tourism. Adaptive preservation is cheaper than loss.
#
# **5. Transparency builds trust:** Polarized communities need shared facts. Open data and inclusive governance create legitimacy.
#
# **6. Adaptation is continuous:** No 10-year plan survives reality. Build institutions for learning and updating.
#
# The strategy rejects false choices (protection vs. retreat, economy vs. environment, efficiency vs. equity) in favor of sequenced interventions that create space for complexity. It acknowledges we cannot save everything, makes tough prioritization transparent, and compensates those who lose. It treats climate adaptation not as engineering problem but as social transformation requiring political skill equal to technical expertise.
#
# Most critically: **it starts now with available resources rather than waiting for perfect information or sufficient funding.** Every year of delay increases costs and reduces options.

# %%
model_name = "gemini-2.5-flash"
answer = ChatModel(
            model_name=model_name,
            provider="google",
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# Mayor,
#
# This is a critical juncture for our city. The projected sea-level rise (SLR) presents an existential challenge, demanding a proactive, balanced, and politically savvy strategy. Our goal for the next 10 years is to lay an irreversible foundation for adaptation, ensuring the city remains viable and vibrant over the 30-year horizon and beyond.
#
# Given the limited municipal funds, existing economic reliance, cultural sensitivity, and political polarization, our strategy must prioritize **data-driven decision-making, broad stakeholder engagement, and a phased "protect where critical, adapt where possible, retreat where necessary" approach.** This plan balances immediate needs with long-term resilience, focusing on equitable outcomes and economic diversification.
#
# ---
#
# ## **Prioritized 10-Year Strategy for Sea-Level Rise Adaptation**
#
# The strategy is structured around four interconnected pillars, ordered by their logical progression and urgency.
#
# ### **Pillar 1: Foundational Assessment & Collaborative Resilience Planning (Years 1-3)**
#
# **Goal:** Establish a shared understanding of risks, build consensus on core principles, and develop a comprehensive, legally sound adaptation framework. This is our "no regrets" phase.
#
# 1.  **Intervention: High-Resolution Vulnerability & Risk Assessment**
#     *   **Specifics:** Commission LiDAR-based topographical surveys, hydrodynamic modeling for various SLR scenarios (e.g., +1ft, +3ft, +5ft), detailed socio-economic vulnerability mapping (identifying at-risk populations, critical infrastructure, cultural sites, and economic assets including the petrochemical plant). This also includes infrastructure audits (stormwater, wastewater, power grids).
#     *   **Order-of-Magnitude Cost:** $2 - $4 Million
#     *   **Financing:** Primarily federal grants (FEMA BRIC, NOAA Coastal Resilience Grants), state resilience funds, potential philanthropic contributions.
#     *   **Governance & Communication:** Led by a newly established *Office of Coastal Resilience* (reporting to Mayor), with input from City Planning, Public Works, and an independent scientific advisory panel. Findings presented in clear, accessible language through public meetings, interactive online maps, and multilingual fact sheets.
#     *   **Performance Indicators:** Completion of detailed SLR maps and vulnerability reports; establishment of a publicly accessible data portal; number of grant applications submitted.
#     *   **Phased Timeline:**
#         *   **Year 1:** Secure funding, hire/contract expertise, commence data collection and modeling.
#         *   **Year 2:** Publish preliminary vulnerability maps, conduct initial stakeholder workshops.
#         *   **Year 3:** Finalize comprehensive assessment report, integrate into city planning documents.
#
# 2.  **Intervention: Inclusive Resilience Master Plan & Zoning Overhaul**
#     *   **Specifics:** Develop a new "Coastal Resilience Master Plan" that integrates SLR projections into all aspects of city development (land use, infrastructure, housing). This includes updating zoning ordinances to restrict new development in high-risk areas, establish building elevation standards, create "resilience zones" for future growth, and enable innovative solutions like transferable development rights (TDRs) for impacted properties.
#     *   **Order-of-Magnitude Cost:** $3 - $6 Million
#     *   **Financing:** Municipal general fund, state planning grants, portion of federal resilience grants.
#     *   **Governance & Communication:** Resilience Office, City Planning Department, and a diverse *Citizens' Resilience Task Force* (with representatives from affected communities, businesses, environmental groups, and the historic district). Extensive public hearings, workshops, and design charrettes to co-create solutions. Emphasize "preparing for the future" over "retreat."
#     *   **Performance Indicators:** Adoption of Coastal Resilience Master Plan; passage of revised zoning ordinances; number of public engagement sessions and participant attendance.
#     *   **Phased Timeline:**
#         *   **Year 1:** Establish Task Force, define planning scope, draft initial policy principles.
#         *   **Year 2:** Public engagement on draft plan, technical reviews, economic impact assessments.
#         *   **Year 3:** Finalize plan, secure City Council adoption, begin implementing zoning changes.
#
# ### **Pillar 2: Targeted Adaptation & Strategic Relocation Preparedness (Years 3-7)**
#
# **Goal:** Implement immediate, high-priority protective measures while actively preparing for managed retreat in the most vulnerable areas.
#
# 1.  **Intervention: Critical Infrastructure & Heritage Protection (Hybrid Approach)**
#     *   **Specifics:** Based on Pillar 1, identify and implement *targeted* protection for critical public infrastructure (e.g., wastewater treatment plants, key transportation arteries) and the most irreplaceable structures within the ancient historic district. This will be a hybrid approach:
#         *   **Nature-Based Solutions:** Restore/create coastal wetlands, oyster reefs, dune systems, and living shorelines where feasible (less costly, ecological benefits).
#         *   **Adaptive Hard Infrastructure:** Targeted elevation of critical facilities, permeable flood barriers, and potentially strategically placed, adaptable sea walls for essential assets (e.g., the petrochemical plant, if deemed critical to protect in place for the medium term). Prioritize interventions that offer co-benefits (e.g., green spaces, improved public access).
#     *   **Order-of-Magnitude Cost:** $75 - $150 Million (Highly variable based on specific assets and chosen solutions)
#     *   **Financing:** Federal infrastructure grants (IIJA funds, FEMA BRIC), state climate bonds, Public-Private Partnerships (PPP) for assets like the petrochemical plant (they have a vested interest in their protection), municipal bonds.
#     *   **Governance & Communication:** Public Works, Resilience Office, Historic Preservation Commission, environmental agencies. Emphasize the economic and cultural value being protected. For the petrochemical plant, direct negotiations and a formal agreement on shared costs and responsibilities.
#     *   **Performance Indicators:** Miles of coastline with nature-based solutions; number of critical facilities elevated/protected; condition assessments of protected historic assets.
#     *   **Phased Timeline:**
#         *   **Year 3-4:** Detailed engineering and environmental studies for priority projects, secure permitting and initial funding.
#         *   **Year 5-7:** Commence construction of nature-based solutions and adaptive hard infrastructure.
#
# 2.  **Intervention: Economic Diversification & Workforce Transition Fund**
#     *   **Specifics:** Establish a dedicated fund to incentivize new, resilient industries (e.g., renewable energy technologies, blue economy sectors like sustainable aquaculture, specialized manufacturing, tech services) and provide robust workforce retraining for those potentially affected by changes in the petrochemical sector or other vulnerable industries. This includes supporting small businesses in vulnerable areas to relocate or adapt.
#     *   **Order-of-Magnitude Cost:** $20 - $40 Million
#     *   **Financing:** Federal EDA grants, state economic development funds, private sector investment, local bond issues dedicated to economic development, re-purposing of some existing municipal economic development budgets.
#     *   **Governance & Communication:** Economic Development Office, Workforce Development Board, Chamber of Commerce, in direct consultation with petrochemical plant management and unions. Messaging focused on "future-proofing our economy" and "creating new opportunities," addressing anxieties about job loss proactively.
#     *   **Performance Indicators:** Number of new jobs created in resilient sectors; percentage of workforce trained for new industries; private investment attracted; number of small businesses supported/relocated.
#     *   **Phased Timeline:**
#         *   **Year 3:** Launch fund, identify target industries, establish training partnerships.
#         *   **Year 4-7:** Begin incentive programs, fund new business incubators, implement workforce retraining.
#
# 3.  **Intervention: Voluntary Managed Retreat & Land Banking Program**
#     *   **Specifics:** For areas identified as highly vulnerable where protection is unfeasible or cost-prohibitive, establish a voluntary buy-out and relocation assistance program. Begin with unoccupied or severely damaged properties. Crucially, identify and acquire suitable "resilience zones" on higher ground for future development or relocation sites (land banking). Develop a framework for equitable property valuation and relocation support, ensuring displaced residents, particularly those from the historic minority community, are offered fair market value and assistance to move to comparable or better housing.
#     *   **Order-of-Magnitude Cost:** $50 - $100 Million (initial phase; scales up significantly over 30 years)
#     *   **Financing:** Federal CDBG-DR funds, HUD grants, FEMA Hazard Mitigation Grant Program, state bonds for climate relocation, municipal bonds.
#     *   **Governance & Communication:** Housing Authority, Resilience Office, City Planning, and a dedicated community outreach team working directly with affected neighborhoods. Emphasize "voluntary choice," "fair compensation," and "building a safer future."
#     *   **Performance Indicators:** Number of properties voluntarily acquired; acres of land banked; number of households receiving relocation assistance; establishment of a community land trust for equitable redevelopment.
#     *   **Phased Timeline:**
#         *   **Year 4:** Design program, establish fair valuation protocols, identify initial target areas (e.g., vacant lots, repeatedly flooded properties).
#         *   **Year 5-7:** Commence voluntary buy-outs and land banking, engage with communities on potential relocation sites.
#
# ### **Pillar 3: Equitable Transition & Long-Term Stewardship (Years 7-10)**
#
# **Goal:** Accelerate the transition to a more resilient city, focusing on the social dimensions of adaptation and institutionalizing long-term stewardship.
#
# 1.  **Intervention: Historic & Cultural Heritage Preservation**
#     *   **Specifics:** For the ancient historic district, beyond the most critical structures identified in Pillar 2:
#         *   **Digital Archiving & Storytelling:** Create comprehensive 3D scans, photographic records, and oral histories to preserve the cultural narrative.
#         *   **Phased Relocation/Elevation Studies:** Explore feasibility and cost for *selected* historic structures (not necessarily all) to be physically moved or elevated.
#         *   **Community-Led Adaptive Reuse:** Work with the minority community to identify structures and traditions to be preserved on higher ground or adapted in place through community-led initiatives. Establish a community land trust specifically for the historic district.
#     *   **Order-of-Magnitude Cost:** $15 - $30 Million (digital + initial studies + limited physical interventions)
#     *   **Financing:** National Park Service grants, state historic preservation funds, philanthropic foundations, targeted federal grants for cultural heritage resilience, community development block grants (CDBG).
#     *   **Governance & Communication:** Historic Preservation Commission, Resilience Office, community leaders from the minority group, university partners (for archiving). Communication must be deeply respectful, culturally sensitive, and transparent, emphasizing "preserving identity, not just buildings."
#     *   **Performance Indicators:** Completion of digital archive; number of historic assets physically protected or relocated; establishment of community-led preservation initiatives.
#     *   **Phased Timeline:**
#         *   **Year 7:** Launch comprehensive digital archiving project, begin detailed studies for select structural interventions.
#         *   **Year 8-10:** Commence implementation of targeted physical preservation efforts and community-led adaptive reuse projects.
#
# 2.  **Intervention: Resilient Housing & Infrastructure Development**
#     *   **Specifics:** Begin developing new, climate-resilient affordable housing options in the identified "resilience zones." This includes climate-smart building codes, green infrastructure for stormwater management in new developments, and integrated utility planning. Prioritize housing for those displaced by SLR, particularly low-income residents and the historic community.
#     *   **Order-of-Magnitude Cost:** $40 - $80 Million (initial phase of new development)
#     *   **Financing:** HUD grants, Low-Income Housing Tax Credits (LIHTC), state housing bonds, municipal affordable housing funds, private development partnerships incentivized by resilience zoning.
#     *   **Governance & Communication:** Housing Authority, City Planning, Resilience Office, private developers. Messaging focuses on "building a safer, healthier, more equitable city for all."
#     *   **Performance Indicators:** Number of new resilient housing units constructed; reduction in flood insurance rates in new zones; adoption of green infrastructure standards.
#     *   **Phased Timeline:**
#         *   **Year 7:** Finalize master plans for resilience zones, secure developer partnerships.
#         *   **Year 8-10:** Commence construction of first resilient housing developments and associated infrastructure.
#
# ---
#
# ### **Summary of 10-Year Order-of-Magnitude Costs:**
#
# *   **Pillar 1 (Assessment & Planning):** $5 - $10 Million
# *   **Pillar 2 (Adaptation & Economic):** $145 - $290 Million
# *   **Pillar 3 (Equity & Transition):** $55 - $110 Million
# *   **Total Estimated 10-Year Cost:** **$205 - $410 Million**
#
# This is a significant investment but pales in comparison to the costs of inaction and represents a fraction of the value of the 20% of urban land at risk.
#
# ---
#
# ## **Key Assumptions and Uncertainties**
#
# **Key Assumptions:**
#
# 1.  **SLR Projections:** The assumption that current 30-year SLR projections are largely accurate and will render 20% of land unusable. While there's a range, the mean scenario is used for planning.
# 2.  **Federal & State Funding:** Significant availability of federal and state grants for climate resilience, infrastructure, economic development, and housing will continue and potentially increase.
# 3.  **Political Will:** Despite current polarization, sufficient political will can be generated to pursue a long-term, potentially challenging adaptation strategy, aided by strong leadership and evidence.
# 4.  **Public Acceptance:** A degree of public acceptance for concepts like managed retreat and new development regulations can be achieved through transparent, equitable, and inclusive engagement.
# 5.  **Private Sector Cooperation:** The petrochemical plant and other major businesses will engage constructively in adaptation planning and potentially contribute financially.
# 6.  **Technological Feasibility:** Engineered solutions (e.g., elevation, targeted barriers) and nature-based solutions are technologically feasible and effective at the scale required.
#
# **Key Uncertainties:**
#
# 1.  **Exact Rate of SLR:** While projections exist, the precise rate and extreme event frequency (storm surge) are uncertain, impacting the speed and scale of required interventions.
# 2.  **Future Funding Levels:** Federal and state priorities and budget allocations can change, potentially reducing available funds or delaying projects.
# 3.  **Political Landscape:** Intensified political polarization or changes in leadership could derail or significantly alter the plan.
# 4.  **Community Resistance:** Strong opposition to managed retreat, new zoning, or specific infrastructure projects could slow or halt implementation.
# 5.  **Economic Shocks:** Unforeseen economic downturns could reduce municipal revenue, private investment, and public capacity to absorb costs.
# 6.  **Petrochemical Plant's Future:** The plant's long-term operational plans (expansion, divestment, closure) are a significant unknown that could profoundly impact the city's economy and adaptation needs.
# 7.  **Technological Advancements:** New, unforeseen technologies could emerge that offer cheaper or more effective adaptation solutions.
#
# ---
#
# ## **Alternative Strategies & Trade-offs**
#
# 1.  **Strategy: Aggressive "Hold the Line" (Full Protection)**
#     *   **Main Approach:** Prioritize large-scale, comprehensive hard infrastructure like massive seawalls, dikes, and pumping stations to protect virtually all current urban land.
#     *   **Trade-offs:**
#         *   **Pros:** Potentially retains all current land, reduces immediate displacement, maintains existing property values in the short term, provides a sense of security.
#         *   **Cons:** **Extremely high cost** (likely billions), significant ecological damage (loss of wetlands, altered hydrology), creates a "bathtub effect" (trapping rainwater), provides a *false sense of security* (eventual overtopping or failure is likely), defers the problem to future generations, limited long-term sustainability. Politically attractive initially, but unsustainable.
#
# 2.  **Strategy: Rapid "Strategic Abandonment" (Full Retreat)**
#     *   **Main Approach:** Proactively plan for and implement widespread, rapid managed retreat from all projected inundation zones within the 10-year horizon, with minimal new protective infrastructure.
#     *   **Trade-offs:**
#         *   **Pros:** Potentially lower long-term infrastructure costs, creates large ecological buffer zones, aligns with extreme SLR scenarios.
#         *   **Cons:** **Massive social disruption and displacement**, huge economic losses (property value depreciation, business closures), immense political and social resistance, loss of cultural heritage (especially the historic district), ethical challenges regarding compensation and equitable relocation. Impractical and likely politically infeasible for 20% of a city within 10 years.
#
# 3.  **Strategy: Reactive "Muddle Through" (Ad-hoc Response)**
#     *   **Main Approach:** Avoid proactive planning and significant upfront investment. Address SLR impacts only as they become critical (e.g., after major storm events, when areas become permanently inundated), relying on emergency response and fragmented, crisis-driven solutions.
#     *   **Trade-offs:**
#         *   **Pros:** Minimal upfront capital expenditure, defers difficult political decisions.
#         *   **Cons:** **Significantly higher long-term costs** (emergency repairs, repeated disaster declarations), greater loss of life and property, exacerbated social inequities (vulnerable populations hit hardest), economic decline due to chronic disruption, loss of investor confidence, irreversible damage to cultural heritage. This approach inevitably leads to panic and chaotic adaptation, not strategic resilience.
#
# ---
#
# ## **Top Five New Data Points and Plan Updates**
#
# 1.  **New Data: Refined SLR Projections indicating significantly FASTER inundation (e.g., 20% land lost in 15 years instead of 30).**
#     *   **Update:**
#         *   **Urgency:** Accelerate all timelines.
#         *   **Pillar 1:** Fast-track assessment and master plan completion (e.g., 18-24 months).
#         *   **Pillar 2:** Shift emphasis more heavily towards strategic retreat and land banking, increasing funding and urgency for voluntary buy-outs. Prioritize protection only for the *most* critical and irreplaceable assets with immediate threat. Rapidly expand economic diversification programs to prepare for larger-scale displacement sooner.
#         *   **Pillar 3:** Expedite resilient housing development and cultural heritage preservation (e.g., more emphasis on digital archiving and relocation studies for historic structures).
#         *   **Funding:** Aggressively pursue emergency federal/state funding for rapid adaptation.
#
# 2.  **New Data: A major federal or philanthropic initiative announces a multi-billion-dollar grant program specifically for coastal cities pursuing managed retreat, with our city being a strong candidate.**
#     *   **Update:**
#         *   **Financing:** Drastically increase the scope and speed of the Voluntary Managed Retreat & Land Banking Program (Pillar 2), potentially converting it from "voluntary preparedness" to a more active "managed relocation" program.
#         *   **Pillar 2 & 3:** Expand funding for equitable compensation, relocation assistance, and the development of new resilient communities. This could also free up municipal funds for other pillars.
#         *   **Scale:** Consider a larger scale for nature-based solutions and economic diversification, knowing a major funding stream is secured.
#         *   **Political Consensus:** Leverage the funding opportunity to build stronger political consensus for difficult decisions.
#
# 3.  **New Data: The petrochemical plant announces plans to *relocate* a significant portion of its operations or *close* within 10-15 years due to climate risk or market shifts.**
#     *   **Update:**
#         *   **Pillar 1 & 2:** Re-evaluate the protection strategy for the plant; if it's leaving, resources can be reallocated away from its specific protection. The land it occupies might become available for new resilient development or ecological restoration.
#         *   **Pillar 2 (Economic):** Massively accelerate and expand the Economic Diversification & Workforce Transition Fund. Focus heavily on retraining the ~12% of the workforce directly affected. This becomes an urgent *economic survival* imperative.
#         *   **Pillar 3:** Potentially free up significant land for new resilient housing or natural buffers, changing the landscape of our resilience zones.
#
# 4.  **New Data: A comprehensive community survey, informed by the vulnerability assessment, reveals *strong majority support* for a proactive managed retreat strategy, even among some affected communities.**
#     *   **Update:**
#         *   **Pillar 2 (Retreat):** Increase the ambition and speed of the Voluntary Managed Retreat & Land Banking Program. Shift from a cautious, incremental approach to a more robust and widely advertised program.
#         *   **Pillar 1 (Planning):** Integrate this strong public mandate directly into the Resilience Master Plan, giving it greater authority and public backing.
#         *   **Communication:** Pivot communication strategies from "preparing for inevitable change" to "building a safer, stronger future *together* by making smart choices now."
#         *   **Political Strategy:** Use the strong public support as leverage to overcome political polarization and push through necessary but difficult policy changes.
#
# 5.  **New Data: Major technological breakthrough in flood protection (e.g., self-repairing permeable barriers, highly cost-effective floating infrastructure) becomes commercially viable and significantly cheaper than current solutions.**
#     *   **Update:**
#         *   **Pillar 2 (Protection):** Re-evaluate the cost-benefit analysis for hard vs. nature-based solutions and potentially expand the scope of protected areas or critical infrastructure, as protection becomes more feasible.
#         *   **Pillar 3 (Development):** Integrate these new technologies into resilient housing and infrastructure development, potentially making more areas viable for adaptation rather than retreat.
#         *   **Cost Estimates:** Adjust cost estimates downwards for protection elements, freeing up funds for other pillars or for expanding the scope of protection.
#         *   **Master Plan:** Incorporate these technologies into future development standards and resilience zone planning.
#
# ---
#
# Mayor, this 10-year strategy is ambitious but necessary. It recognizes our constraints while proactively steering the city towards a resilient, equitable, and economically stable future. Consistent, transparent leadership and broad engagement will be key to its success.

# %%
model_name = "deepseek-chat"
answer = ChatModel(
            model_name=model_name,
            provider="deepseek",
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# # **Comprehensive 10-Year Coastal Resilience Strategy for Mid-Sized Coastal City**
#
# ## **Executive Summary**
# This 10-year strategy prioritizes **phased managed retreat, targeted protection, and economic transition** to address sea-level rise while balancing safety, equity, heritage, and economic stability. The plan is structured in three phases: **Immediate Actions (Years 0-3)**, **Consolidation & Transition (Years 4-7)**, and **Long-term Foundation (Years 8-10)**.
#
# ---
#
# ## **PRIORITIZED STRATEGY & INTERVENTIONS**
#
# ### **1. IMMEDIATE RISK REDUCTION & PLANNING (Years 0-3)**
# **Objective:** Protect lives, freeze further risk exposure, and establish governance.
#
# #### **A. Zoning & Development Moratoria**
# - **Intervention:** Immediate moratorium on new construction/rezoning in highest-risk areas (projected 30-year inundation zone plus 100-year floodplain).
# - **Cost:** ~$500K (planning staff, legal review, outreach).
# - **Financing:** Municipal operating budget.
# - **Governance:** Emergency ordinance via city council; technical committee with independent scientists.
# - **Communication:** Clear maps in multiple languages; town halls in vulnerable neighborhoods.
# - **Performance Indicators:** 0% new permits in prohibited zones; 90% resident awareness in affected areas.
#
# #### **B. Targeted Protection for Critical Infrastructure & Historic District**
# - **Intervention:** Hybrid natural-gray infrastructure: elevate critical roads/utilities; deploy **modular flood barriers** around historic district; begin **living shoreline** restoration (oyster reefs, mangroves) as buffer.
# - **Cost:** ~$40M.
# - **Financing:** FEMA BRIC grants (25%), state resilience funds (25%), municipal bonds (50%).
# - **Governance:** Public works department with oversight committee including historic district representatives.
# - **Performance Indicators:** Reduce flood depth in historic district by 50% in 10-year storm; maintain 100% utility service during moderate flooding.
#
# #### **C. Economic Stress Test & Transition Planning**
# - **Intervention:** Commission independent study on petrochemical plant’s vulnerability and transition options (relocation, diversification, worker retraining).
# - **Cost:** ~$2M.
# - **Financing:** Public-private partnership (city 50%, state 30%, industry 20%).
# - **Communication:** Transparent process with union and company involvement.
# - **Performance Indicators:** Complete study by Year 2; establish industry-labor transition task force.
#
# ---
#
# ### **2. MANAGED RETREAT & HOUSING RELOCATION (Years 4-7)**
# **Objective:** Begin voluntary relocation from highest-risk areas while preserving community fabric.
#
# #### **A. Voluntary Property Acquisition & Land Swaps**
# - **Intervention:** Offer **pre-disaster buyouts** at pre-moratorium values for repetitive-loss properties; create **community land trust** in safer areas with priority for affected residents.
# - **Cost:** ~$150M (acquiring 500 properties @ ~$300K avg).
# - **Financing:** HUD CDBG-DR funds (40%), state bonds (40%), municipal contribution (20%).
# - **Governance:** Independent appraisal board; community oversight for land trust.
# - **Performance Indicators:** Relocate 80% of highest-risk households by Year 7; 0% displacement without option.
#
# #### **B. Historic District Adaptive Preservation**
# - **Intervention:** **Elevate/retrofit historic structures** where feasible; document/digitize cultural assets; create **"cultural continuity" fund** to support community institutions relocating together.
# - **Cost:** ~$60M.
# - **Financing:** Historic preservation tax credits (20%), philanthropic grants (30%), federal grants (50%).
# - **Performance Indicators:** 100% of significant structures documented; 70% of historic district population retained within reconstituted community.
#
# ---
#
# ### **3. ECONOMIC DIVERSIFICATION & LONG-TERM ADAPTATION (Years 8-10)**
# **Objective:** Build resilient economy and finalize long-term land use.
#
# #### **A. Petrochemical Transition Implementation**
# - **Intervention:** Based on Year 2 study: either **relocate key operations** inland with city/state incentives OR **diversify** into green chemistry/renewable energy with worker retraining.
# - **Cost:** ~$200M (relocation) or ~$80M (retraining + incentives).
# - **Financing:** Federal Economic Adjustment Assistance, state green jobs funds, private investment.
# - **Governance:** Tripartite council (city, company, labor).
# - **Performance Indicators:** Maintain ≥90% of jobs; reduce economic concentration from 12% to ≤8% of workforce.
#
# #### **B. Resilient Zoning & Blue-Green Infrastructure**
# - **Intervention:** Convert acquired risk-zone land to **multi-functional buffers** (wetlands, parks, aquaculture); update city code for **flood-proof construction** elsewhere.
# - **Cost:** ~$50M.
# - **Financing:** EPA Clean Water State Revolving Fund, conservation grants.
# - **Performance Indicators:** Convert 60% of acquired land to public resilience assets; reduce stormwater runoff by 40%.
#
# ---
#
# ## **PHASED TIMELINE**
# - **Years 0-2:** Moratoria, protection projects, economic study, governance establishment.
# - **Years 3-5:** Begin buyouts, historic district adaptation, worker retraining pilots.
# - **Years 6-8:** Scale relocation, implement economic transition, expand blue-green infrastructure.
# - **Years 9-10:** Complete priority acquisitions, evaluate and adjust.
#
# ---
#
# ## **KEY ASSUMPTIONS & UNCERTAINTIES**
# 1. **Federal/state funding** will be available at projected levels.
# 2. **Sea-level rise projections** remain within current uncertainty bounds.
# 3. **Political polarization** can be mitigated through transparent, equitable processes.
# 4. **Petrochemical plant** is willing to engage in transition planning.
# 5. **Property values** don’t collapse prematurely, enabling orderly buyouts.
# 6. **Community trust** can be built despite historical inequities.
#
# ---
#
# ## **ALTERNATIVE STRATEGIES & TRADE-OFFS**
#
# | Strategy | Main Trade-offs |
# |----------|-----------------|
# | **1. Aggressive Protection** (seawalls, pumps around entire city) | High cost (~$1B+) risks bankrupting city; provides false long-term security; may worsen equity if protecting wealthy areas first. |
# | **2. Market-Driven Retreat** (no buyouts, let insurance market drive retreat) | Faster abandonment but catastrophic for vulnerable populations; destroys community fabric; likely violates equity principles. |
# | **3. Status Quo with Incremental Protection** | Cheaper short-term but massive long-term liability; likely leads to chaotic crisis response; highest loss of life/property. |
#
# ---
#
# ## **TOP FIVE DATA NEEDS & ADAPTIVE RESPONSES**
#
# | Data Need | How It Would Change Plan | Adaptive Response |
# |-----------|--------------------------|-------------------|
# | **1. Accelerated SLR projections** (e.g., >1m by 2050) | Compress timeline; may make protection futile. | Shift to faster mandatory retreat; prioritize essential infrastructure only. |
# | **2. Petrochemical plant closure announcement** | Immediate jobs crisis. | Pivot to emergency job creation; accelerate green industry incentives. |
# | **3. Major federal resilience funding availability** | Enables more ambitious protection/relocation. | Expand buyout program; add community amenities in relocation areas. |
# | **4. Historic district community preference survey** | Reveals strong opposition to physical relocation. | Focus on maximum feasible protection; elevate critical structures. |
# | **5. Groundwater/subsidence data showing faster flooding** | Increases near-term risk. | Move protection projects earlier; expand monitoring/early warning. |
#
# ---
#
# ## **JUSTIFICATION OF MAJOR CHOICES**
#
# 1. **Prioritizing managed retreat over walling city:** Cost-benefit analysis shows permanent protection of all 20% at risk is financially unsustainable; retreat is more equitable if properly managed.
#
# 2. **Starting with voluntary buyouts:** Respects property rights while reducing future liability; mandatory relocation would face legal/political challenges.
#
# 3. **Including petrochemical transition from Year 1:** 12% employment concentration represents critical vulnerability; early planning prevents sudden economic collapse.
#
# 4. **Special historic district protections:** Rectifies historical inequities; cultural loss is irreversible unlike infrastructure.
#
# 5. **10-year horizon for 30-year threat:** Provides time for orderly transition while addressing immediate risks; aligns with political/planning cycles.
#
# 6. **Phased approach:** Builds trust through early wins; allows course correction with new data.
#
# This strategy accepts the **inevitability of retreat** from some areas while **protecting what matters most** through targeted investments, **maintaining community integrity** through planned relocation, and **ensuring economic stability** through proactive transition planning—all within realistic fiscal constraints.

# %%
model_name = "openai/gpt-oss-120b"
answer = ChatModel(
            model_name=model_name,
            provider="groq",
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# ## 1. Executive Summary
#
# **Goal:** Within **10 years** the city must (a) keep people safe from flooding, (b) make the built environment resilient, (c) protect the historic minority‑anchored district, (d) preserve the ~ 12 % jobs tied to the petrochemical plant, and (e) do it in a way that does not leave the poorest residents bearing the brunt of costs or displacement.
#
# **Approach:** A **four‑track, phased plan** that mixes *protect‑first* (defences, early‑warning), *managed‑retreat* (buy‑outs, land‑use change), *economic‑transition* (workforce up‑skilling, diversification), and *cultural‑heritage* (retrofit & interpretive tourism).
#
# The plan is ordered by **risk‑reduction impact per dollar**, **political feasibility**, and **equity**.  Every track has:
#
# | Element | Core Intervention(s) | Rough 10‑yr Cost | Primary Financing | Lead Agency / Governance | Key Performance Indicators |
# |---|---|---|---|---|---|
# | **1. Risk Mapping & Early‑Warning** | High‑resolution flood‑risk GIS, community alert system, “safe‑zone” signage | $2 – 4 M | Municipal budget + State grant (e.g., FEMA Pre‑Disaster) | City Planning + Emergency Management (joint task‑force) | % of at‑risk parcels mapped; <5 min average alert time |
# | **2. “Soft” Defences & Green Infrastructure** | Urban wetlands, living shorelines, permeable pavement, rain gardens in low‑lying neighborhoods | $45 – 70 M | Federal Climate Resilience Grants, municipal bonds, private “green‑bond” investors | Public Works + Parks & Recreation + Community Advisory Board | Flood‑peak reduction (cfs); 30 % increase in storm‑water infiltration |
# | **3. Targeted “Hard” Defences** | Modular flood‑gate/levee segments protecting critical arterial roads & the historic district (design for 1‑ft/30‑yr rise + safety margin) | $120 – 180 M | State coastal resilience fund, PPP with engineering firms, low‑interest municipal bonds | Department of Transportation + Army Corps liaison | Road closures <2 % during 1‑in‑100‑yr event |
# | **4. Managed‑Retreat & Land‑Use Re‑Zoning** | Voluntary buy‑outs + “Transfer‑of‑Development‑Rights” (TDR) to encourage development inland, creation of a “Resilience Greenbelt” in the most exposed 20 % of land | $250 – 350 M | Combination of municipal bonds, FEMA “Building Resilient Infrastructure and Communities” (BRIC) grants, impact‑fees on new development, philanthropic climate‑trusts | City Council (Zoning Committee) + Independent “Retreat Board” (incl. historic‑district reps) | % of at‑risk housing relocated (target 60 % by yr 8); greenbelt acreage protected |
# | **5. Historic‑District Preservation** | Elevation & flood‑proofing of 150 key structures, façade‑preservation grants, heritage‑tourism marketing, digital “living‑heritage” archive | $30 – 55 M | National Trust for Historic Preservation grants, state cultural‑heritage funds, community‑development block grants (CDBG) earmarked for minority‑served areas | Historic Preservation Office + Community Heritage Council | % of historic buildings retrofitted (≥90 %); increase in heritage‑tourism revenue (target +25 % yr 10) |
# | **6. Economic Transition & Workforce Development** | *Petro‑Plant Resilience* (process safety upgrades), *Just‑Transition* training hub (green‑tech, logistics, biotech), small‑business seed fund for displaced workers | $35 – 55 M | State “Just Transition” fund, private‑sector ESG investment, local workforce‑development tax‑increment financing (TIF) | Economic Development Agency + Labor Dept + Plant‑owner joint committee | % of plant workers re‑skilled (≥80 %); new green‑jobs created (≥500 by yr 10) |
# | **7. Equity & Affordable‑Housing Buffer** | 200 units of “climate‑resilient” affordable housing on reclaimed land, rent‑assistance for displaced households, anti‑displacement ordinance | $45 – 70 M | Federal Low‑Income Housing Tax Credits (LIHTC), state housing trust, community‑development finance institution (CDFI) loans | Housing Authority + Equity Advisory Council | % of displaced households rehoused within 12 mo; affordability index unchanged |
# | **8. Governance, Outreach & Monitoring** | Creation of a **Resilience Steering Committee** (mayor, council, plant rep, historic‑district elders, youth, NGOs), transparent dashboard, bilingual communications, annual “Resilience Town Hall” | $5 – 8 M | Municipal operating budget, grant‑matching from state “Climate Action” program | Mayor’s Office (Chief Resilience Officer) | Public‑trust score (annual survey >70 %); dashboard data completeness >95 % |
#
# **Total 10‑yr outlay (mid‑point):** **≈ $560 M** – **$750 M** (≈ 0.2‑0.3 % of annual city tax base, spread over a decade).  The bulk is financed **outside the municipal operating budget**, leveraging state/federal grants, low‑interest bonds, and private‑sector ESG capital.
#
# ---
#
# ## 2. Phased Implementation Timeline
#
# | Phase | Years | Core Actions (by track) | Milestones / Decision Gates |
# |---|---|---|---|
# | **0 – Prep** | 0‑1 | • Form **Resilience Steering Committee (RSC)** <br>• Secure “seed” $2 M state grant for risk‑mapping <br>• Launch public‑engagement platform (website, town‑halls) | GIS flood‑risk model delivered; RSC charter approved |
# | **1 – Immediate Protection** | 1‑3 | • Deploy community early‑warning system (SMS, sirens). <br>• Begin **soft‑infrastructure** (wetland restoration 50 ac, permeable sidewalks in flood‑prone neighborhoods). <br>• Pilot “buy‑out” in one high‑risk block (10 % of target). | 80 % of at‑risk parcels identified; pilot buy‑out 75 % uptake |
# | **2 – Scale‑Up Defences & Transition** | 3‑6 | • Build **modular flood‑gate** on main coastal artery (Phase 1). <br>• Expand buy‑outs to reach 30 % of at‑risk housing. <br>• Open **Just‑Transition Training Hub** (partner with community college). <br>• Issue first round of **green bonds** ($150 M). | Flood‑gate operational; 300 workers enrolled, 60 % completed first certification |
# | **3 – Heritage & Equity Consolidation** | 6‑8 | • Complete retrofit of 150 historic structures. <br>• Construct **200 affordable climate‑resilient units** on reclaimed greenbelt. <br>• Full TDR zoning amendment enacted. | 85 % of historic district retrofitted; affordable‑housing occupancy 90 % |
# | **4 – Full‑System Resilience & Review** | 8‑10 | • Finish remaining **hard‑defence** sections (complete barrier loop). <br>• Close remaining voluntary buy‑outs; convert vacated land to public park & storm‑water basin. <br>• Conduct **10‑yr performance audit** and update the city‑wide Climate Action Plan. | 100 % of targeted defences in place; 95 % of at‑risk housing either protected or relocated; audit shows risk‑reduction >70 % vs 2025 baseline |
# | **Beyond 10 yr** | 10+ | • Operate and maintain infrastructure (funded by a dedicated Resilience Fund). <br>• Continue monitoring sea‑level trends; adjust TDR ratios as needed. | Ongoing |
#
# ---
#
# ## 3. Detailed Track‑by‑Track Blueprint
#
# ### 3.1. Risk Mapping, Early‑Warning & Community Awareness
#
# | Intervention | Why it matters | Cost | Financing | Governance | KPI |
# |---|---|---|---|---|---|
# | **High‑resolution LiDAR & hydraulic modelling** (0.5 m DEM, flood‑depth maps) | Provides the scientific base for every subsequent decision; reduces “political guess‑work”. | $1.5 M (procurement) + $0.5 M (staff) | State/USACE grant (e.g., FEMA Pre‑Disaster) | City Planning + Emergency Management (joint task‑force) | % of parcels with flood‑risk rating (target 95 % by yr 2) |
# | **Multi‑language alert platform** (SMS, automated calls, sirens) | Saves lives; especially vital for minority community with limited English. | $0.5 M (software) + $0.2 M/yr ops | Municipal budget (re‑allocation) | Emergency Management Director | Avg. alert latency <5 min; 90 % household enrollment |
# | **“Safe‑Zone” signage & community workshops** | Empowers residents to self‑protect; builds trust. | $0.3 M | CDBG community‑development funds | Community Advisory Council | Surveyed awareness ≥80 % in at‑risk neighborhoods |
#
# **Justification:**  A $2‑$4 M upfront investment yields a *multiplier* of >10 in risk‑reduction because all later investments (buy‑outs, defences) are targeted precisely.
#
# ---
#
# ### 3.2. Soft (Nature‑Based) Defences
#
# | Intervention | Rationale | Cost | Financing | Governance | KPI |
# |---|---|---|---|---|---|
# | **Living shoreline & salt‑marsh restoration (40 ac)** | Attenuates storm surge, provides habitat, qualifies for NOAA “Coastal Resilience” grant. | $25 M | NOAA grant (≈ $15 M) + municipal green‑bond ($10 M) | Parks & Recreation + Coastal Science Advisory Board | Wave‑energy reduction at shoreline ≤ 30 % |
# | **Permeable pavement & rain‑garden network (5 km streets)** | Cuts runoff, reduces pressure on storm‑drain system. | $12 M | State storm‑water infrastructure grant | Public Works | 30 % drop in peak storm‑drain flow |
# | **Urban tree canopy & green roofs (city‑wide pilot)** | Lowers heat‑island, improves drainage, adds community amenity. | $5 M | Local corporate sponsorship, utility “green‑rate” rebate | Sustainability Office | 10 % increase in canopy cover; 5 % reduction in energy use for participating buildings |
#
# **Why nature first?**  They are *cheaper per foot of protection*, create jobs, and are politically palatable (visible community benefits).
#
# ---
#
# ### 3.3. Hard (Engineered) Defences
#
# | Intervention | Why needed | Cost | Financing | Governance | KPI |
# |---|---|---|---|---|---|
# | **Modular flood‑gate/levee system** (2 km of tide‑gate, 1.5 km of earthen berm) | Protects the main commercial corridor and the historic district, which sit just above the 1‑ft rise projection. | $150 M (incl. design, construction, 20‑yr O&M reserve) | 40 % State Coastal Resilience Fund, 30 % municipal green‑bond, 30 % private PPP (engineering firm) | Dept. of Transportation + Army Corps liaison | No road closure during 1‑in‑100‑yr storm (target) |
# | **Road elevation & bridge retrofits** (key access routes to plant & hospital) | Guarantees continuity of emergency services and the petro‑plant’s supply chain. | $70 M | Federal Highway Administration (FHWA) “Infrastructure for Climate Resilience” grant (≈ $30 M) + municipal bonds | Public Works + RSC | Travel time increase <5 % during storm events |
# | **Utility hardening (underground power, flood‑proof substations)** | Prevents prolonged outages that can cripple the plant and low‑income neighborhoods. | $30 M | Utility‑company cost‑share (50 %) + state energy‑resilience fund | City Utilities Board | Outage duration <2 h during 50‑yr event |
#
# **Cost‑effectiveness:**  The modular design allows future height upgrades if sea‑level rise accelerates, limiting sunk‑cost risk.
#
# ---
#
# ### 3.4. Managed‑Retreat & Land‑Use Re‑Zoning
#
# | Intervention | Why it matters | Cost | Financing | Governance | KPI |
# |---|---|---|---|---|---|
# | **Voluntary buy‑out program** (target 20 % of at‑risk housing, 6 000 units) | Provides a dignified exit for residents in the most exposed zones; reduces future emergency‑relief spend. | $250 M (average $40k per unit, plus admin) | FEMA BRIC grant (up to 75 % per unit) + municipal bonds (30‑yr, 2.5 %) + “Resilience Tax Increment” on new inland developments | **Retreat Board** (incl. historic‑district reps, low‑income advocates) | % of at‑risk housing purchased (target 60 % by yr 8) |
# | **Transfer‑of‑Development‑Rights (TDR) program** | Allows developers to increase density **away** from the coast while preserving open space **in** the risk zone (greenbelt). | $5 M (legal & admin) | Municipal budget (dedicated TDR fund) | Planning Dept + City Council | Net increase in inland housing units (≥ 2 k) |
# | **Resilience Greenbelt** (converted to flood‑plain park & storm‑water storage) | Turns “dead land” into public amenity, reduces flood energy, creates equity‑focused recreation. | $45 M (land acquisition + park construction) | State parks & recreation grant + private philanthropy | Parks & Recreation + Community Advisory Council | Acres of greenbelt created (target 150 ac) |
#
# **Equity Lens:**  Buy‑outs are **means‑tested**; low‑income households receive additional relocation assistance ($5 k) and priority for the new affordable units (see Section 3.7).
#
# ---
#
# ### 3.5. Historic‑District Preservation
#
# | Intervention | Rationale | Cost | Financing | Governance | KPI |
# |---|---|---|---|---|---|
# | **Structure elevation & flood‑proofing** (150 key buildings) | Keeps the cultural heart intact; qualifies for Federal “Historic Preservation Tax Credits”. | $35 M | 40 % National Trust grant, 30 % state historic‑preservation fund, 30 % private donations (heritage foundations) | Historic Preservation Office + Community Heritage Council | % of historic structures retrofitted (≥ 90 %) |
# | **Façade‑preservation & design‑guidelines** (new infill) | Prevents “gentrification‑driven demolition” while allowing compatible development. | $5 M (guideline development, review) | Municipal budget (planning) | Planning Dept + Heritage Council | Number of permits complying with guidelines (target 100 % in district) |
# | **Heritage‑tourism marketing & digital archive** | Generates revenue to fund ongoing maintenance and creates jobs for minority residents (guides, artisans). | $5 M | CDBG‑East (Economic Development) + private sponsorship | Economic Development Agency | Year‑over‑year tourism spend (+25 % by yr 10) |
# | **Community‑led oral‑history project** | Embeds intangible culture, builds political support for preservation. | $0.5 M | Local foundation, university partnership | Community Heritage Council | Number of interviews captured (≥ 300) |
#
# **Why a separate budget?**  The historic district is a **cultural‑equity anchor**; separating funding avoids competition with “hard” infrastructure and signals commitment to minority heritage.
#
# ---
#
# ### 3.6. Economic Transition & Just‑Transition for Petrochemical Workforce
#
# | Intervention | Rationale | Cost | Financing | Governance | KPI |
# |---|---|---|---|---|---|
# | **Plant safety & flood‑proof upgrades** (elevated critical equipment, secondary power) | Guarantees the plant can continue operating safely, preserving 12 % of city jobs. | $20 M | Plant‑owner cost‑share (70 %) + state “Industrial Resilience” grant (30 %) | Joint Plant‑City Resilience Committee (incl. labor union) | Plant downtime <24 h during flood event |
# | **Just‑Transition Training Hub** (green‑tech, advanced manufacturing, logistics) | Provides an alternative career path for workers whose roles may be displaced by automation or future plant downsizing. | $30 M | State “Just Transition” fund, private ESG investors, local community‑college contributions | Economic Development Agency + Labor Dept | Workers completing certification (≥ 80 % of participants) |
# | **Small‑business seed fund** (target 150 minority‑owned start‑ups) | Diversifies the local economy, reduces reliance on a single employer. | $15 M (grant + loan‑loss reserve) | Federal Economic Development Administration (EDA) + local CDFI | Small‑Business Development Center | New businesses launched (≥ 100) |
# | **Carbon‑tax revenue recycling** (if/when state adopts carbon pricing) | Long‑term financing for transition; aligns with plant’s own emissions reductions. | Variable (future) | State carbon‑tax fund earmarked for “Just Transition” | City Council (budget committee) | % of transition fund financed by carbon‑tax revenue (target 30 % by yr 10) |
#
# **Justification:**  Protecting the plant **short‑term** avoids a sudden economic shock, while **simultaneously** investing in alternative pathways avoids “lock‑in” to a carbon‑intensive sector.
#
# ---
#
# ### 3.7. Equity & Affordable‑Housing Buffer
#
# | Intervention | Why needed | Cost | Financing | Governance | KPI |
# |---|---|---|---|---|---|
# | **200 climate‑resilient affordable units** (elevated foundations, flood‑proof utilities) on reclaimed greenbelt | Guarantees that displaced low‑income households have a place to go; avoids “climate‑gentrification”. | $55 M | LIHTC (≈ $30 M) + state housing trust ($15 M) + municipal bond ($10 M) | Housing Authority + Equity Advisory Council | % of displaced households rehoused within 12 mo (≥ 90 %) |
# | **Rent‑assistance & moving stipend** (for households relocating out of the risk zone) | Reduces financial burden of displacement. | $5 M over 10 yr | Federal Emergency Management Agency (FEMA) “Community Development Block Grant – Disaster” | Housing Authority | Average household relocation cost covered (≥ 80 %) |
# | **Anti‑Displacement Ordinance** (requires 10 % of new development units to be affordable) | Prevents market‑driven rent spikes in newly “safe” neighborhoods. | $0.5 M (legal drafting, enforcement) | Municipal budget | City Council + Legal Department | Ratio of affordable units to market units (target 10 %) |
# | **Community‑benefit agreements** with the petro‑plant (e.g., fund scholarships for local youth) | Links the plant’s continued presence to direct community returns. | $3 M | Plant‑owner contribution (negotiated) | RSC (with labor union) | Number of scholarships awarded (≥ 50 yr 1) |
#
# ---
#
# ### 3.8. Governance, Outreach & Monitoring
#
# | Component | Details | Cost | Financing | Lead |
# |---|---|---|---|---|
# | **Resilience Steering Committee (RSC)** (15 members, quarterly public meetings) | Multi‑stakeholder body that approves budgets, monitors KPIs, adjudicates conflicts. | $1 M (staff, admin) | Municipal operating budget (matched by state grant) | Mayor’s Office (Chief Resilience Officer) |
# | **Public‑dashboard & open‑data portal** | Real‑time flood‑risk map, project status, finances; mobile‑friendly. | $2 M (development + 5 yr maintenance) | Grant from Open Government Partnership | IT Department |
# | **Bilingual communications campaign** (social media, flyers, community radio) | Builds trust especially in historic minority district. | $2 M (5 yr) | CDBG‑East & municipal budget | Community Outreach Office |
# | **Annual “Resilience Town Hall”** | Review of performance, citizen Q&A, voting on any major plan revision. | $0.5 M (venue, facilitation) | Municipal budget | RSC Chair |
#
# **KPIs** are tracked on a **quarterly** basis; any metric that falls >15 % short of target triggers a **mid‑year corrective workshop**.
#
# ---
#
# ## 4. Key Assumptions & Uncertainties
#
# | Assumption | Impact if Wrong | Mitigation |
# |---|---|---|
# | **Sea‑level rise of ≈ 1 ft by 2050** (IPCC RCP 4.5) | Under‑design of hard defences; higher future retrofitting cost. | Build **modular, up‑gradable** barriers; embed a *review‑point* at yr 5 to adjust design heights. |
# | **Petrochemical plant will remain operational for at least 15 yr** | Over‑investment in plant upgrades, lock‑in of emissions. | Include **conditional clauses** in plant‑owner cost‑share (e.g., upgrade funding phased based on plant’s production outlook). |
# | **State & federal climate‑grant pipelines remain available** | Funding shortfalls leading to project delays. | Secure **bond‑backed “Resilience Fund”** as backup; stagger projects to match cash‑flow. |
# | **Community willingness to accept voluntary buy‑outs** | Low participation → “hold‑out” parcels that block greenbelt creation. | Offer **enhanced incentives** (tax‑abatement on relocated land, priority for affordable housing). |
# | **Labor market will support transition to green jobs** | Retraining may not lead to employment, causing political backlash. | Partner with **regional employers** (port, renewable‑energy firms) to pre‑commit to hire a share of trainees. |
# | **Historic‑district residents will prioritize preservation over relocation** | Pushback against retrofitting costs. | Conduct **participatory design workshops**; allow “cultural‑relocation” (moving structures) as a last resort. |
#
# ---
#
# ## 5. Three Alternative Strategies & Trade‑offs
#
# | Strategy | Core Premise | Main Advantages | Main Disadvantages / Risks |
# |---|---|---|---|
# | **A. Aggressive Managed‑Retreat** (Buy‑outs for 80 % of at‑risk land, convert most of the 20 % to greenbelt; minimal hard defences) | **Risk‑avoidance** – eliminates exposure, creates large public park. | Lowest long‑term maintenance cost; creates new recreation & ecosystem services; strong equity narrative. | High upfront cost ($350‑$450 M); political resistance from plant and some homeowners; loss of tax base from vacated land. |
# | **B. “Fortress City”** (Build a continuous, 10‑ft‑high seawall + massive pump stations; keep all land, minimal retreat) | **Infrastructure‑first** – protect existing development, preserve tax base. | Keeps current jobs and property values; clear, visible symbol of action. | Very high capital cost ($500‑$650 M) + O&M (> $20 M/yr); may exacerbate inequity if low‑income neighborhoods are left outside the wall; risk of “false sense of security”. |
# | **C. Business‑as‑Usual + Incremental Adaptation** (Only early‑warning and modest green infrastructure; no major buy‑outs or hard defences) | **Fiscal conservatism** – rely on existing budget, hope for slower sea‑level rise. | Cheapest short‑term; politically easiest. | Likely **catastrophic loss** of life/property by yr 10; huge future FEMA disaster costs; disproportionate impact on vulnerable groups; damage to city’s reputation and tourism. |
#
# **Why the recommended plan sits between A and B:**
# It **mixes** selective retreat (protecting the most exposed 20 % of land) with **targeted hard defences** around critical corridors and the historic district, while leveraging **nature‑based solutions** for cost‑effectiveness. This balances **budget reality**, **political feasibility**, and **equity** better than the extremes.
#
# ---
#
# ## 6. Top Five Pieces of New Data That Could Shift the Plan
#
# | Data Item | How it would affect the plan | Update Mechanism |
# |---|---|---|
# | **1. Revised local sea‑level rise projection (e.g., 1.5 ft by 2050)** | Would require raising the design elevation of flood‑gates, possibly expanding the retreat zone. | Conduct a **“design‑height re‑assessment”** at the end of Year 4; adjust engineering specifications and TDR ratios accordingly. |
# | **2. Independent economic impact study of the petrochemical plant (e.g., projected 30 % job loss in 7 yr)** | Would push the city toward a **faster, larger just‑transition** component and possibly negotiate a **plant‑closure buy‑out**. | Activate the **“Economic Shock Protocol”** of the RSC; re‑allocate 20 % of the resilience bond proceeds to training & seed‑fund. |
# | **3. Federal “Coastal Resilience” grant program rules change (e.g., higher matching‑fund requirement)** | May reduce available external financing, forcing the city to seek more municipal bonds or private capital. | Re‑run the **Financing Model**; prioritize low‑cost green‑infrastructure and delay the most expensive hard‑defence segments. |
# | **4. Updated demographic vulnerability index showing a new hotspot in a low‑income inland suburb** | Would broaden the equity focus, prompting additional affordable‑housing or retrofitting in that area. | Amend the **Equity Action Plan** (Year 5) to add a second affordable‑housing phase and a targeted community‑outreach budget. |
# | **5. Technological breakthrough: low‑cost, self‑healing flood‑gate material** | Could lower the hard‑defence budget, freeing funds for other tracks (e.g., more buy‑outs). | Conduct a **tech‑adoption pilot** in Year 3; if successful, re‑budget 10‑% of hard‑defence funds to retreat. |
#
# **Update Process:**
# All new data trigger a **RSC “Data‑Review Session”** (within 90 days of receipt). The session produces a **“Plan Amendment Recommendation”**, which is voted on by the City Council. The public dashboard is instantly updated, and a **special town‑hall** communicates changes.
#
# ---
#
# ## 7. Why the Recommended Choices Are Reasonable
#
# 1. **Risk‑adjusted cost‑effectiveness:**  Nature‑based solutions cost roughly **$1‑2 M/acre** and provide multi‑benefit returns (flood attenuation, jobs, recreation).  Hard defences are reserved for **critical arteries** where failure would cripple the economy or cultural core.
#
# 2. **Equity built‑in:**  All major financing streams (GRANT, LIHTC, CDBG) have **low‑income or minority‑focused eligibility**; the buy‑out program is means‑tested; affordable housing is built on reclaimed land, not on scarce existing parcels.
#
# 3. **Political palatability:**  By **preserving the petrochemical plant** (short‑term), the plan avoids a powerful opposition bloc.  Simultaneously, **visible green‑infrastructure** (parks, wetlands) wins community support.  The phased approach lets the city demonstrate quick wins (early‑warning, pilot buy‑out) to build trust.
#
# 4. **Financing diversity:**  The plan does not rely on a single source; it blends **federal/state grants**, **municipal bonds**, **private ESG capital**, and **tax‑increment financing**.  This spreads risk and keeps the city’s debt metrics within acceptable limits (projected debt service < 3 % of annual general‑fund revenue).
#
# 5. **Scalability & adaptability:**  Modular flood‑gates, TDR, and the Resilience Steering Committee all allow the plan to be **scaled up or down** as sea‑level projections or economic conditions evolve.
#
# ---
#
# ## 8. Condensed Action Checklist (What the Mayor Signs Today)
#
# | Immediate (0‑6 mo) | 6‑24 mo | 2‑5 yr | 5‑10 yr |
# |---|---|---|---|
# | • Appoint **Chief Resilience Officer** & form **Resilience Steering Committee**. | • Secure first round of **state/federal grants** (risk mapping, green‑infrastructure). | • Issue **first green bond**; begin **hard‑defence** design. | • Complete **full greenbelt** & **affordable‑housing** build‑out. |
# | • Commission **high‑resolution flood‑risk GIS**. | • Launch **early‑warning platform**; begin community workshops. | • Start **voluntary buy‑outs** (pilot → scale). | • Finish **historic‑district retrofit**; open **heritage tourism** program. |
# | • Publicly commit to **anti‑displacement ordinance**. | • Begin **living‑shoreline** construction (first 10 ac). | • Open **Just‑Transition Training Hub**; partner with plant. | • Conduct **10‑yr performance audit**; adjust financing as needed. |
# | • Publish **Resilience Dashboard** (baseline data). | • Approve **TDR zoning amendment**. | • Build **modular flood‑gate** Phase 1. | • Review sea‑level projections; upgrade defences if needed. |
#
# ---
#
# **Prepared for:** Mayor [Name], City of [Coastal City]
# **Prepared by:** [Your Consulting Team] – Climate‑Resilience & Urban‑Equity Specialists
# **Date:** January 1 2026
#
# *All cost figures are 2026 USD, rounded to the nearest $5 M; actual bids may vary.*

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
#!ollama pull deepseek-r1:7b

# %%
model_name = "deepseek-r1:7b"
answer = ChatModel(
            model_name=model_name,
            provider="ollama",
            api_key="me"
        ).generate_response(
            messages=messages,
            print_response=True
        )

competitors.append(model_name)
answers.append(answer)
# Out:
# To address the challenges posed by sea-level rise in the coastal mid-sized city, a comprehensive and balanced strategy is developed to protect lives, preserve culture, maintain economic stability, and ensure equity. The strategy incorporates four main elements, each with specific actions, costs, financing mechanisms, governance steps, performance indicators, timelines, assumptions, uncertainties, alternative strategies, and key data points.
#
# ### Strategy Elements:
#
# 1. **Mitigation and Adaptation Planning**
#    - **Actions**: Implement sea wall construction on high-risk areas (e.g., 90+ meters from shore) with projected costs of $500M over a decade.
#    - **Cost Estimations**: Initial funding sources include federal grants, state funds, and private partnerships. Public-private collaborations are proposed for sustained investment.
#
# 2. **Cultural Heritage Preservation**
#    - **Actions**: Revitalization projects such as upgrading the historic district into a cultural hub with cost ~$30M over five years.
#    - **Cost Estimations**: Includes preservation grants, community donations, and potential federal support post-improvement.
#
# 3. **Economic Resilience InvestmenT**
#    - **Actions**: Development of targeted sectors like renewable energy ($15M annually) and tech hubs ($20M annual investment).
#    - **Cost Estimations**: Supported by state reinvestment funds for infrastructure upgrades, targeting local vendors to promote equity.
#
# 4. **Equity-Focused ReZHousing and Job Programs**
#    - **Actions**: Relocation programs with integrated support systems ($10M annually) including job creation in resilient sectors.
#    - **Cost Estimations**: Utilized through federal grants, philanthropy, and donor funding for ensuring equitable opportunities.
#
# ### Timeline Phases:
# - **First 3 Years**: Risk assessment and stakeholder engagement; preliminary adaptation measures like upgrading storm drainage;
# - **Next 5 Years**: Implementation of early sea wall measures and economic resilience projects;
# - **Final 2 Years**: Full-scale cultural preservation initiatives with targeted equity job programs;
#
# ## Assumptions & Uncertainties:
# - **Assumptions**: Projections indicate a steady-state sea-level rise, economic impacts of the petrochemical industry are significant, and cultural preservation is key to identity.
# - **Uncertainties**: Variability in sea-level projections, economic resilience of the petrochemical sector, and community's response to cultural preservation.
#
# ## Alternative Strategies:
# 1. Strengthen coastal infrastructure with adaptive measures focusing on high-risk areas.
# 2. Invest heavily in renewable energy while preserving historical sites as buffers.
# 3. Leverage minority expertise for cultural preservation while prioritizing resilient sectors and equity job programs.
#
# ## Top Data Points:
# - **Sea-level rise trajectory**: Crucial to review projections regularly.
# - **Petroleum industry impact**: Potential evolution based on policies and market shifts.
# - **Cultural preservation costs vs infrastructure**: Assessing community support and resources.
# - **Equity in relocation**: Evaluating integration strategies for affected populations.
#
# This strategy balances immediate needs with long-term sustainability, ensuring all sectors—lives, culture, economy, equity—are addressed effectively.

# %%
print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-5', 'gemini-2.5-flash', 'deepseek-chat', 'openai/gpt-oss-120b', 'deepseek-r1:7b']
# ['Executive summary\nWorking within a 10-year planning horizon and a constrained fiscal environment, the city should pursue a balanced, phased resilience strategy that (1) protects lives and essential property (especially in high-risk flood zones and near the petrochemical cluster), (2) preserves economic stability and jobs (including a safe, continued operation of the major employer while diversifying the economy), (3) safeguards the historic district and supports inclusive, equitable outcomes for vulnerable residents, and (4) builds transparent governance and diversified financing to sustain implementation. The strategy combines hard and nature-based protections where cost-effective, targeted relocation/retreat options only where necessary, workforce retraining and economic diversification, and robust community engagement. It relies on multi-source financing (federal/state grants, resilience bonds, public-private partnerships, special assessments), staged capital investments, and a cross-agency resilience governance structure with strong public communication.\n\nPillar 1. Protect lives and high-risk property; improve resilience of critical assets (near-term focus)\nWhy this is first: 1) saves lives in storms/floods, 2) preserves critical infrastructure and the petrochemical plant’s safety, 3) reduces potential cascading losses to the economy and minority communities.\n\nInterventions, order-of-magnitude costs, financing, governance, metrics, timeline\n\n- A. Critical-infrastructure flood protection and floodproofing\n  - What: Harden emergency services, hospital, and key essential facilities; elevate or floodproof critical electrical and data centers; protect evacuation routes and bridges leading to the Historic District and key economic zones.\n  - Estimated cost (order of magnitude): $50M–$400M (depends on asset inventory and existing protection levels)\n  - Financing mechanisms: municipal bonds (short- to mid-term), federal/State hazard mitigation grants (FEMA, HUD), public-private cost-sharing with critical-service partners, storm-hardening set-aside funds.\n  - Governance/communication: establish a cross-department “Resilience Hardening Team” with periodic briefings to City Council; publish a 24/7 status dashboard during events; bilingual emergency updates; involve the Petrochemical Plant Safety Liaison in planning.\n  - Performance indicators: days of service continuity during storms; percent of critical facilities with floodproofing/upgrades; time to restore essential services after a storm.\n  - Timeline: 0–2 years design and initial upgrades; 2–5 years full implementation in the highest-risk corridors; 5–10 years expanded where needed.\n\n- B. Nature-based coastal protections and hybrid defenses\n  - What: Restored marsh/wetland buffers, dune restoration, living shorelines, and tide/sea-level rise adaptive buffers; where feasible pair with seawalls or flood barriers in the most vulnerable pockets.\n  - Estimated cost: $50M–$600M (high variance based on land ownership and habitat restoration scale)\n  - Financing: federal/state resilience grants, environmental equity funds, watershed/land-conservation funds, debt financing if staged; potential private restoration investment in exchange for long-term public benefits.\n  - Governance/communication: interagency coastal program with capability to implement environmental permits quickly; community engagement in restoration sites; outreach in multiple languages.\n  - Performance indicators: acreage of restored/retained natural buffers; reduction in flood depth in target zones; habitat quality metrics; public blue-green space access.\n  - Timeline: 1–3 years planning and permitting; 3–7 years implementation; monitoring ongoing through year 10 and beyond.\n\n- C. Drainage, floodplain management, and utility hardening\n  - What: Upgraded pumping stations, gravity drainage, reduced culvert bottlenecks, secondary power sources for critical systems; climate-resilient utility cor ...

# %%
together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
results = ChatModel(
            model_name="gpt-5-mini",
            provider="openai"
        ).generate_response(
            messages=judge_messages,
            print_response=True
        )
# Out:
# {"results": ["2", "5", "1", "3", "4", "6"]}

# %%
results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: claude-sonnet-4-5
# Rank 2: openai/gpt-oss-120b
# Rank 3: gpt-5-nano
# Rank 4: gemini-2.5-flash
# Rank 5: deepseek-chat
# Rank 6: deepseek-r1:7b

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
